# %%
# LFV Higgs Decays in Scotogenic Model

# %% [markdown]
# This model is a simple extension Standard Model which includes an extra $Z_2$ symmetry, second Higgs doublet and finally three right handed neutrinos,  all this new fields are odd under $Z_2$ symmetry.
# The matter content of the Scotogenic Model with the group $SU(2)_L\otimes U(1)_Y\otimes Z_2$ is given by [Ma 2006](https://journals.aps.org/prd/abstract/10.1103/PhysRevD.73.077301):
# $$
# \left(\nu_{L i}, l_{L i}\right) \sim(2,-1 / 2,+),\quad l_{R i} \sim(1,1,+), \quad N_{R i} \sim(1,0,-)$$
# $$
# \left(\phi^{+}, \phi^{0}\right) \sim(2,1 / 2,+), \quad\left(\eta^{+}, \eta^{0}\right) \sim(2,1 / 2,-)
# $$
# Yukawa sector allows the interaction between left and right handed neutrinos including $\eta$ field
# $$
# \mathcal{L}_{Y}=f_{i j}\left(\phi^{-} \nu_{L i}+\overline{\phi_{0}} l_{L i}\right) l_{R j}+y_{i j}\left(\nu_{L i} \eta_{0}-l_{L i} \eta^{+}\right) N_{R j}+ \textrm{h. c.},
# $$
# and the Majorana term to right handed neutrinos is added.
# $$
# \frac{1}{2} M_{i} N_{R i} N_{R i}+h . c .
# $$
# In this case the more general scalar potential under $Z_2$ symmetry is given by
# $$
# V(\Phi, \eta)= \mu_{1}^{2}\left(\Phi^{\dagger} \Phi\right)+\mu_{2}^{2}\left(\eta^{\dagger} \eta\right)+\frac{\lambda_{1}}{2}\left(\Phi^{\dagger} \Phi\right)^{2}+\frac{\lambda_{2}}{2}\left(\eta^{\dagger} \eta\right)^{2} +\lambda_{3}\left(\Phi^{\dagger} \Phi\right)\left(\eta^{\dagger} \eta\right)+\lambda_{4}\left(\Phi^{\dagger} \eta\right)\left(\eta^{\dagger} \Phi\right)+\frac{\lambda_{5}}{2}\left[\left(\Phi^{\dagger} \eta\right)^{2}+ \textrm{h. c.} \right].
# $$
# The mass spectrum to new scalar particles is
# $$
# m^{2}(\sqrt{2} R e \phi_{0})=m_h^2 =2 \lambda_{1} v^{2},$$
# $$ m^{2}\eta^{ \pm}=m_{\eta}^2 =\frac{\lambda_{3} v^{2}}{2}+m_{2}^{2},$$
# $$m^{2}(\sqrt{2} Re \eta_{0})=m_{R}^2 =2 m_{2}^{2}+v^{2}\left(\lambda_{3}+\lambda_{4}+\lambda_{5}\right), $$
# $$m^{2}\sqrt{2} Im \eta_{0}=m_I^2=2 m_{2}^{2}+v^{2}\left(\lambda_{3}+\lambda_{4}-\lambda_{5}\right),
# $$
# and SM-like Higgs is associated to $h = \sqrt{2}\text{Re}\phi_0 $.
#
# Neutrino mass is generated by a radiative seesaw mechanism. The analytic expression is given by
# $$
# \left(\mathbf{\mathcal{M}}_\nu\right)_{i j}= y_{i k} y_{j k} M_{k} \frac{1}{16 \pi^{2}}\left[\left(\frac{m_{R}^{2}}{M_{k}^{2}-m_{R}^{2}} \log \frac{m_{R}^{2}}{M_{k}^{2}}\right)-\left(\frac{m_{I}^{2}}{M_{k}^{2}-m_{I}^{2}} \log \frac{m_{I}^{2}}{M_{k}^{2}}\right)\right],
# $$
# where $m_R$, $m_I$, $m_\eta$ and $M_k$ are the masses of $\eta_R$, $\eta_I$, $\eta^{\pm}$ and $N_{Ri}$ respectively. Also, $k$ index sums over heavy neutrino masses. In the particular case in which  $m_R^2 - m_I^2 = 2 \lambda_{5} v^2$ is assumed smaller than $m_0^2 = (m_R^2 + m_I^2)/2$ we have the next simplification
#
# $$
# \left(\mathcal{M}_{\nu}\right)_{i j}=\frac{\lambda_{5} v^{2}}{8 \pi^{2}} \sum_{k} \frac{y_{i k} y_{j k} M_{k}}{m_{0}^{2}-M_{k}^{2}}\left[1-\frac{M_{k}^{2}}{m_{0}^{2}-M_{k}^{2}} \ln \frac{m_{0}^{2}}{M_{k}^{2}}\right].
# $$
# Which can be rewritten in a matrix form as follows
# $$
# \mathbf{\mathcal{M}}_\nu = \mathbf{Y}\mathbf{D}_{\Lambda}\mathbf{Y}^{\top},
# $$
# where
# $$
# \mathbf{D}_{\Lambda} = \text{diag}(\Lambda_1,\Lambda_2,\Lambda_3)$$
# $$\Lambda_k = \frac{\lambda_{5} v^2}{16 \pi M_k} I(\frac{M_k^2}{m_0^2}), $$
# $$I(x) = \frac{x}{1-x} + \frac{x^2 \ln{x}}{(1-x)^2},
# $$
# To other side, Yukawa matrix can be parametrized in terms of neutrinos masses and one orthogonal matrix by means of Casas-Ibarra parmetrization [Casas, Ibarra 2001](https://www.sciencedirect.com/science/article/pii/S0550321301004758?via%3Dihub)
# $$
# \mathbf{Y} = \mathbf{D}_{(\sqrt{\Lambda})^{-1}} \mathbf{R} \mathbf{D}_{\sqrt{m_{\nu}}} \mathbf{U}^{\dagger}
# $$
# where $\mathbf{U}$ is the Pontercorvo-Maki-Nakata-Sakata matrix, also the next notation is followed for diagonal matrices,
# $$
# \mathbf{D}_{(\sqrt{\Lambda})^{-1}} = \text{diag}(\sqrt{\Lambda_1}^{-1},\sqrt{\Lambda_2}^{-1},\sqrt{\Lambda_3}^{-1}),\,\,
# \mathbf{D}_{(\sqrt{m_\nu})} = \text{diag}(\sqrt{m_{\nu_1}},\sqrt{m_{\nu_2}},\sqrt{m_{\nu_3}}),
# $$
# To other hand, $\mathbf{R}$ orthogonal matrix can be parametrized in general by three complex angles  $\theta_{1,2,3}$ as follows:
# $$
# \mathbf{R}=\left(\begin{array}{ccc}
# {c_{2} c_{3}} & {-c_{1} s_{3}-s_{1} s_{2} c_{3}} & {s_{1} s_{3}-c_{1} s_{2} c_{3}} \\
# {c_{2} s_{3}} & {c_{1} c_{3}-s_{1} s_{2} s_{3}} & {-s_{1} c_{3}-c_{1} s_{2} s_{3}} \\
# {s_{2}} & {s_{1} c_{2}} & {c_{1} c_{2}}
# \end{array}\right)
# $$
# where the notation $c_i \equiv \cos{\theta_i}$ and $s_i \equiv \sin{\theta_i}$ has been used.
# Finally, for LFV Higgs decays the pertinent vertexes in this model are given in  the next table.
#
# |          Vertex          | Coupling                                               |          Vertex          | Coupling|
# |:------------------------:|:--------------------------------------------------------:|:------------------------:|:--------------------------------------------------------:|
# |      $h G^{+} G^{-}$     | $-i \frac{m_{h}^{2}}{v}$                               |   $h \eta^{+} \eta^{-}$  | $ \frac{-2i\left(m_{\eta}^{2}-\mu_{2}^{2}\right)}{v} $ |
# |  $G^{-}l^{+}_i \nu_{j}$  | $i \frac{\sqrt{2}}{v} m_i U^{*}_{ji} P_{L}$            |  $G^{+}l^{-}_i \nu_{j}$  | $i \frac{\sqrt{2}}{v} m_i U_{ji} P_{R}$                |
# |      $h G^{+} W^{-}$     | $\frac{i}{2}g_2 (-p^{G^{+}}_\mu + p^{h}_\mu)$          |     $h  W^{+} G^{-}$     | $-\frac{i}{2}g_2 (p^{G^{-}}_\mu + p^{h}_\mu)$          |
# |  $W^{-} l^{+}_i \nu_{j}$ | $-i \frac{g_2}{\sqrt{2}}U^{\nu *}_{ji} \gamma_\mu P_L$ |  $W^{+} l^{-}_i \nu_{j}$ | $-i \frac{g_2}{\sqrt{2}}U^{\nu}_{ji} \gamma_\mu P_L$   |
# | $\eta^{-} l^{+}_i N_{l}$ | $i y^{*}_{li}$                                         | $\eta^{+} l^{-}_i N_{l}$ | $i y_{li}$                                             |
# |  $h W^{+}_\mu W^{-}_\nu$ | $\frac{i}{2}g_2^2 v g_{\mu \nu}$                       |                          |                                                        |

# %% [markdown]
# ![dia_htaumuPar.png](/home/moiseszm/Dropbox/ART_MOY-LOR-OL 2020/Images/dia_htaumuPar.png)

# %% [markdown]
# # LFVHD Scotogenic model
# ## Diagrams
# ![dia_htaumuPar.png](attachment:dia_htaumuPar.png)

# %% [markdown]
# this![BubleScoto.png](attachment:BubleScoto.png)

# %% [markdown]
# ## Heavy neutrino contributions to LFV Higgs Decays

# %% [markdown]
# Scotogenic model has a total split between standard model particles and new particles as a consequence of $Z_2$ symmetry. Then, LFV Higgs decays has separate contributions of light neutrinos ($\nu_i$) and heavy neutrinos ($N_i$). Light neutrino contribution is smaller due to light neutrino mas order ($<1$eV). To other side, heavy neutrino contribution has a wide allowed parameter space where we can find higher values of $Br(h \rightarrow l_i l_j)$, and the number of diagrams to consider is only three. The diagrams involved are only three and only charged inert scalars and heavy neutrinos appear.

# %%
import OneLoopLFVHD as lfvhd
from sympy import symbols, init_printing, conjugate,I,IndexedBase,Matrix,Add,MatrixSymbol, lambdify
init_printing()

# %%
from mpmath import *

# %%
mp.dps = 80; mp.pretty = True

# %% [markdown]
# **Defining symbolic variables**

# %%
μ2,v = symbols(r'\mu_2,v',real=True)
Yν = IndexedBase(r'{{Y^\nu}}')
l,i,j = symbols('l,i,j',integer=True)

## Masses of heavy neutrino l and charged scalars
mNul,mη = symbols(r'm_{{N_l}},m_{{\eta}}',positive=True)
masasNηη = [mNul,mη,mη]

λ3 = (2/v**2)*(mη**2-μ2**2)

# %% [markdown]
# **Defining Vertexes**

# %%
vertex_hηuηd = lfvhd.VertexHSS(-I*λ3*v)
vertex_ηuljNl = lfvhd.VertexSFF(0,I*Yν[l,j]) 
vertex_ηdliNl = lfvhd.VertexSFF(I*conjugate(Yν[l,i]),0)

# %% [markdown]
# ### Triangle diagram $N_l \eta^+ \eta^-$

# %%
TriangleNlηuηd = lfvhd.TriangleFSS(vertex_hηuηd,vertex_ηuljNl,vertex_ηdliNl,masasNηη)

# %%
TriangleNlηuηd.AL().subs(lfvhd.cambiosDivFin(mNul,mη,mη))#.subs(lfvhd.cambios_aprox(mNul,mη,mη))
# Out:
#     ⎛      2             2⎞ ⎛⎛           2             2⎞
# -mᵢ⋅⎝- \mu₂  + m_{{\eta}} ⎠⋅⎝⎝- m_{{N_l}}  + m_{{\eta}} ⎠⋅C₀(m_{{N_l}}, m_{{\e
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ta}}, m_{{\eta}}) + {{b_0}}__{(1)}(m_{{N_l}}, m_{{\eta}}) - {{b_0}}__{(12)}(m_
# ──────────────────────────────────────────────────────────────────────────────
#                           2   2
#                        8⋅π ⋅mₐ ⋅v
#
#                      ⎞ _______________
# {{\eta}}, m_{{\eta}})⎠⋅{{Y^\nu}}[l, i]⋅{{Y^\nu}}[l, j]
# ───────────────────────────────────────────────────────

# %%
TriangleNlηuηd.AL()#_GIM()#.factor()
# Out:
#     ⎛      2             2⎞                                       ____________
# -mᵢ⋅⎝- \mu₂  + m_{{\eta}} ⎠⋅C₁(m_{{N_l}}, m_{{\eta}}, m_{{\eta}})⋅{{Y^\nu}}[l,
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2
#                                               8⋅π ⋅v
#
# ___
#  i]⋅{{Y^\nu}}[l, j]
# ────────────────────

# %%
str(TriangleNlηuηd.AL()).replace('m_i','mi').replace(
    '\\mu_2','mu2').replace('m_{{\\eta}}','meta').replace(
    'm_{{N_l}}','mNl').replace(
    'conjugate({{Y^\\nu}}[l, i])','Ynucli').replace(
    '{{Y^\\nu}}[l, j]','Ynulj')
# Out:
# '-mi*(-mu2**2 + meta**2)*C_1(mNl, meta, meta)*Ynucli*Ynulj/(8*pi**2*v)'

# %%
TriangleNlηuηd.AR()#_GIM().simplify()
# Out:
#     ⎛      2             2⎞                                       ____________
# m_j⋅⎝- \mu₂  + m_{{\eta}} ⎠⋅C₂(m_{{N_l}}, m_{{\eta}}, m_{{\eta}})⋅{{Y^\nu}}[l,
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2
#                                               8⋅π ⋅v
#
# ___
#  i]⋅{{Y^\nu}}[l, j]
# ───────────────────

# %%
str(TriangleNlηuηd.AR()).replace('m_j','mj').replace(
    '\\mu_2','mu2').replace('m_{{\\eta}}','meta').replace(
    'm_{{N_l}}','mNl').replace(
    'conjugate({{Y^\\nu}}[l, i])','Ynucli').replace(
    '{{Y^\\nu}}[l, j]','Ynulj')
# Out:
# 'mj*(-mu2**2 + meta**2)*C_2(mNl, meta, meta)*Ynucli*Ynulj/(8*pi**2*v)'

# %% [markdown]
# ### Bubble $N_l \eta$

# %%
g,mW = symbols('g,m_W',positive=True)
vhll = lambda m:(I*g*m)/(2*mW)

# %%
vertex_hljlj = lfvhd.VertexHFF(vhll(lfvhd.mj))
BubbleNlη = lfvhd.BubbleFS(vertex_hljlj,vertex_ηuljNl,vertex_ηdliNl,[mNul,mη])
BubbleNlη
# Out:
# BubbleFS(VertexHFF(I*g*m_j/(2*m_W)), VertexSFF(0,I*{{Y^\nu}}[l, j]), VertexSFF(I*conjugate({{Y^\nu}}[l, i]),0),[m_{{N_l}}, m_{{\eta}}])

# %%
BubbleNlη.AL()#.subs(lfvhd.cambiosDivFin(mNul,mη,mη)).simplify()
# Out:
#         2                                         _______________
# g⋅mᵢ⋅m_j ⋅{{B_{1}}}__{(1)}(m_{{N_l}}, m_{{\eta}})⋅{{Y^\nu}}[l, i]⋅{{Y^\nu}}[l,
# ──────────────────────────────────────────────────────────────────────────────
#                                   2     ⎛  2      2⎞
#                               32⋅π ⋅m_W⋅⎝mᵢ  - m_j ⎠
#
#
#  j]
# ───

# %%
str(BubbleNlη.AL()).replace('m_i','mi').replace('m_j','mj').replace('m_W','mW').replace(
    '\\mu_2','mu2').replace('m_{{\\eta}}','meta').replace(
    'm_{{N_l}}','mNl').replace(
    'conjugate({{Y^\\nu}}[l, i])','Ynucli').replace(
    '{{Y^\\nu}}[l, j]','Ynulj').replace('{{B^{(1)}_{1}}}','B11')
# Out:
# 'g*mi*mj**2*B11(mNl, meta)*Ynucli*Ynulj/(32*pi**2*mW*(mi**2 - mj**2))'

# %%
BubbleNlη.AR()#.subs(lfvhd.cambiosDivFin(mNul,mη,mη)).simplify()
# Out:
#     2                                             _______________
# g⋅mᵢ ⋅m_j⋅{{B_{1}}}__{(1)}(m_{{N_l}}, m_{{\eta}})⋅{{Y^\nu}}[l, i]⋅{{Y^\nu}}[l,
# ──────────────────────────────────────────────────────────────────────────────
#                                   2     ⎛  2      2⎞
#                               32⋅π ⋅m_W⋅⎝mᵢ  - m_j ⎠
#
#
#  j]
# ───

# %%
str(BubbleNlη.AR()).replace('m_i','mi').replace('m_j','mj').replace('m_W','mW').replace(
    '\\mu_2','mu2').replace('m_{{\\eta}}','meta').replace(
    'm_{{N_l}}','mNl').replace(
    'conjugate({{Y^\\nu}}[l, i])','Ynucli').replace(
    '{{Y^\\nu}}[l, j]','Ynulj').replace('{{B^{(1)}_{1}}}','B11')
# Out:
# 'g*mi**2*mj*B11(mNl, meta)*Ynucli*Ynulj/(32*pi**2*mW*(mi**2 - mj**2))'

# %% [markdown]
# ### Bubble $\eta N_l$

# %%
vertex_hlili = lfvhd.VertexHFF(vhll(lfvhd.mi))
BubbleηNl = lfvhd.BubbleSF(vertex_hlili,vertex_ηuljNl,vertex_ηdliNl,[mNul,mη])
BubbleηNl
# Out:
# BubbleSF(VertexHFF(I*g*m_i/(2*m_W)), VertexSFF(0,I*{{Y^\nu}}[l, j]), VertexSFF(I*conjugate({{Y^\nu}}[l, i]),0),[m_{{N_l}}, m_{{\eta}}])

# %%
BubbleηNl.AL()#.subs(lfvhd.cambiosDivFin(mNul,mη,mη)).simplify()
# Out:
#          2                                         _______________
# -g⋅mᵢ⋅m_j ⋅{{B_{1}}}__{(2)}(m_{{N_l}}, m_{{\eta}})⋅{{Y^\nu}}[l, i]⋅{{Y^\nu}}[l
# ──────────────────────────────────────────────────────────────────────────────
#                                   2     ⎛    2      2⎞
#                               32⋅π ⋅m_W⋅⎝- mᵢ  + m_j ⎠
#
#
# , j]
# ─────

# %%
str(BubbleηNl.AL()).replace('m_i','mi').replace('m_j','mj').replace('m_W','mW').replace(
    '\\mu_2','mu2').replace('m_{{\\eta}}','meta').replace(
    'm_{{N_l}}','mNl').replace(
    'conjugate({{Y^\\nu}}[l, i])','Ynucli').replace(
    '{{Y^\\nu}}[l, j]','Ynulj').replace('{{B^{(2)}_{1}}}','B21')
# Out:
# '-g*mi*mj**2*B21(mNl, meta)*Ynucli*Ynulj/(32*pi**2*mW*(-mi**2 + mj**2))'

# %%
BubbleηNl.AR()#.subs(lfvhd.cambiosDivFin(mNul,mη,mη)).simplify()
# Out:
#      2                                             _______________
# -g⋅mᵢ ⋅m_j⋅{{B_{1}}}__{(2)}(m_{{N_l}}, m_{{\eta}})⋅{{Y^\nu}}[l, i]⋅{{Y^\nu}}[l
# ──────────────────────────────────────────────────────────────────────────────
#                                   2     ⎛    2      2⎞
#                               32⋅π ⋅m_W⋅⎝- mᵢ  + m_j ⎠
#
#
# , j]
# ─────

# %%
str(BubbleηNl.AR()).replace('m_i','mi').replace('m_j','mj').replace('m_W','mW').replace(
    '\\mu_2','mu2').replace('m_{{\\eta}}','meta').replace(
    'm_{{N_l}}','mNl').replace(
    'conjugate({{Y^\\nu}}[l, i])','Ynucli').replace(
    '{{Y^\\nu}}[l, j]','Ynulj').replace('{{B^{(2)}_{1}}}','B21')
# Out:
# '-g*mi**2*mj*B21(mNl, meta)*Ynucli*Ynulj/(32*pi**2*mW*(-mi**2 + mj**2))'

# %%
Diagrams = [TriangleNlηuηd, BubbleNlη,BubbleηNl]
print(Add(*[D.AL() for D in Diagrams]).expand().collect([mNul],evaluate=False).keys())
# Out:
# dict_keys([1])

# %% [markdown]
# # Numerical implemention

# %%
from OneLoopLFVHD.data import ml

# %%
mh = symbols('m_h',real=True)
valores ={mW:mpf('80.379'),mh:mpf('125.10'),g:(2*mpf('80.379'))/mpf('246'),v:mpf('246')}

# %%
cambios_hij = lambda ii, jj:{lfvhd.ma:valores[mh],lfvhd.mi:ml[ii],lfvhd.mj:ml[jj]}

Ylj, Ycli = symbols('Y_{lj}, {{Y_{li}^*}}')
YOne = {Yν[l,j]:Ylj,conjugate(Yν[l,i]):Ycli}

#from Unu_seesaw import diagonalizationMnu
#diagonalizationMnu1 = lambda m1,m6: diagonalizationMnu(m1,m2,m3,m6,m6,m6)

# %%
YOne
# Out:
# ⎧_______________                                        ⎫
# ⎨{{Y^\nu}}[l, i]: {{Y_{li}__*}}, {{Y^\nu}}[l, j]: Y_{lj}⎬
# ⎩                                                       ⎭

# %%
from OneLoopLFVHD.data import replaceBs, pave_functions

# %%
Dia1mpL = lambda i,j: lambdify([mNul,mη,μ2,Ylj, Ycli],replaceBs(TriangleNlηuηd.AL().subs(cambios_hij(i,j)).subs(valores).subs(YOne)),
                  modules=[pave_functions(valores[mh],i,j,lib='mpmath'),'mpmath'])
Dia1mpR = lambda i,j: lambdify([mNul,mη,μ2,Ylj, Ycli],replaceBs(TriangleNlηuηd.AR().subs(cambios_hij(i,j)).subs(valores).subs(YOne)),
                  modules=[pave_functions(valores[mh],i,j,lib='mpmath'),'mpmath'])


Dia2mpL = lambda i,j: lambdify([mNul,mη,Ylj, Ycli],replaceBs(BubbleNlη.AL().subs(cambios_hij(i,j)).subs(valores).subs(YOne)),
                  modules=[pave_functions(valores[mh],i,j,lib='mpmath'),'mpmath'])
Dia2mpR = lambda i,j: lambdify([mNul,mη,Ylj, Ycli],replaceBs(BubbleNlη.AR().subs(cambios_hij(i,j)).subs(valores).subs(YOne)),
                  modules=[pave_functions(valores[mh],i,j,lib='mpmath'),'mpmath'])


Dia3mpL = lambda i,j: lambdify([mNul,mη,Ylj, Ycli],replaceBs(BubbleηNl.AL().subs(cambios_hij(i,j)).subs(valores).subs(YOne)),
                  modules=[pave_functions(valores[mh],i,j,lib='mpmath'),'mpmath'])
Dia3mpR = lambda i,j: lambdify([mNul,mη,Ylj, Ycli],replaceBs(BubbleηNl.AR().subs(cambios_hij(i,j)).subs(valores).subs(YOne)),
                  modules=[pave_functions(valores[mh],i,j,lib='mpmath'),'mpmath'])

# %%
mp.nprint(Dia1mpL(1,3)(100,200,1,0.1,0.01))
# Out:
# (5.87685e-12 + 0.0j)

# %% [markdown]
# ## Form factors
#
# Then, the total Form factors $A_R$ y $A_L$, considering only heavy neutrinos contributions are given by the sum of the three predefined diagrams `TriangleNlηuηd`, `BubbleNlη` and `BubbleηNl`, as follows.

# %% [markdown]
# $$
# \Lambda_k =  \frac{M_{k} }{32 \pi^{2}}\left[\left(\frac{m_{R}^{2}}{M_{k}^{2}-m_{R}^{2}} \log \frac{m_{R}^{2}}{M_{k}^{2}}\right)-\left(\frac{m_{I}^{2}}{M_{k}^{2}-m_{I}^{2}} \log \frac{m_{I}^{2}}{M_{k}^{2}}\right)\right],
# $$

# %% [markdown]
# # Diagonal base to Y

# %%
from OneLoopLFVHD.neutrinos import UpmnsStandardParametrization, NuOscObservables
Nudata = NuOscObservables

# %%
m1 = mpf('3.01e-11')  #GeV 

#current values to Square mass differences
d21 = mpf(str(Nudata.squareDm21.central))*mpf('1e-18')# factor to convert eV^2 to GeV^2
d31 = mpf(str(Nudata.squareDm31.central))*mpf('1e-18')

m2 = sqrt(m1**2 + d21)
m3 = sqrt(m1**2 + d31)

# %%
# mp.nprint((m1,m2,m3))
# mp.nprint((m3-m1))
# mp.nprint((m2-m1))

# %%
Upmns = mp.matrix([
[ 0.821302075974486,  0.550502406897554, 0.149699699398496],
[-0.463050759961518,  0.489988544456971, 0.738576482160108],
[ 0.333236993293153, -0.675912957636513, 0.657339166640784]])

# %%
YMw = lambda L1,L2,L3: matrix([[sqrt(m1/L1),0,0],[0,sqrt(m2/L2),0],[0,0,sqrt(m3/L3)]])
YMw(m3,m3,m3)
# Out:
# [0.71695361666935117001291502716015198041863291149292364132589593407690160438171355                                                                                 0.0  0.0]
# [                                                                               0.0  0.73114642279319402115214757256462568945957124496486701009204396452364372077192737  0.0]
# [                                                                               0.0                                                                                 0.0  1.0]

# %% [markdown]
# Then in the physics basis we have a new yukawa couplings

# %%
YMf = lambda L1,L2,L3: YMw(L1,L2,L3)*Upmns
YMf(1,2,3)
# Out:
# [ 0.0000045059479257976352972292226427785250065601681214521899884715737416821966585754977  0.0000030202470577752417249780022514749950784426026047978486067333231119190466807871904  0.00000082130445024972436632848685847645145492184199733587582548574601401332312448646461]
# [-0.0000018319353828124812504008605421794313379489022149893632625263851630324622631800466  0.0000019385074583143093356922848580310044161229598349468643539906581392232124264151746   0.0000029219785552122118428931247870027684999215137962061890576409508418041214288234737]
# [  0.000001472260864436212295891349784259376369142897974094017554683873647097674954900257  -0.000002986223664604215359033489937087589569407338364185999463165286193559789050564188   0.0000029041635508185484777031183600043350729468038496194489913257338319171703465829368]

# %%
def Deltak(mR,mI,mk):
    return ((mk)/(32*pi**2)*(mR**2/(mR**2 - mk**2)*log(mR**2/mk**2) - 
                          mI**2/(mI**2 - mk**2)*log(mI**2/mk**2)))

# %%
mIexp2 = lambda mR,l5: mR**2 - 2*l5*valores[v]**2

Ymw2 = lambda M1,M2,M3,mR,l5:YMw(Deltak(mR,mp.sqrt(mIexp2(mR,l5)),M1),
                                Deltak(mR,mp.sqrt(mIexp2(mR,l5)),M2),
                                Deltak(mR,mp.sqrt(mIexp2(mR,l5)),M3))

Ynu = lambda M1,M2,M3,mR,l5:YMf(Deltak(mR,mp.sqrt(mIexp2(mR,l5)),M1),
                                Deltak(mR,mp.sqrt(mIexp2(mR,l5)),M2),
                                Deltak(mR,mp.sqrt(mIexp2(mR,l5)),M3))

# %%
mp.nprint(mp.chop(Ymw2(500,600,700,200,mpf('1e-10'))))
# Out:
# [0.528371       0.0       0.0]
# [     0.0  0.544045       0.0]
# [     0.0       0.0  0.753915]

# %%
mp.nprint(mp.chop(Ynu(500,600,700,200,mpf('1e-10'))))
# Out:
# [0.433953    0.29087  0.079097]
# [-0.25192   0.266576  0.401819]
# [0.251232  -0.509581  0.495578]

# %%
# Ynu1 = lambda M,mR,l5: Ynu(M,M,M,mR,l5)
# Ynu2 = lambda M,mR,l5: Ynu(M/mpf('3.0'),M/mpf('2.0'),M,mR,l5)

# %%
# Ylj, Ycli
def Dia1_tot(ii,jj,M1,M2,M3,meta,mR,l5,mu,quirality='L'):
    Yuk = Ynu(M1,M2,M3,mR,l5)
    if quirality=='L':
        F = Dia1mpL(ii,jj)
    elif quirality=='R':
        F = Dia1mpR(ii,jj)
    else:
        raise ValueError('quirality must be L or R')
    return (F(M1,meta,mu,Yuk[0,jj-1],conj(Yuk[0,ii-1])) + 
            F(M2,meta,mu,Yuk[1,jj-1],conj(Yuk[1,ii-1])) + 
            F(M3,meta,mu,Yuk[2,jj-1],conj(Yuk[2,ii-1])))

def Dia2_tot(ii,jj,M1,M2,M3,meta,mR,l5,quirality='L'):
    Yuk = Ynu(M1,M2,M3,mR,l5)
    if quirality=='L':
        F = Dia2mpL(ii,jj)
    elif quirality=='R':
        F = Dia2mpR(ii,jj)
    else:
        raise ValueError('quirality must be L or R')
    return (F(M1,meta,Yuk[0,jj-1],conj(Yuk[0,ii-1])) + 
            F(M2,meta,Yuk[1,jj-1],conj(Yuk[1,ii-1])) + 
            F(M3,meta,Yuk[2,jj-1],conj(Yuk[2,ii-1])))

def Dia3_tot(ii,jj,M1,M2,M3,meta,mR,l5,quirality='L'):
    Yuk = Ynu(M1,M2,M3,mR,l5)
    if quirality=='L':
        F = Dia3mpL(ii,jj)
    elif quirality=='R':
        F = Dia3mpR(ii,jj)
    else:
        raise ValueError('quirality must be L or R')
    return (F(M1,meta,Yuk[0,jj-1],conj(Yuk[0,ii-1])) + 
            F(M2,meta,Yuk[1,jj-1],conj(Yuk[1,ii-1])) + 
            F(M3,meta,Yuk[2,jj-1],conj(Yuk[2,ii-1])))

# %%
def Aijtot(ii,jj,M1,M2,M3,meta,mR,l5,mu,quirality):
    X = Dia1_tot(ii,jj,M1,M2,M3,meta,mR,l5,mu,quirality)
    Y = Dia2_tot(ii,jj,M1,M2,M3,meta,mR,l5,quirality)
    Z = Dia3_tot(ii,jj,M1,M2,M3,meta,mR,l5,quirality)
    return X + Y + Z

# %%
from Light_neutrino_contribution import AL23tot as AL23totnu
from Light_neutrino_contribution import AR23tot as AR23totnu

from Light_neutrino_contribution import AL32tot as AL32totnu
from Light_neutrino_contribution import AR32tot as AR32totnu

from Light_neutrino_contribution import AL13tot as AL13totnu
from Light_neutrino_contribution import AR13tot as AR13totnu

from Light_neutrino_contribution import AL31tot as AL31totnu
from Light_neutrino_contribution import AR31tot as AR31totnu

from Light_neutrino_contribution import AL12tot as AL12totnu
from Light_neutrino_contribution import AR12tot as AR12totnu

from Light_neutrino_contribution import AL21tot as AL21totnu
from Light_neutrino_contribution import AR21tot as AR21totnu

# %%
AL23nu = AL23totnu(m1)
AR23nu = AR23totnu(m1)

AL32nu = AL32totnu(m1)
AR32nu = AR32totnu(m1)

AL13nu = AL13totnu(m1)
AR13nu = AR13totnu(m1)

AL31nu = AL31totnu(m1)
AR31nu = AR31totnu(m1)

AL12nu = AL12totnu(m1)
AR12nu = AR12totnu(m1)

AL21nu = AL21totnu(m1)
AR21nu = AR21totnu(m1)

# %%
print(AR12nu,AR21nu)
print(AL12nu,AL21nu)
# Out:
# (6.3717320740071778411692165882979703e-22 + 0.0j) (-6.8048871943327569039304451820288491e-24 + 0.0j)
# (-6.8048871943327569039276425851001995e-24 + 0.0j) (6.3717320740071778411620419401606272e-22 + 0.0j)

# %%
print(AR13nu,AR31nu)
print(AL13nu,AL31nu)
# Out:
# (2.3182406554467757795014922082981347e-20 + 0.0j) (1.5492758878769589071382514452895357e-23 + 0.0j)
# (1.5492758878769589071376208609805895e-23 + 0.0j) (2.3182406554467757795026401520001096e-20 + 0.0j)

# %%
print(AR23nu,AR32nu)
print(AL23nu,AL32nu)
# Out:
# (3.6433981046579108314183581339593053e-21 + 0.0j) (2.1675517044791448619181777411282086e-22 + 0.0j)
# (2.1675517044791448619468763336775809e-22 + 0.0j) (3.6433981046579108314183581339593053e-21 + 0.0j)

# %%
#########################################################
def AL23tot_total(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(2,3,M1,M2,M3,meta,mR,l5,mu,'L') + AL23nu
def AR23tot_total(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(2,3,M1,M2,M3,meta,mR,l5,mu,'R') + AR23nu

def AL13tot_total(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,3,M1,M2,M3,meta,mR,l5,mu,'L') + AL13nu
def AR13tot_total(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,3,M1,M2,M3,meta,mR,l5,mu,'R') + AR13nu

def AL12tot_total(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,2,M1,M2,M3,meta,mR,l5,mu,'L') + AL12nu
def AR12tot_total(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,2,M1,M2,M3,meta,mR,l5,mu,'R') + AR12nu

# %%
def AL23tot(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(2,3,M1,M2,M3,meta,mR,l5,mu,'L') #+ AL23nu
def AR23tot(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(2,3,M1,M2,M3,meta,mR,l5,mu,'R') #+ AR23nu

def AL13tot(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,3,M1,M2,M3,meta,mR,l5,mu,'L') #+ AL13nu
def AR13tot(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,3,M1,M2,M3,meta,mR,l5,mu,'R') #+ AR13nu

def AL12tot(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,2,M1,M2,M3,meta,mR,l5,mu,'L') #+ AL12nu
def AR12tot(M1,M2,M3,meta,mR,l5,mu):
    return  Aijtot(1,2,M1,M2,M3,meta,mR,l5,mu,'R') #+ AR12nu

# %% [markdown]
# ## Form factor in this base

# %%
from OneLoopLFVHD import Γhlilj

# %% [markdown]
# ## Caso 1

# %%
def Γhl2l3_caso1(M,meta,mR,l5,mu):
    return Γhlilj(AL23tot(M,M,M,meta,mR,l5,mu),AR23tot(M,M,M,meta,mR,l5,mu),valores[mh],ml[2],ml[3])

def Γhl1l3_caso1(M,meta,mR,l5,mu):
    return Γhlilj(AL13tot(M,M,M,meta,mR,l5,mu),AR13tot(M,M,M,meta,mR,l5,mu),valores[mh],ml[1],ml[3])

def Γhl1l2_caso1(M,meta,mR,l5,mu):
    return Γhlilj(AL12tot(M,M,M,meta,mR,l5,mu),AR12tot(M,M,M,meta,mR,l5,mu),valores[mh],ml[1],ml[2])

def Γhl2l3_caso1_total(M,meta,mR,l5,mu):
    return Γhlilj(AL23tot_total(M,M,M,meta,mR,l5,mu),AR23tot_total(M,M,M,meta,mR,l5,mu),valores[mh],ml[2],ml[3])

def Γhl1l3_caso1_total(M,meta,mR,l5,mu):
    return Γhlilj(AL13tot_total(M,M,M,meta,mR,l5,mu),AR13tot_total(M,M,M,meta,mR,l5,mu),valores[mh],ml[1],ml[3])

def Γhl1l2_caso1_total(M,meta,mR,l5,mu):
    return Γhlilj(AL12tot_total(M,M,M,meta,mR,l5,mu),AR12tot_total(M,M,M,meta,mR,l5,mu),valores[mh],ml[1],ml[2])

# %% [markdown]
# ## Caso 2

# %%
def Γhl2l3_caso2(M,meta,mR,l5,mu):
    return Γhlilj(AL23tot(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),
                         AR23tot(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),valores[mh],ml[2],ml[3])

def Γhl1l3_caso2(M,meta,mR,l5,mu):
    return Γhlilj(AL13tot(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),
                         AR13tot(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),valores[mh],ml[1],ml[3])

def Γhl1l2_caso2(M,meta,mR,l5,mu):
    return Γhlilj(AL12tot(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),
                         AR12tot(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),valores[mh],ml[1],ml[2])

def Γhl2l3_caso2_total(M,meta,mR,l5,mu):
    return Γhlilj(AL23tot_total(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),
                         AR23tot_total(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),valores[mh],ml[2],ml[3])

def Γhl1l3_caso2_total(M,meta,mR,l5,mu):
    return Γhlilj(AL13tot_total(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),
                         AR13tot_total(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),valores[mh],ml[1],ml[3])

def Γhl1l2_caso2_total(M,meta,mR,l5,mu):
    return Γhlilj(AL12tot_total(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),
                         AR12tot_total(M/mpf('3.0'),M/mpf('2.0'),M,meta,mR,l5,mu),valores[mh],ml[1],ml[2])

# %% [markdown]
# ## Caso 3

# %%
def Γhl2l3_caso3(M1,M2,M3,meta,mR,l5,mu):
    return Γhlilj(AL23tot(M1,M2,M3,meta,mR,l5,mu),AR23tot(M1,M2,M3,meta,mR,l5,mu),valores[mh],ml[2],ml[3])

def Γhl1l3_caso3(M1,M2,M3,meta,mR,l5,mu):
    return Γhlilj(AL13tot(M1,M2,M3,meta,mR,l5,mu),AR13tot(M1,M2,M3,meta,mR,l5,mu),valores[mh],ml[1],ml[3])

def Γhl1l2_caso3(M1,M2,M3,meta,mR,l5,mu):
    return Γhlilj(AL12tot(M1,M2,M3,meta,mR,l5,mu),AR12tot(M1,M2,M3,meta,mR,l5,mu),valores[mh],ml[1],ml[2])

#################
def Γhl2l3_caso3_total(M1,M2,M3,meta,mR,l5,mu):
    return Γhlilj(AL23tot_total(M1,M2,M3,meta,mR,l5,mu),
    AR23tot_total(M1,M2,M3,meta,mR,l5,mu),valores[mh],ml[2],ml[3])

def Γhl1l3_caso3_total(M1,M2,M3,meta,mR,l5,mu):
    return Γhlilj(AL13tot_total(M1,M2,M3,meta,mR,l5,mu),
    AR13tot_total(M1,M2,M3,meta,mR,l5,mu),valores[mh],ml[1],ml[3])

def Γhl1l2_caso3_total(M1,M2,M3,meta,mR,l5,mu):
    return Γhlilj(AL12tot_total(M1,M2,M3,meta,mR,l5,mu),
    AR12tot_total(M1,M2,M3,meta,mR,l5,mu),valores[mh],ml[1],ml[2])

# %%
from multiprocessing import Pool
from time import time

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def speedup_array(f,array,procs=4): 
    pool = Pool(procs,maxtasksperchild=100).map(f, array)
    result = np.array(list(pool))
    return result

# %%
n = 200
expmp = linspace(2,6,n)#2,3
Mmp = np.array([mpf('10.0')**k for k in expmp])#np.logspace(-1,15,n)
#Mmp = linspace(100,1000,n)

# %%
# %%time
# YW23 = speedup_array(lambda M:Γhl2l3_caso1(M,300,600,mpf('1e-8'),1),Mmp)

# YW13 = speedup_array(lambda M:Γhl1l3_caso1(M,300,600,mpf('1e-8'),1),Mmp)

# YW12 = speedup_array(lambda M:Γhl1l2_caso1(M,300,600,mpf('1e-8'),1),Mmp)

# %%
# %%time
meta = mpf('800')
mR=mpf('805')
l5=mpf('1e-10')
mu=mpf('1.0')
YW23 = np.array([Γhl2l3_caso1(M,meta,mR,l5,mu) for M in Mmp])#M,meta,mR
YW13 = np.array([Γhl1l3_caso1(M,meta,mR,l5,mu) for M in Mmp])
YW12 = np.array([Γhl1l2_caso1(M,meta,mR,l5,mu) for M in Mmp])
Wtot = YW23 + YW13 + YW12 + 0.0032
# Out:
# CPU times: user 1min 26s, sys: 70 ms, total: 1min 26s
# Wall time: 1min 26s

# %%
# %%time
meta = mpf('800')
mR=mpf('805')
l5=mpf('1e-10')
mu=mpf('1.0')
YW23_full = np.array([Γhl2l3_caso1_total(M,meta,mR,l5,mu) for M in Mmp])#M,meta,mR
YW13_full = np.array([Γhl1l3_caso1_total(M,meta,mR,l5,mu) for M in Mmp])
YW12_full = np.array([Γhl1l2_caso1_total(M,meta,mR,l5,mu) for M in Mmp])
Wtot_full = YW23_full + YW13_full + YW12_full + 0.0032
# Out:
# CPU times: user 1min 26s, sys: 12 ms, total: 1min 26s
# Wall time: 1min 26s

# %%
with plt.style.context('seaborn-deep'):
    plt.figure(figsize=(12,8))
    plt.loglog(Mmp,(YW23 #+ YW32
                             )/Wtot,label=r'Br($h \to \mu \tau$)', linewidth=2.5)
    plt.loglog(Mmp,(YW13 #+ YW31
                             )/Wtot,label=r'Br($h \to e \tau$)', linewidth=2.5)
    plt.loglog(Mmp,(YW12 #+ YW21
                             )/Wtot,label=r'Br($h \to e \mu$)', linewidth=2.5)

    plt.xlim(1e2,1e6)
    plt.yticks(fontsize=20)
    plt.xticks(fontsize=20)
    # plt.title(r'$M_1 = M_3/3$, $M_2 = M_3/2$, $m_{\eta} = 300$ GeV, $m_{R} = 305$ GeV, $\mu=1$ and $\lambda_5 = 1e-10$'
    #           , fontsize=15)
    #plt.title(r'Caso 1', fontsize=15)
    plt.xlabel('$M_1$ [GeV]',fontsize=20)
    plt.ylabel(r'$\mathcal{BR}(h\to l_a l_b)$',fontsize=20)
    plt.legend(fontsize=18,frameon=False)
    #plt.savefig('caso1.png',dpi=200)#_with_nu

# %% [markdown]
# # Nuevo

# %%
# %%time
meta = mpf('800')
mR=mpf('805')
l5=mpf('1e-10')
mu=mpf('1.0')
YW23 = np.array([Γhl2l3_caso3(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW13 = np.array([Γhl1l3_caso3(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW12 = np.array([Γhl1l2_caso3(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])

Wtot = YW23 + YW13 + YW12 + 0.0032

YW23_full = np.array([Γhl2l3_caso3_total(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW13_full = np.array([Γhl1l3_caso3_total(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW12_full = np.array([Γhl1l2_caso3_total(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])

Wtot_full = YW23_full + YW13_full + YW12_full + 0.0032
# Out:
# CPU times: user 2min 10s, sys: 1.1 s, total: 2min 11s
# Wall time: 2min 21s

# %%
with plt.style.context('seaborn-deep'):
    plt.figure(figsize=(12,8))
#     plt.loglog(Mmp,(YW23 #+ YW32
#             )/Wtot,'b--',label=r'$\mathcal{BR}(h \to \mu \tau)_{{Inert}}$', linewidth=2.5)
                             ##################
    plt.semilogy(Mmp,(YW23_full #+ YW32
            )/Wtot_full,'b',label=r'$\mathcal{BR}(h \to \mu \tau)$', linewidth=2.5)
                             ##################

                             
#     plt.loglog(Mmp,(YW13 #+ YW31
#             )/Wtot,'g--',label=r'$\mathcal{BR}(h \to e \tau)_{{Inert}}$', linewidth=2.5)
                             #################
    plt.semilogy(Mmp,(YW13_full #+ YW31
            )/Wtot_full,'g',label=r'$\mathcal{BR}(h \to e \tau)$', linewidth=2.5)
                             #################################


#     plt.loglog(Mmp,(YW12 #+ YW21
#             )/Wtot,'r--',label=r'$\mathcal{BR}(h \to e \mu)_{{Inert}}$', linewidth=2.5)
    plt.semilogy(Mmp,(YW12_full #+ YW21
            )/Wtot_full,'r',label=r'$\mathcal{BR}(h \to e \mu)$', linewidth=2.5)

    #plt.hlines(1,100,1000,linestyles='-.',label=r'$1.7\times 10^{-2}$')
    #plt.hlines(1e-10,100,1000,linestyles='--',color='b',label=r'$1\times 10^{-19}$')

    plt.xlim(1e2,1e3)
    plt.yticks(fontsize=20)
    plt.xticks(fontsize=20)
    #plt.title('Case 2', fontsize=15)
    #plt.title(r'$M_2 = 10^4$ GeV, $M_3 = 10^5$ GeV, $m_{\eta} = 300$ GeV, $m_{R} = 305$ GeV, $\mu=1$ and $\lambda_5 = 1e-10$'
    #          , fontsize=15)
#     plt.vlines(800**2 - 125.1**2,1e-40,1e-30)

    
    plt.xlabel('$M_1$ [GeV]',fontsize=20)
    plt.ylabel(r'$\mathcal{BR}(h\to l_a l_b)$',fontsize=20)
    plt.legend(fontsize=16,frameon=False)
    plt.savefig('BRs_scoto_comparacion800-10.png',dpi=200)# _with_nu

# %%
# %%time

n = 100
expmp = linspace(2,3,n)#2,3
Mmp = np.array([mpf('10.0')**k for k in expmp])

meta = mpf('200')
mR=mpf('205')
l5=mpf('1e-10')
mu=mpf('1.0')
YW23v2 = np.array([Γhl2l3_caso3(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW13v2 = np.array([Γhl1l3_caso3(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW12v2 = np.array([Γhl1l2_caso3(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])

Wtotv2 = YW23 + YW13 + YW12 + 0.0032

YW23_fullv2 = np.array([Γhl2l3_caso3_total(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW13_fullv2 = np.array([Γhl1l3_caso3_total(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])
YW12_fullv2 = np.array([Γhl1l2_caso3_total(M,mpf('10.0')**4,mpf('10.0')**5,meta,mR,l5,mu) for M in Mmp])

Wtot_fullv2 = YW23_fullv2 + YW13_fullv2 + YW12_fullv2 + 0.0032
# Out:
# CPU times: user 2min 36s, sys: 1.72 s, total: 2min 38s
# Wall time: 3min 2s

# %%
with plt.style.context('seaborn-deep'):
    plt.figure(figsize=(12,8))
    plt.semilogy(Mmp,(YW23_full #+ YW32
            )/Wtot_full,'b',label=r'$\mathcal{BR}(h \to \mu \tau)_{800}$', linewidth=2.5)
                             ##################
    plt.semilogy(Mmp,(YW23_fullv2 #+ YW32
            )/Wtot_fullv2,'--b',label=r'$\mathcal{BR}(h \to \mu \tau)_{200}$', linewidth=2.5)
                             ##################

                             
    plt.semilogy(Mmp,(YW13_full #+ YW31
            )/Wtot_full,'g',label=r'$\mathcal{BR}(h \to e \tau)_{800}$', linewidth=2.5)
                             #################
    plt.semilogy(Mmp,(YW13_fullv2 #+ YW31
            )/Wtot_fullv2,'--g',label=r'$\mathcal{BR}(h \to e \tau)_{200}$', linewidth=2.5)
                             #################################


    plt.semilogy(Mmp,(YW12_full #+ YW21
            )/Wtot_full,'r',label=r'$\mathcal{BR}(h \to e \mu)_{800}$', linewidth=2.5)
    plt.semilogy(Mmp,(YW12_fullv2 #+ YW21
            )/Wtot_fullv2,'--r',label=r'$\mathcal{BR}(h \to e \mu)_{200}$', linewidth=2.5)


    #plt.hlines(1,100,1000,linestyles='-.',label=r'$1.7\times 10^{-2}$')
    #plt.hlines(1e-10,100,1000,linestyles='--',color='b',label=r'$1\times 10^{-19}$')

    plt.xlim(1e2,1e3)
    plt.yticks(fontsize=20)
    plt.xticks(fontsize=20)
    #plt.title('Case 2', fontsize=15)
    #plt.title(r'$M_2 = 10^4$ GeV, $M_3 = 10^5$ GeV, $m_{\eta} = 300$ GeV, $m_{R} = 305$ GeV, $\mu=1$ and $\lambda_5 = 1e-10$'
    #          , fontsize=15)
    
    plt.xlabel('$M_1$ [GeV]',fontsize=22)
    plt.ylabel(r'$\mathcal{BR}(h\to l_a l_b)$',fontsize=22)
    plt.legend(ncol=2,fontsize=18,frameon=False)
    plt.savefig('BRs_scoto_comparacion200-10_log.png',dpi=200)

# %%
def Wtothlilj(M1,M2,M3,meta,mR,l5,mu):
    return (Γhl2l3_caso3(M1,M2,M3,meta,mR,l5,mu) + 
           Γhl1l3_caso3(M1,M2,M3,meta,mR,l5,mu) + 
           Γhl1l2_caso3(M1,M2,M3,meta,mR,l5,mu) + 0.0032) 

##############################################################################
def BRhl2l3(M1,M2,M3,meta,mR,l5,mu):
    return Γhl2l3_caso3(M1,M2,M3,meta,mR,l5,mu)/Wtothlilj(M1,M2,M3,meta,mR,l5,mu)
def BRhl1l3(M1,M2,M3,meta,mR,l5,mu):
    return Γhl1l3_caso3(M1,M2,M3,meta,mR,l5,mu)/Wtothlilj(M1,M2,M3,meta,mR,l5,mu)
def BRhl1l2(M1,M2,M3,meta,mR,l5,mu):
    return Γhl1l2_caso3(M1,M2,M3,meta,mR,l5,mu)/Wtothlilj(M1,M2,M3,meta,mR,l5,mu)

# %%
B = matrix([[0.0,1.0,mpf('0.1783')],
            [0.0,0.0,mpf('0.1741')],
            [0.0,0.0,0.0]])

#Definition of BR(lj -> li gamma)
Fsym = lambda x:(1-6*x + 3*x**2 + 2*x**3 - 6*x**2*ln(x))/(6*(1-x)**4)
def Bljligamma(M1,M2,M3,meta,mR,l5,ii,jj):
    GF = mpf('1.16637e-5')
    αem = mpf('1.0')/mpf('137.0')
    Ms = [M1,M2,M3]
    Yuk = Ynu(M1,M2,M3,mR,l5) 
    #print(Ynu[ii-1,0]*conj(Ynu[jj-1,0]))
    sumak = sum(Fsym(Ms[k]**2/meta**2)*Yuk[ii-1,k]*conj(Yuk[jj-1,k]) for k in range(len(Ms)))
    return ((3*αem*B[ii-1,jj-1])/(64*pi*GF**2*meta**4))*abs(sumak)**2

# %%
Bmue = lambda M1,M2,M3,meta,mR,l5:Bljligamma(M1,M2,M3,meta,mR,l5,1,2)
Btaue = lambda M1,M2,M3,meta,mR,l5:Bljligamma(M1,M2,M3,meta,mR,l5,1,3)
Btaumu = lambda M1,M2,M3,meta,mR,l5:Bljligamma(M1,M2,M3,meta,mR,l5,2,3)

# %%
import pandas as pd
#import numpy as np
#import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
path = '/home/moiseszm/Dropbox/TESIS MOISES DOCTORADO/Doctorado/Programas/python/build-lagrangian/Scotogenic Model/Model fase 3/ScanDataNew'
files = os.listdir(path)

dfs = []
for f in files:
    df = pd.read_csv(path + '/'+ f,sep='\t',
                     float_precision='round_trip'#importante para mantener la precision de los números en los archivos.
                    )
    #addcols(df)
    dfs.append(df)

# %%
space = pd.concat(dfs, ignore_index=True, sort=False)
space
# Out:
#                M1            M2            M3           mu22   l2  \
# 0      208.026808    101.313844  43460.226889 -140487.972122  0.1
# 1      111.409728  18781.542692  16947.028620 -215537.073293  0.1
# 2      235.100858  32012.911026  27994.868434  -51776.454766  0.1
# 3      123.932395  48038.249801  40902.781923 -227405.574235  0.1
# 4      612.735274  45387.200988  14667.394273  123181.330880  0.1
# ...           ...           ...           ...            ...  ...
# 20920  156.120108  45692.238431  48139.568515  -33143.888462  0.1
# 20921  173.629549  34753.043130   8816.675020 -103638.270255  0.1
# 20922  161.542103  13649.596522  49488.284169 -274636.412535  0.1
# 20923  259.154616  16490.234838  19232.197630 -184974.591529  0.1
# 20924  216.411322  26536.107812  44099.567918 -236734.161783  0.1
#
#                  l5        meta          mR
# 0      1.597007e-10  214.552830  218.482739
# 1      2.779692e-10  111.410872  121.380640
# 2      2.413651e-10  235.124940  238.332709
# 3      4.976137e-10  123.934452  124.802528
# 4      1.508149e-10  612.781017  615.942177
# ...             ...         ...         ...
# 20920  4.218452e-10  156.135467  161.672957
# 20921  2.647706e-10  173.631616  181.255342
# 20922  2.659494e-10  161.547592  161.881588
# 20923  1.634569e-10  259.186510  270.074298
# 20924  2.597603e-10  216.427109  228.593995
#
# [20925 rows x 8 columns]

# %%
M1 = space['M1']
M2 = space['M2']
M3 = space['M3']
meta = space['meta']
mR = space['mR']
l5 = space['l5']
mu22 = space['mu22']

# %%
from lfv_ljligamma_constraintsYks import Bmuenp #as Bmue
from lfv_ljligamma_constraintsYks import Btauenp #as Btaue
from lfv_ljligamma_constraintsYks import Btaumunp #as Btaumu

Btaumu_scan = lambda M1,M2,M3,meta,mR,l5: Btaumunp(M1,M2,M3,l5,mR,meta,m1)
Btaue_scan = lambda M1,M2,M3,meta,mR,l5: Btauenp(M1,M2,M3,l5,mR,meta,m1,0)
Bmue_scan = lambda M1,M2,M3,meta,mR,l5: Bmuenp(M1,M2,M3,l5,mR,meta,m1,0)

m1 = 3.01e-11

# %%
plt.semilogy(np.nan_to_num(np.array([
    Btaumunp(M1[n],M2[n],M3[n],
    l5[n],mR[n],meta[n],m1)
                      for n in range(10000)
])),'.')

# %%
space['BRtaumu'] = np.nan_to_num(
    np.array(
        [Btaumunp(M1[n],M2[n],M3[n],l5[n],mR[n],meta[n],m1)
                      for n in range(len(M1))
                      ]
                      )
                      )
#space.apply(Btaumu_df , axis=1)

space['BRtaue'] = np.nan_to_num(
    np.array(
        [Btauenp(M1[n],M2[n],M3[n],l5[n],mR[n],meta[n],m1,0.0)
                      for n in range(len(M1))
                      ]
                      )
                      )
#space.apply( Btaue_df, axis=1)
space['BRmue'] = np.nan_to_num(
    np.array(
        [Bmuenp(M1[n],M2[n],M3[n],l5[n],mR[n],meta[n],m1,0.0)
                      for n in range(len(M1))
                      ]
                      )
                      )

#space.apply( Bmue_df, axis=1)

# %%
space['BRtaumu']
# Out:
# 0        3.177185e-07
# 1        5.563391e-15
# 2        3.463284e-15
# 3        2.857341e-16
# 4        5.793749e-13
#              ...
# 20920    5.780729e-17
# 20921    4.607550e-13
# 20922    5.565436e-14
# 20923    3.855685e-16
# 20924    2.004436e-15
# Name: BRtaumu, Length: 20925, dtype: float64

# %%
cond1 = (M2>M1)&(M3>M1)&(mu22>0.0)
cond2 = space['BRmue'][cond1]<5.7e-13
cond2
plt.loglog(space['BRmue'][cond1][cond2],space['BRtaue'][cond1][cond2],'o')

# %%
M1 = space['M1'][cond1][cond2]
M2 = space['M2'][cond1][cond2]
M3 = space['M3'][cond1][cond2]
meta = space['meta'][cond1][cond2]
mR = space['mR'][cond1][cond2]
l5 = space['l5'][cond1][cond2]
mu22 = space['mu22'][cond1][cond2]

space = pd.DataFrame({'M1':M1,'M2':M2,'M3':M3,'meta':meta,'mR':mR,'l5':l5,'mu22':mu22})

# %%
M1 = space['M1']
M2 = space['M2']
M3 = space['M3']
meta = space['meta']
mR = space['mR']
l5 = space['l5']
mu22 = space['mu22']

# %%
M1.index
# Out:
# Int64Index([    4,     7,     8,     9,    10,    12,    13,    16,    17,
#                18,
#             ...
#             20904, 20906, 20907, 20908, 20911, 20912, 20914, 20915, 20916,
#             20918],
#            dtype='int64', length=11651)

# %%
space['BRtaumu'] = np.nan_to_num(
    np.array(
        [Btaumunp(M1[n],M2[n],M3[n],l5[n],mR[n],meta[n],m1)
                      for n in M1.index
                      ]
                      )
                      )
#space.apply(Btaumu_df , axis=1)

space['BRtaue'] = np.nan_to_num(
    np.array(
        [Btauenp(M1[n],M2[n],M3[n],l5[n],mR[n],meta[n],m1,0.0)
                      for n in M1.index
                      ]
                      )
                      )
#space.apply( Btaue_df, axis=1)
space['BRmue'] = np.nan_to_num(
    np.array(
        [Bmuenp(M1[n],M2[n],M3[n],l5[n],mR[n],meta[n],m1,0.0)
                      for n in M1.index
                      ]
                      )
                      )


#space.apply( Bmue_df, axis=1)

# %%
def BRhmutau_df(x):
    if x['M2']>x['M1'] and x['M3']>x['M1'] and x['mu22']>0.0:
        return BRhl2l3(mpf(str(x['M1'])),mpf(str(x['M2'])),
                      mpf(str(x['M3'])),mpf(str(x['meta'])),
                      mpf(str(x['mR'])),mpf(str(x['l5'])),mp.sqrt(mpf(str(x['mu22']))))

# %%
space['BRhmutau'] = space.apply(BRhmutau_df, axis=1)

# %%
def BRhetau_df(x):
    if x['M2']>x['M1'] and x['M3']>x['M1'] and x['mu22']>0.0:
        return BRhl1l3(mpf(str(x['M1'])),mpf(str(x['M2'])),
                      mpf(str(x['M3'])),mpf(str(x['meta'])),
                      mpf(str(x['mR'])),mpf(str(x['l5'])),np.sqrt(x['l5']))

# %%
space['BRhetau'] = space.apply(BRhetau_df, axis=1)

# %%
plt.figure(figsize=(10,8))
plt.semilogx(space['BRtaue'], space['BRhetau'],'o',alpha=0.5)
plt.xlabel(r'Br($\tau \rightarrow e \gamma$)',fontsize=20)
plt.ylabel(r'Br($h \rightarrow e \tau$)',fontsize=20)
plt.yticks([7.013e-9,7.0138e-9])
#plt.ylim([6.97e-9,7.01e-9])
plt.tick_params(labelsize=20)
plt.savefig('BtauevsBhetau_with_nu.png',dpi=200)

# %%
def BRhemu_df(x):
    if x['M2']>x['M1'] and x['M3']>x['M1'] and x['mu22']>0.0:
        return BRhl1l2(mpf(str(x['M1'])),mpf(str(x['M2'])),
                      mpf(str(x['M3'])),mpf(str(x['meta'])),
                      mpf(str(x['mR'])),mpf(str(x['l5'])),np.sqrt(x['l5']))

# %%
space['BRhemu'] = space.apply(BRhemu_df, axis=1)

# %%
plt.figure(figsize=(10,8))
plt.loglog(space['BRmue'], space['BRhemu'] ,'o',alpha=0.5)#space['BRhemu']
plt.xlabel(r'Br($\mu \rightarrow e \gamma$)',fontsize=20)
plt.ylabel(r'Br($h \rightarrow e \mu$)',fontsize=20)
plt.tick_params(labelsize=20)
plt.savefig('BmuevsBhemu_with_nu.png',dpi=200)

# %%
cond = space['BRmue']<5.7e-13

# %%
cond
# Out:
# 4        True
# 7        True
# 8        True
# 9        True
# 10       True
#          ...
# 20912    True
# 20914    True
# 20915    True
# 20916    True
# 20918    True
# Name: BRmue, Length: 11651, dtype: bool

# %%
plt.figure(figsize=(12,9))
plt.loglog(space['BRtaumu'][cond], space['BRhmutau'][cond],'o',alpha=0.5,label=r'$\mathcal{BR}(h \to \mu \tau)$ vs $\mathcal{BR}(\tau \to \mu \gamma)$')
plt.loglog(space['BRtaue'][cond], space['BRhetau'][cond],'o',alpha=0.5,label=r'$\mathcal{BR}(h \to e \tau)$ vs $\mathcal{BR}(\tau \to e \gamma)$')
plt.loglog(space['BRmue'][cond], space['BRhemu'][cond] ,'o',alpha=0.5,label=r'$\mathcal{BR}(h \to e \mu)$ vs $\mathcal{BR}(\mu \to e \gamma)$')
plt.xlabel(r'$\mathcal{BR}(l_b \rightarrow l_a \gamma)$',fontsize=22)
plt.ylabel(r'$\mathcal{BR}(h \rightarrow l_a l_b)$',fontsize=22)
plt.tick_params(labelsize=20)
#plt.yticks([1e-36,1e-34,1e-32,1e-30,1e-28,1e-26,1e-24,1e-22,1e-20,1e-18,1e-16,1e-14,1e-11,1e-10,1e-8])
plt.legend(fontsize=20)
#plt.vlines(4.4e-8,1e-17,1e-8)
plt.xlim(1e-21,1e-11)
#plt.grid(True)
plt.savefig('BlblavsBhlalb_with_nu.png',dpi=200)

# %%
space.to_csv('allowed_space_with_Brs.txt',sep='\t',index=False)

# %%
space.keys()
# Out:
# Index(['M1', 'M2', 'M3', 'meta', 'mR', 'l5', 'mu22', 'BRtaumu', 'BRtaue',
#        'BRmue', 'BRhmutau', 'BRhetau', 'BRhemu'],
#       dtype='object')

# %%
x = np.linspace(90,810,100)
plt.figure(figsize=(10,8))
plt.scatter(M1[mu22>0],meta[mu22>0],alpha=0.5,label='Allowed points')
plt.plot(x,x,'r',label=r'$M_1 = m_\eta$')
plt.xlabel(r'$M_1$ [GeV]',fontsize=20)
plt.ylabel(r'$m_{\eta}$ [GeV]',fontsize=20)
plt.legend(fontsize=18)
plt.tick_params(labelsize=20)
#plt.savefig('M1vsmeta.png',dpi=200)

# %%
plt.figure(figsize=(10,8))
plt.scatter(M1[mu22>0],mR[mu22>0],alpha=0.5,label='Allowed points')
plt.plot(x,x,'r',label=r'$M_1 = m_R$')
plt.xlabel(r'$M_1$ [GeV]',fontsize=20)
plt.ylabel(r'$m_{R}$ [GeV]',fontsize=20)
plt.legend(fontsize=18)
plt.tick_params(labelsize=20)
#plt.savefig('M1vsmR.png',dpi=200)

# %%
plt.figure(figsize=(10,8))
plt.scatter(mR[mu22>0],meta[mu22>0],alpha=0.5,label='Allowed points')
plt.plot(x,x,'r',label=r'$m_R = m_{\eta}$')
plt.xlabel(r'$m_R$ [GeV]',fontsize=20)
plt.ylabel(r'$m_{\eta}$ [GeV]',fontsize=20)
plt.legend(fontsize=18)
plt.tick_params(labelsize=20)
#plt.savefig('mRvsmeta.png',dpi=200)

# %%
plt.figure(figsize=(10,8))
plt.scatter(M1[M2>10000][mu22>0],l5[M2>10000][mu22>0],alpha=0.5,label='Allowed points')
#plt.plot(x,x,'r',label=r'$M_1 = m_R$')
plt.xlabel(r'$M_1$ [GeV]',fontsize=20)
plt.ylabel(r'$\lambda_5$',fontsize=20)
plt.legend(fontsize=18)
plt.tick_params(labelsize=20)
#plt.savefig('M1vsl5.png',dpi=200)

# %%
plt.figure(figsize=(10,8))
plt.scatter(M1[M2>10000][mu22>0],M2[M2>10000][mu22>0],alpha=0.5,label='$M_2$')
plt.scatter(M1[M3>10000][mu22>0],M3[M3>10000][mu22>0],alpha=0.5,label='$M_3$')
#plt.plot(x,x,'r',label=r'$M_1 = m_R$')
plt.xlabel(r'$M_1$ [GeV]',fontsize=20)
plt.ylabel(r'$M_k$ [GeV]',fontsize=20)
plt.legend(fontsize=18)
plt.tick_params(labelsize=20)
#plt.savefig('M1vsM23.png',dpi=200)

# %%
l3 = 2/246**2*(meta**2 - mu22)
mI = np.sqrt(mR**2 - 2*l5)#*246**2
l4 = (mR**2 + mI**2 - 4*mu22)/(2*246**2)-l3
plt.figure(figsize=(10,8))
plt.scatter(l3[M2>10000][mu22>0],l4[M2>10000][mu22>0],alpha=0.5,label='Allowed points')
#plt.plot(x,x,'r',label=r'$M_1 = m_R$')
plt.xlabel(r'$\lambda_3$',fontsize=20)
plt.ylabel(r'$\lambda_4$',fontsize=20)
plt.legend(fontsize=18)
plt.tick_params(labelsize=20)
plt.savefig('l3vsl4.png',dpi=200)

# %%
l4.min()
# Out:
# -10.788138616895152

# %%
### h-> mu tau

ALNmutaunp = lambdify([M1,M2,M3,mR,mη,μ2,λ5],ALNmutau,modules=['numpy',{'polylog':sci_polylog}])
ARNmutaunp = lambdify([M1,M2,M3,mR,mη,μ2,λ5],ARNmutau,modules=['numpy',{'polylog':sci_polylog}])

# %%
import dill
dill.settings['recurse'] = True

# %%
## h->tau mu
dill.dump(ALNtaumunp , open("ALNtaumu.txt", "wb"))
dill.dump(ARNtaumunp , open("ARNtaumu.txt", "wb"))

# %%
## h-> mu tau
dill.dump(ALNmutaunp , open("ALNmutau.txt", "wb"))
dill.dump(ARNmutaunp , open("ARNmutau.txt", "wb"))
