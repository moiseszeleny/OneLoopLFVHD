# %%
import sys
sys.path.append('/home/moises/Escritorio/ProyectoLFVHD')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # LFVHD Scotogenic model
# ## Diagrams
# ![dia_htaumuPar.png](attachment:dia_htaumuPar.png)

# %% [markdown]
# ![BubleScoto.png](attachment:BubleScoto.png)

# %% [markdown]
# Our conventions to this Feynman diagrams are shown below

# %% [markdown]
# ![ConvencionesDiagramas.png](attachment:7d672b13-0a69-4754-83dd-dd772334e647.png)

# %% [markdown]
# ## Couplings

# %% [markdown]
# ![couplingsscoto.png](attachment:couplings_scoto.png)

# %%
from LFVHDFeynG import *
from sympy import *
init_printing()
# Out:
# All right LFVHDFeynG

# %% [markdown]
# ## Light neutrino contribution
#
# ### FSS contribution
#
# We have two posibles diagrams with this form the first one is $\nu_l H^{+} H^{-}$, then we need the next couplings
# $h H^{+} H^{-} \rightarrow -i \lambda_1 v$, $H^{-}\mu^{+} \nu_{l} \rightarrow i \frac{\sqrt{2}}{v} m_2 U^{\nu *}_{l2} P_{L}$ and
# $H^{+}\tau^{-} \nu_{l} \rightarrow i \frac{\sqrt{2}}{v} m_1 U^{\nu}_{l3} P_{R}$ assuming summation on repeated indexes

# %%
triangulo = {'a':0}

# %%
g2,v = symbols(r'g2,v',real=True)
λ1 = mh**2/v**2
Uν = IndexedBase(r'{{U^\nu}}')
l,b = symbols('l,b',integer=True)
hHuHd = VertexSSS(-I*λ1*v)
Hdμνl = VertexSFF(0,I*(sqrt(2)/v)*m2*conjugate(Uν[l,2]))
Huτνl = VertexSFF(I*(sqrt(2)/v)*m1*Uν[l,3],0)

# %%
mnul,mH,mW = symbols(r'm_{{\nu_l}},m_{{H^{\pm}}},m_W',real=True)
Masas1 = [mnul,mW,mW]
νlHuHd = TriangleFSS(hHuHd,Hdμνl,Huτνl,Masas1)
triangulo['νlHuHd'] = νlHuHd
νlHuHd.ML()#.subs(cambiosDivFin(*νlHuHd.masas)).simplify()#.subs(
    #cambios_aprox((*νlHuHd.masas)))#.subs(cambiosMs).subs(cambiomnuHW).subs(masas_valor).n()
νlHuHd.MR()
# Out:
#     2      2                           _______________
# ⅈ⋅m₁ ⋅m₂⋅mₕ ⋅C₁(m_{{\nu_l}}, m_W, m_W)⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────────────────────────────────────────────────────
#                                   2  3
#                                8⋅π ⋅v
#         2   2                           _______________
# -ⅈ⋅m₁⋅m₂ ⋅mₕ ⋅C₂(m_{{\nu_l}}, m_W, m_W)⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────────────────────────────────────────────────────
#                                    2  3
#                                 8⋅π ⋅v

# %%
MLs = [0]*10
MRs = [0]*10

# %%
MLs[0] = νlHuHd.ML_GIM()
MLs[0]
MRs[0] = νlHuHd.MR_GIM()
MRs[0]
# Out:
#     2    ⎛⎛   2              2⎞
# ⅈ⋅m₁ ⋅m₂⋅⎝⎝m_W  - m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W, m_W) + {{b_0}}__{(1)}(m_{
# ──────────────────────────────────────────────────────────────────────────────
#                                                               2  3
#                                                            8⋅π ⋅v
#
#               ⎞ _______________
# {\nu_l}}, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ───────────────────────────────────────────────
#        2 ⎛⎛   2              2⎞
# ⅈ⋅m₁⋅m₂ ⋅⎝⎝m_W  - m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W, m_W) + {{b_0}}__{(2)}(m_{
# ──────────────────────────────────────────────────────────────────────────────
#                                                               2  3
#                                                            8⋅π ⋅v
#
#               ⎞ _______________
# {\nu_l}}, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ───────────────────────────────────────────────

# %% [markdown]
# ## FSV contribution
# In this case we only have one contribution, $\nu_{l} H^{+} W^{-}$, the we need to consider the next couplings
# $h H^{+} W^{-} \rightarrow \frac{i}{2}g_2 (-p^{H^{+}}_\mu + p^{h}_\mu)$, $W^{-} \mu^{+} \nu_{l} \rightarrow -i \frac{g_2}{\sqrt{2}}U^{\nu *}_{l2} \gamma_\mu P_L$ and $ H^{+} \tau^{-} \nu_l \rightarrow i Y^{e*}_{3,b}U^{\nu}_{lb} P_R$

# %%
hHuWd = VertexVSS(I*g2/2)
Wdμνl = VertexVFF(0,-I*(g2/sqrt(2))*conjugate(Uν[l,2]))
#Huτνl

# %%
mW = symbols('m_W',real=True)
Masas3 = [mnul,mW,mW]
νlHuWd = TriangleFSV(hHuWd,Wdμνl,Huτνl,Masas3)
triangulo['νlHuWd'] = νlHuWd
νlHuWd.ML().factor()
# Out:
#      2   2
# -ⅈ⋅g₂ ⋅m₁ ⋅m_{{\nu_l}}⋅(2⋅C₀(m_{{\nu_l}}, m_W, m_W) - C₁(m_{{\nu_l}}, m_W, m_W
# ──────────────────────────────────────────────────────────────────────────────
#                                                          2
#                                                      32⋅π ⋅v
#
#    _______________
# ))⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ───────────────────────────────────

# %%
#νlHuWd.ML_GIM()
MLs[1] = νlHuWd.ML_GIM()
MLs[1]
#.subs(cambiosDivFin).simplify().subs(cambios_aprox).subs(cambiosMs).subs(cambim_2M_0(omnuHW).subs(masas_valor).n()
# Out:
#     2   2             ⎛  ⎛     2       2              2⎞
# ⅈ⋅g₂ ⋅m₁ ⋅m_{{\nu_l}}⋅⎝- ⎝- m_W  + 2⋅mₕ  + m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                    ⎞ _________
# m_W) + {{b_0}}__{(1)}(m_{{\nu_l}}, m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{U^\nu}}
# ──────────────────────────────────────────────────────────────────────────────
#          2   2
#      32⋅π ⋅mₕ ⋅v
#
# ______
# [l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────

# %%
collect(MLs[1].expand(),[Δe],simplify)
# Out:
#     2   2             ⎛   2                                 2
# ⅈ⋅g₂ ⋅m₁ ⋅m_{{\nu_l}}⋅⎝m_W ⋅C₀(m_{{\nu_l}}, m_W, m_W) - 2⋅mₕ ⋅C₀(m_{{\nu_l}},
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                        2
# m_W, m_W) - m_{{\nu_l}} ⋅C₀(m_{{\nu_l}}, m_W, m_W) + {{b_0}}__{(1)}(m_{{\nu_l}
# ──────────────────────────────────────────────────────────────────────────────
#                                 2   2
#                             32⋅π ⋅mₕ ⋅v
#
#                                    ⎞ _______________
# }, m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────────────────────────────────────────────────

# %%
νlHuWd.MR()#.subs({B2_1(mnul,mW):PaVetoDivFin(B2_1(mnul,mW)),
           #       B2_0(mnul,mW):PaVetoDivFin(B2_0(mnul,mW))}).expand().simplify()
# Out:
#     2
# ⅈ⋅g₂ ⋅m₁⋅m₂⋅m_{{\nu_l}}⋅(C₀(m_{{\nu_l}}, m_W, m_W) + C₂(m_{{\nu_l}}, m_W, m_W)
# ──────────────────────────────────────────────────────────────────────────────
#                                                         2
#                                                     32⋅π ⋅v
#
#   _______________
# )⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────

# %%
MRs[1] = νlHuWd.MR_GIM()
MRs[1]
# Out:
#     2                   ⎛⎛     2     2              2⎞
# ⅈ⋅g₂ ⋅m₁⋅m₂⋅m_{{\nu_l}}⋅⎝⎝- m_W  + mₕ  + m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W, m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                  ⎞ ___________
# W) + {{b_0}}__{(12)}(m_W, m_W) - {{b_0}}__{(2)}(m_{{\nu_l}}, m_W)⎠⋅{{U^\nu}}[l
# ──────────────────────────────────────────────────────────────────────────────
#         2   2
#     32⋅π ⋅mₕ ⋅v
#
# ____
# , 2]⋅{{U^\nu}}[l, 3]
# ────────────────────

# %%
collect(MRs[1].expand(),[Δe],evaluate=False).keys()#[Δe].simplify()
# Out:
# dict_keys([1])

# %% [markdown]
# ## FVS contribution
# In this case we only have one contribution too, $\nu_{l} W^{+} H^{-}$, the we need to consider the next couplings
# $h W^{+} H^{-} \rightarrow -\frac{i}{2}g_2 (-p^{H^{-}}_\mu + p^{h}_\mu)$, $ H^{-} \mu^{+} \nu_l \rightarrow i U^{\nu *}_{lb} Y^{e}_{2b}P_L$ and $W^{+} \tau^{-} \nu_{l} \rightarrow -i \frac{g_2}{\sqrt{2}}U^{\nu}_{l3} \gamma_\mu P_L$

# %%
hWuHd = VertexVSS(-I*g2/2)
#Hdμνl
Wuτνl = VertexVFF(0,-I*(g2/sqrt(2))*Uν[l,3])

# %%
Masas4 = [mnul,mW,mW]
νlWuHd = TriangleFVS(hWuHd,Hdμνl,Wuτνl,Masas4)
triangulo['νlWuHd'] = νlWuHd
νlWuHd.ML()#.subs(cambiosDivFin(*Masas4)).simplify()
# Out:
#     2
# ⅈ⋅g₂ ⋅m₁⋅m₂⋅m_{{\nu_l}}⋅(C₀(m_{{\nu_l}}, m_W, m_W) + C₁(m_{{\nu_l}}, m_W, m_W)
# ──────────────────────────────────────────────────────────────────────────────
#                                                         2
#                                                     32⋅π ⋅v
#
#   _______________
# )⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────

# %%
#collect(collect(νlWuHd.ML().expand(),[mnul],evaluate=False)[mnul].simplify(),νlWuHd.Cs,simplify)
MLs[2] = νlWuHd.ML_GIM()
MLs[2]
# Out:
#     2                   ⎛⎛   2     2              2⎞
# ⅈ⋅g₂ ⋅m₁⋅m₂⋅m_{{\nu_l}}⋅⎝⎝m_W  + mₕ  - m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W, m_W)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                ⎞ _____________
#  + {{b_0}}__{(1)}(m_{{\nu_l}}, m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{U^\nu}}[l,
# ──────────────────────────────────────────────────────────────────────────────
#        2   2
#    32⋅π ⋅mₕ ⋅v
#
# __
# 2]⋅{{U^\nu}}[l, 3]
# ──────────────────

# %%
collect(MLs[2].expand(),[Δe],evaluate=False).keys()#[Δe].simplify()
# Out:
# dict_keys([1])

# %%
νlWuHd.MR()
# Out:
#      2   2
# -ⅈ⋅g₂ ⋅m₂ ⋅m_{{\nu_l}}⋅(2⋅C₀(m_{{\nu_l}}, m_W, m_W) + C₂(m_{{\nu_l}}, m_W, m_W
# ──────────────────────────────────────────────────────────────────────────────
#                                                          2
#                                                      32⋅π ⋅v
#
#    _______________
# ))⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ───────────────────────────────────

# %%
MRs[2] = νlWuHd.MR_GIM()
MRs[2]
#νlWuHd.MR().subs(cambiosDivFin(mnul,mW,mH))
# Out:
#     2   2             ⎛  ⎛     2       2              2⎞
# ⅈ⋅g₂ ⋅m₂ ⋅m_{{\nu_l}}⋅⎝- ⎝- m_W  + 2⋅mₕ  + m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                    ⎞ _________
# m_W) - {{b_0}}__{(12)}(m_W, m_W) + {{b_0}}__{(2)}(m_{{\nu_l}}, m_W)⎠⋅{{U^\nu}}
# ──────────────────────────────────────────────────────────────────────────────
#          2   2
#      32⋅π ⋅mₕ ⋅v
#
# ______
# [l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────

# %% [markdown]
# ## FVV contribution
# In this case we only have one contribution too, $\nu_{l} W^{+} W^{-}$, the we need to consider the next couplings
# $h W^{+} W^{-} \rightarrow \frac{i}{2}g_2^2 v g_{\mu \nu}$, $ W^{-} \mu^{+} \nu_l \rightarrow -i \frac{g_2}{\sqrt{2}}U^{\nu*}_{l2} \gamma_\mu P_L$ and $W^{+} \tau^{-} \nu_{l} \rightarrow -i \frac{g_2}{\sqrt{2}}U^{\nu}_{l3} \gamma_\mu P_L$

# %%
hWuWd = VertexSVV(I*g2**2/2*v)
Wdμνl = VertexVFF(0,-I*(g2/sqrt(2))*conjugate(Uν[l,2]))
#Wuτνl

# %%
Masas5 = [mnul,mW,mW]
νlWuWd = TriangleFVV(hWuWd,Wdμνl,Wuτνl,Masas5)
triangulo['νlWuWd'] = νlWuWd
#νlWuWd.ML().subs(cambiosDivFin(*νlWuWd.masas)).simplify().subs(D,4)
#print('-'*200)
MLs[3] = νlWuWd.ML_GIM().subs(D,4)
ep = symbols(r'\epsilon',real=True)
MLs[3].simplify()
# Out:
#     4      ⎛⎛   2              2⎞
# ⅈ⋅g₂ ⋅m₁⋅v⋅⎝⎝m_W  - m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W, m_W) + {{b_0}}__{(1)}(m
# ──────────────────────────────────────────────────────────────────────────────
#                                                                2   2
#                                                            32⋅π ⋅mₕ
#
#                 ⎞ _______________
# _{{\nu_l}}, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────────────

# %%
MRs[3] = νlWuWd.MR_GIM().subs(D,4)
MRs[3].simplify()
# Out:
#     4      ⎛⎛   2              2⎞
# ⅈ⋅g₂ ⋅m₂⋅v⋅⎝⎝m_W  - m_{{\nu_l}} ⎠⋅C₀(m_{{\nu_l}}, m_W, m_W) + {{b_0}}__{(2)}(m
# ──────────────────────────────────────────────────────────────────────────────
#                                                                2   2
#                                                            32⋅π ⋅mₕ
#
#                 ⎞ _______________
# _{{\nu_l}}, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────────────

# %%
del triangulo['a']

# %% [markdown]
# ## Adding all triangle

# %%
#ContTL = sum(triangulo[t].ML().subs(cambiosDivFin(*triangulo[t].masas)).subs(cambios_aprox(*triangulo[t].masas)) for t in triangulo.keys()).subs(D,4)#.subs(cambios_aprox(*triangulo[t].masas))
#ContTL = sum(t for t in ContTL.expand().args if t.has(mnul))#.factor()
#ContTR = sum(triangulo[t].MR().subs(cambiosDivFin(*triangulo[t].masas)).subs(cambios_aprox(*triangulo[t].masas)) for t in triangulo.keys()).subs(D,4)#.subs(cambios_aprox(*triangulo[t].masas))
#ContTR = sum(t for t in ContTR.expand().args if t.has(mnul))#.factor()

# %%
#ContTL.subs(mH,mW)

# %%
sum(triangulo[t].ML_GIM() for t in triangulo.keys()).subs(D,4).expand().collect(mnul,simplify)
# Out:
#       2               3                                     _______________
#   ⅈ⋅g₂ ⋅m₁⋅m_{{\nu_l}} ⋅(m₁ + m₂)⋅C₀(m_{{\nu_l}}, m_W, m_W)⋅{{U^\nu}}[l, 2]⋅{{
# - ────────────────────────────────────────────────────────────────────────────
#                                              2   2
#                                          32⋅π ⋅mₕ ⋅v
#
#                     2                ⎛      2
# U^\nu}}[l, 3]   ⅈ⋅g₂ ⋅m₁⋅m_{{\nu_l}}⋅⎝m₁⋅m_W ⋅C₀(m_{{\nu_l}}, m_W, m_W) + m₁⋅{
# ───────────── + ──────────────────────────────────────────────────────────────
#
#
#
#                                                                        2
# {b_0}}__{(1)}(m_{{\nu_l}}, m_W) - m₁⋅{{b_0}}__{(12)}(m_W, m_W) + m₂⋅m_W ⋅C₀(m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# {{\nu_l}}, m_W, m_W) + m₂⋅{{b_0}}__{(1)}(m_{{\nu_l}}, m_W) - m₂⋅{{b_0}}__{(12)
# ──────────────────────────────────────────────────────────────────────────────
#             2   2
#         32⋅π ⋅mₕ ⋅v
#
#                 2                                       ⎞ _______________
# }(m_W, m_W) + mₕ ⋅(-2⋅m₁ + m₂)⋅C₀(m_{{\nu_l}}, m_W, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                               2 ⎛  4  4             2⎞
# \nu}}[l, 3]   ⅈ⋅m₁⋅m_{{\nu_l}} ⋅⎝g₂ ⋅v  + 4⋅m₁⋅m₂⋅mₕ ⎠⋅C₀(m_{{\nu_l}}, m_W, m_
# ─────────── - ────────────────────────────────────────────────────────────────
#                                                              2   2  3
#                                                          32⋅π ⋅mₕ ⋅v
#
#    _______________                        ⎛  4  4             2⎞ ⎛   2
# W)⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]   ⅈ⋅m₁⋅⎝g₂ ⋅v  + 4⋅m₁⋅m₂⋅mₕ ⎠⋅⎝m_W ⋅C₀(m_{{
# ────────────────────────────────── + ─────────────────────────────────────────
#
#
#
#                                                      ⎞ _______________
# \nu_l}}, m_W, m_W) + {{b_0}}__{(1)}(m_{{\nu_l}}, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                      2   2  3
#                  32⋅π ⋅mₕ ⋅v
#
#
# }}[l, 3]
# ────────

# %%
sum(triangulo[t].MR_GIM() for t in triangulo.keys()).subs(D,4).expand().collect(mnul,simplify)
# Out:
#     2               3                                     _______________
# ⅈ⋅g₂ ⋅m₂⋅m_{{\nu_l}} ⋅(m₁ - m₂)⋅C₀(m_{{\nu_l}}, m_W, m_W)⋅{{U^\nu}}[l, 2]⋅{{U^
# ──────────────────────────────────────────────────────────────────────────────
#                                            2   2
#                                        32⋅π ⋅mₕ ⋅v
#
#                   2                ⎛        2
# \nu}}[l, 3]   ⅈ⋅g₂ ⋅m₂⋅m_{{\nu_l}}⋅⎝- m₁⋅m_W ⋅C₀(m_{{\nu_l}}, m_W, m_W) + m₁⋅{
# ─────────── + ────────────────────────────────────────────────────────────────
#
#
#
#                                                                        2
# {b_0}}__{(12)}(m_W, m_W) - m₁⋅{{b_0}}__{(2)}(m_{{\nu_l}}, m_W) + m₂⋅m_W ⋅C₀(m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# {{\nu_l}}, m_W, m_W) - m₂⋅{{b_0}}__{(12)}(m_W, m_W) + m₂⋅{{b_0}}__{(2)}(m_{{\n
# ──────────────────────────────────────────────────────────────────────────────
#           2   2
#       32⋅π ⋅mₕ ⋅v
#
#                 2                                      ⎞ _______________
# u_l}}, m_W) + mₕ ⋅(m₁ - 2⋅m₂)⋅C₀(m_{{\nu_l}}, m_W, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                              2 ⎛  4  4             2⎞
# nu}}[l, 3]   ⅈ⋅m₂⋅m_{{\nu_l}} ⋅⎝g₂ ⋅v  + 4⋅m₁⋅m₂⋅mₕ ⎠⋅C₀(m_{{\nu_l}}, m_W, m_W
# ────────── - ─────────────────────────────────────────────────────────────────
#                                                             2   2  3
#                                                         32⋅π ⋅mₕ ⋅v
#
#   _______________                        ⎛  4  4             2⎞ ⎛   2
# )⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]   ⅈ⋅m₂⋅⎝g₂ ⋅v  + 4⋅m₁⋅m₂⋅mₕ ⎠⋅⎝m_W ⋅C₀(m_{{\
# ───────────────────────────────── + ──────────────────────────────────────────
#
#
#
#                                                     ⎞ _______________
# nu_l}}, m_W, m_W) + {{b_0}}__{(2)}(m_{{\nu_l}}, m_W)⎠⋅{{U^\nu}}[l, 2]⋅{{U^\nu}
# ──────────────────────────────────────────────────────────────────────────────
#                     2   2  3
#                 32⋅π ⋅mₕ ⋅v
#
#
# }[l, 3]
# ───────

# %%
ContTL = sum(triangulo[t].ML_GIM().subs(cambios_aprox(*triangulo[t].masas)) for t in triangulo.keys()).subs(D,4)
ContTL = sum(t for t in ContTL.expand().args if t.has(mnul))
ContTR = sum(triangulo[t].MR_GIM().subs(cambios_aprox(*triangulo[t].masas)) for t in triangulo.keys()).subs(D,4)
ContTR = sum(t for t in ContTL.expand().args if t.has(mnul))

# %%
#ContTL

# %% [markdown]
# # Burbujas
#
# This process also have Bubbles
# ## FV contribution
# In this case we only have one contribution too, $\nu_{a} W^{+}$, the we need to consider the next couplings
# $h e_{2} e_{2} \rightarrow \frac{ig m_2}{2\sqrt{2}m_W}$, $W^{+} \tau^{-} \nu_{a} \rightarrow i \frac{g}{\sqrt{2}}U^{\nu}_{1a} \gamma_\mu P_L$ and $ W^{-} \mu^{+} \nu_{a} \rightarrow i \frac{g}{\sqrt{2}}U^{\nu*}_{2a} \gamma_\nu P_L$

# %%
burbuja = {'a':0}

# %%
c = (I*g2*m2)/(2*sqrt(2)*mW)

nulWu = BubbleFV(c,Wuτνl,Wdμνl ,[mnul,mW])
MLL1 = nulWu.ML().subs({D:4}).subs({A0(mW):PaVetoDivFin(A0(mW)),B1_1(mnul,mW):PaVetoDivFin(B1_1(mnul,mW)),
                             B1_0(mnul,mW):PaVetoDivFin(B1_0(mnul,mW))}).expand()

# %%
#PaVetoDivFin(B1_0(mnul,mW))
#PaVetoDivFin(B1_1(mnul,mW))
MLL1 = nulWu.ML().subs({D:4})#.subs({A0(mW):PaVetoDivFin(A0(mW)),B1_1(mnul,mW):PaVetoDivFin(B1_1(mnul,mW)),
                       #      B1_0(mnul,mW):PaVetoDivFin(B1_0(mnul,mW))})
MLL1
# Out:
#         3      2                                    _______________
# -√2⋅ⅈ⋅g₂ ⋅m₁⋅m₂ ⋅{{B_{1}}}__{(1)}(m_{{\nu_l}}, m_W)⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[
# ──────────────────────────────────────────────────────────────────────────────
#                                    2     ⎛  2     2⎞
#                                64⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
#
# l, 3]
# ──────

# %% [markdown]
# ## ML

# %%
nulWu.ML().subs(cambiosDivFin(mnul,mW,mW)).simplify().subs(D,4)
# Out:
#         3      2                                                        ______
# -√2⋅ⅈ⋅g₂ ⋅m₁⋅m₂ ⋅(\Delta_\epsilon + 2⋅{{b_1}}__{(1)}(m_{{\nu_l}}, m_W))⋅{{U^\n
# ──────────────────────────────────────────────────────────────────────────────
#                                               2     ⎛  2     2⎞
#                                          128⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
# _________
# u}}[l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────────

# %%
divLnuW = collect(MLL1.subs(B1_1(mnul,mW),PaVetoDivFin(B1_1(mnul,mW))).expand(),[Δe],evaluate=False)[Δe]*Δe
divLnuW
# Out:
#                         3      2 _______________
# -√2⋅ⅈ⋅\Delta_\epsilon⋅g₂ ⋅m₁⋅m₂ ⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────────────────────────────
#                   ⎛    2   2           2   2    ⎞
#                 2⋅⎝64⋅π ⋅m₁ ⋅m_W - 64⋅π ⋅m₂ ⋅m_W⎠

# %% [markdown]
# ## MR

# %%
nulWu.MR().subs(cambiosDivFin(mnul,mW,mW)).simplify().subs(D,4)
# Out:
#         3   2                                                           ______
# -√2⋅ⅈ⋅g₂ ⋅m₁ ⋅m₂⋅(\Delta_\epsilon + 2⋅{{b_1}}__{(1)}(m_{{\nu_l}}, m_W))⋅{{U^\n
# ──────────────────────────────────────────────────────────────────────────────
#                                               2     ⎛  2     2⎞
#                                          128⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
# _________
# u}}[l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────────

# %%
MRR1 = nulWu.MR().subs({D:4}).subs({B1_1(mnul,mW):PaVetoDivFin(B1_1(mnul,mW))}).expand()
MRR1.simplify()
# Out:
#         3   2                                                           ______
# -√2⋅ⅈ⋅g₂ ⋅m₁ ⋅m₂⋅(\Delta_\epsilon + 2⋅{{b_1}}__{(1)}(m_{{\nu_l}}, m_W))⋅{{U^\n
# ──────────────────────────────────────────────────────────────────────────────
#                                               2     ⎛  2     2⎞
#                                          128⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
# _________
# u}}[l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────────

# %%
divRnuW = collect(MRR1.expand(),[Δe],evaluate=False)[Δe]*Δe
divRnuW
# Out:
#                         3   2    _______________
# -√2⋅ⅈ⋅\Delta_\epsilon⋅g₂ ⋅m₁ ⋅m₂⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────────────────────────────
#                   ⎛    2   2           2   2    ⎞
#                 2⋅⎝64⋅π ⋅m₁ ⋅m_W - 64⋅π ⋅m₂ ⋅m_W⎠

# %% [markdown]
# ## Contributino VF

# %%
c1 = (I*g2*m1)/(2*sqrt(2)*mW)
Wunul = BubbleVF(c1,Wuτνl,Wdμνl ,[mnul,mW])
burbuja['nulWuL'] = nulWu.ML() +  Wunul.ML()
burbuja['nulWuR'] = nulWu.MR() +  Wunul.MR()
MLL2 = Wunul.ML().subs({D:4}).subs({A0(mW):PaVetoDivFin(A0(mW)),
                             B2_1(mnul,mW):PaVetoDivFin(B2_1(mnul,mW)),
                             B2_0(mnul,mW):PaVetoDivFin(B2_0(mnul,mW))}).expand()

# %%
Wunul.ML().subs({D:4})#.subs({A0(mW):PaVetoDivFin(A0(mW)),B2_1(mnul,mW):PaVetoDivFin(B2_1(mnul,mW)),
                      #       B2_0(mnul,mW):PaVetoDivFin(B2_0(mnul,mW))})
# Out:
#        3      2                                    _______________
# √2⋅ⅈ⋅g₂ ⋅m₁⋅m₂ ⋅{{B_{1}}}__{(2)}(m_{{\nu_l}}, m_W)⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l
# ──────────────────────────────────────────────────────────────────────────────
#                                  2     ⎛    2     2⎞
#                              64⋅π ⋅m_W⋅⎝- m₁  + m₂ ⎠
#
#
# , 3]
# ────

# %% [markdown]
# ## ML

# %%
Wunul.ML().subs(cambiosDivFin(mnul,mW,mW)).simplify().subs(D,4)
# Out:
#        3      2                                                        _______
# √2⋅ⅈ⋅g₂ ⋅m₁⋅m₂ ⋅(\Delta_\epsilon - 2⋅{{b_1}}__{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                                              2     ⎛  2     2⎞
#                                         128⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
# ________
# }}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────

# %%
MLL2.simplify()
# Out:
#        3      2                                                        _______
# √2⋅ⅈ⋅g₂ ⋅m₁⋅m₂ ⋅(\Delta_\epsilon - 2⋅{{b_1}}__{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                                              2     ⎛  2     2⎞
#                                         128⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
# ________
# }}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────

# %%
divLWnu = collect(MLL2,[Δe],evaluate=False)[Δe]*Δe
divLWnu
# Out:
#                         3      2 _______________
# -√2⋅ⅈ⋅\Delta_\epsilon⋅g₂ ⋅m₁⋅m₂ ⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────────────────────────────
#                  ⎛      2   2           2   2    ⎞
#                2⋅⎝- 64⋅π ⋅m₁ ⋅m_W + 64⋅π ⋅m₂ ⋅m_W⎠

# %% [markdown]
# ## MR

# %%
Wunul.MR().subs(cambiosDivFin(mnul,mW,mW)).simplify().subs(D,4)
# Out:
#        3   2                                                           _______
# √2⋅ⅈ⋅g₂ ⋅m₁ ⋅m₂⋅(\Delta_\epsilon - 2⋅{{b_1}}__{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                                              2     ⎛  2     2⎞
#                                         128⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
# ________
# }}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────

# %%
MRR2 = Wunul.MR().subs({D:4}).subs({A0(mW):PaVetoDivFin(A0(mW)),B2_1(mnul,mW):PaVetoDivFin(B2_1(mnul,mW)),
                             B2_0(mnul,mW):PaVetoDivFin(B2_0(mnul,mW))}).expand()
MRR2.simplify()
# Out:
#        3   2                                                           _______
# √2⋅ⅈ⋅g₂ ⋅m₁ ⋅m₂⋅(\Delta_\epsilon - 2⋅{{b_1}}__{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                                              2     ⎛  2     2⎞
#                                         128⋅π ⋅m_W⋅⎝m₁  - m₂ ⎠
#
# ________
# }}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────

# %%
divRWnu =collect(MRR2,[Δe],evaluate=False)[Δe]*Δe
divRWnu
# Out:
#                         3   2    _______________
# -√2⋅ⅈ⋅\Delta_\epsilon⋅g₂ ⋅m₁ ⋅m₂⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────────────────────────────
#                  ⎛      2   2           2   2    ⎞
#                2⋅⎝- 64⋅π ⋅m₁ ⋅m_W + 64⋅π ⋅m₂ ⋅m_W⎠

# %% [markdown]
# ### Pruebas burbujas FV y VF

# %%
divLnuW + divLWnu
(divLnuW + divLWnu).simplify()
# Out:
#                          3      2 _______________
#   √2⋅ⅈ⋅\Delta_\epsilon⋅g₂ ⋅m₁⋅m₂ ⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]   √2⋅ⅈ⋅\Delt
# - ─────────────────────────────────────────────────────────────── - ──────────
#                    ⎛    2   2           2   2    ⎞
#                  2⋅⎝64⋅π ⋅m₁ ⋅m_W - 64⋅π ⋅m₂ ⋅m_W⎠
#
#              3      2 _______________
# a_\epsilon⋅g₂ ⋅m₁⋅m₂ ⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────────────────
#       ⎛      2   2           2   2    ⎞
#     2⋅⎝- 64⋅π ⋅m₁ ⋅m_W + 64⋅π ⋅m₂ ⋅m_W⎠
# 0

# %% [markdown]
# ## FS contribution
# In this case we only have one contribution too, $\nu_{a} H^{+}$, the we need to consider the next couplings
# $h e_{2} e_{2} \rightarrow \frac{ig m_2}{2\sqrt{2}m_W}$, $H^{+}\tau^{-} \nu_{l} \rightarrow i \frac{\sqrt{2}}{v} m_1 U^{\nu}_{l3} P_{R}$ and $H^{-}\mu^{+} \nu_{l} \rightarrow i \frac{\sqrt{2}}{v} m_2 U^{\nu *}_{l2} P_{L}$

# %%
#Hdμνl,Huτνl
nulH = BubbleFS(c,Huτνl,Hdμνl,[mnul,mW])
nulH.ML().subs(cambiosDivFin(mnul,mW,mW)).simplify()
# Out:
#            2   3                                                        ______
# -√2⋅ⅈ⋅g₂⋅m₁ ⋅m₂ ⋅(\Delta_\epsilon + 2⋅{{b_1}}__{(1)}(m_{{\nu_l}}, m_W))⋅{{U^\n
# ──────────────────────────────────────────────────────────────────────────────
#                                             2      2 ⎛  2     2⎞
#                                         64⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠
#
# _________
# u}}[l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────────

# %%
nulH.MR().subs(cambiosDivFin(mnul,mW,mW)).simplify()
# Out:
#            3   2                                                        ______
# -√2⋅ⅈ⋅g₂⋅m₁ ⋅m₂ ⋅(\Delta_\epsilon + 2⋅{{b_1}}__{(1)}(m_{{\nu_l}}, m_W))⋅{{U^\n
# ──────────────────────────────────────────────────────────────────────────────
#                                             2      2 ⎛  2     2⎞
#                                         64⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠
#
# _________
# u}}[l, 2]⋅{{U^\nu}}[l, 3]
# ──────────────────────────

# %% [markdown]
# ## SF contribution
# In this case we only have one contribution too, $H^{+} \nu_{l}$, the we need to consider the next couplings
# $h e_{1} e_{1} \rightarrow \frac{ig m_1}{2\sqrt{2}m_W}$, $H^{+}\tau^{-} \nu_{l} \rightarrow i \frac{\sqrt{2}}{v} m_1 U^{\nu}_{l3} P_{R}$ and $H^{-}\mu^{+} \nu_{l} \rightarrow i \frac{\sqrt{2}}{v} m_2 U^{\nu *}_{l2} P_{L}$

# %%
Hnul = BubbleSF(c1,Huτνl,Hdμνl,[mnul,mW])
burbuja['nulHL'] = nulH.ML() + Hnul.ML()
burbuja['nulHR'] = nulH.MR() + Hnul.MR()
Hnul.ML().subs(cambiosDivFin(mnul,mW,mW)).simplify()
# Out:
#           2   3                                                        _______
# √2⋅ⅈ⋅g₂⋅m₁ ⋅m₂ ⋅(\Delta_\epsilon - 2⋅{{b_1}}__{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                                            2      2 ⎛  2     2⎞
#                                        64⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠
#
# ________
# }}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────

# %%
Hnul.MR().subs(cambiosDivFin(mnul,mW,mW)).simplify()
# Out:
#           3   2                                                        _______
# √2⋅ⅈ⋅g₂⋅m₁ ⋅m₂ ⋅(\Delta_\epsilon - 2⋅{{b_1}}__{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                                            2      2 ⎛  2     2⎞
#                                        64⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠
#
# ________
# }}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────

# %%
(Hnul.ML()).subs({B1_1(mnul,mW):PaVetoDivFin(B1_1(mnul,mW)),
                              B2_1(mnul,mW):PaVetoDivFin(B2_1(mnul,mW))}).simplify()
# Out:
#           2   3                                                        _______
# √2⋅ⅈ⋅g₂⋅m₁ ⋅m₂ ⋅(\Delta_\epsilon - 2⋅{{b_1}}__{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu
# ──────────────────────────────────────────────────────────────────────────────
#                                            2      2 ⎛  2     2⎞
#                                        64⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠
#
# ________
# }}[l, 2]⋅{{U^\nu}}[l, 3]
# ────────────────────────

# %%
(nulH.ML() + Hnul.ML()).subs({B1_1(mnul,mW):PaVetoDivFin(B1_1(mnul,mW)),
                              B2_1(mnul,mW):PaVetoDivFin(B2_1(mnul,mW))}).simplify()
# Out:
#            2   3
# -√2⋅ⅈ⋅g₂⋅m₁ ⋅m₂ ⋅({{b_1}}__{(1)}(m_{{\nu_l}}, m_W) + {{b_1}}__{(2)}(m_{{\nu_l}
# ──────────────────────────────────────────────────────────────────────────────
#                                                     2      2 ⎛  2     2⎞
#                                                 32⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠
#
#          _______________
# }, m_W))⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ─────────────────────────────────────────

# %%
del burbuja['a']

# %%
burbuja.keys()
# Out:
# dict_keys(['nulWuL', 'nulWuR', 'nulHL', 'nulHR'])

# %%
sum(burbuja[B].subs(cambiosDivFin(mnul,mW,mW)).subs(D,4) for B in ['nulWuL','nulHL']).expand().collect(mnul,simplify)
# Out:
#               2 ⎛  2  2          ⎞
# -√2⋅ⅈ⋅g₂⋅m₁⋅m₂ ⋅⎝g₂ ⋅v  + 2⋅m₁⋅m₂⎠⋅({{b_1}}__{(1)}(m_{{\nu_l}}, m_W) + {{b_1}}
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2      2 ⎛  2
#                                                          64⋅π ⋅m_W⋅v ⋅⎝m₁  - m
#
#                            _______________
# __{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ───────────────────────────────────────────────────────────
#  2⎞
# ₂ ⎠

# %%
sum(burbuja[B].subs(cambiosDivFin(mnul,mW,mW)).subs(D,4) for B in ['nulWuR','nulHR']).expand().collect(mnul,simplify)
# Out:
#            2    ⎛  2  2          ⎞
# -√2⋅ⅈ⋅g₂⋅m₁ ⋅m₂⋅⎝g₂ ⋅v  + 2⋅m₁⋅m₂⎠⋅({{b_1}}__{(1)}(m_{{\nu_l}}, m_W) + {{b_1}}
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2      2 ⎛  2
#                                                          64⋅π ⋅m_W⋅v ⋅⎝m₁  - m
#
#                            _______________
# __{(2)}(m_{{\nu_l}}, m_W))⋅{{U^\nu}}[l, 2]⋅{{U^\nu}}[l, 3]
# ───────────────────────────────────────────────────────────
#  2⎞
# ₂ ⎠

# %% [markdown]
# ## Adding all bubbles

# %%
ContBL = (burbuja['nulWuL'].subs(cambiosDivFin(mnul,mW,mW)).subs(cambios_aprox(mnul,mW,mW)) + burbuja['nulHL'].subs(cambiosDivFin(mnul,mW,mW)).subs(cambios_aprox(mnul,mW,mW))).subs(D,4).simplify()
ContBL
ContBR = (burbuja['nulWuR'].subs(cambiosDivFin(mnul,mW,mW)).subs(cambios_aprox(mnul,mW,mW)) + burbuja['nulHR'].subs(cambiosDivFin(mnul,mW,mW)).subs(cambios_aprox(mnul,mW,mW))).subs(D,4).simplify()
ContBR
# Out:
#                                                    ⎛           2⎞
#               2            4 ⎛  2  2          ⎞    ⎜m_{{\nu_l}} ⎟ ____________
# -√2⋅ⅈ⋅g₂⋅m₁⋅m₂ ⋅m_{{\nu_l}} ⋅⎝g₂ ⋅v  + 2⋅m₁⋅m₂⎠⋅log⎜────────────⎟⋅{{U^\nu}}[l,
#                                                    ⎜       2    ⎟
#                                                    ⎝    m_W     ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        2
#                              2      2 ⎛  2     2⎞ ⎛   2              2⎞
#                          64⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠⋅⎝m_W  - m_{{\nu_l}} ⎠
#
#
# ___
#  2]⋅{{U^\nu}}[l, 3]
#
#
# ────────────────────
#                                                    ⎛           2⎞
#            2               4 ⎛  2  2          ⎞    ⎜m_{{\nu_l}} ⎟ ____________
# -√2⋅ⅈ⋅g₂⋅m₁ ⋅m₂⋅m_{{\nu_l}} ⋅⎝g₂ ⋅v  + 2⋅m₁⋅m₂⎠⋅log⎜────────────⎟⋅{{U^\nu}}[l,
#                                                    ⎜       2    ⎟
#                                                    ⎝    m_W     ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        2
#                              2      2 ⎛  2     2⎞ ⎛   2              2⎞
#                          64⋅π ⋅m_W⋅v ⋅⎝m₁  - m₂ ⎠⋅⎝m_W  - m_{{\nu_l}} ⎠
#
#
# ___
#  2]⋅{{U^\nu}}[l, 3]
#
#
# ────────────────────

# %% [markdown]
# ## $M_L$ Total

# %%
valores ={mW:80.379,mh:125,m1:1.777,m2:0.1507,δ:0,v:246,g2:(2*80.379)/(246),λ1:(125)**2/(246)**2}
MLtot = (ContTL + ContBL).subs(valores).n()
MRtot = (ContTR + ContBR).subs(valores).n()

# %%
#MLtot

# %%
MLmnul = MLtot.collect(mnul,evaluate=False)[mnul]*mnul + MLtot.collect(mnul,evaluate=False)[1]

# %%
MLmnu0 = MLtot.collect(mnul,evaluate=False)[1].simplify()
#MLmnu0

# %%
MRmnu0 = MRtot.collect(mnul,evaluate=False)[1].simplify()
MRmnul = MRtot.collect(mnul,evaluate=False)[1].simplify() + MRtot.collect(mnul,evaluate=False)[mnul]*mnul

# %%
from neutrinos import NuOscObservables, UpmnsStandardParametrization

# %%
Nudata = NuOscObservables
d21 = Nudata.squareDm21.central
d21
d31 = Nudata.squareDm31.central
d31
# Out:
# 7.390000000000001e-05
# 0.002523

# %%
θ12,θ13,θ23 = symbols(r'\theta_{12},\theta_{13},\theta_{23}')
cambiospmns = {sin(θ12):sqrt(Nudata.sin2theta12.central).n(),
              sin(θ13):sqrt(Nudata.sin2theta13.central).n(),
              sin(θ23):sqrt(Nudata.sin2theta23.central).n()}
cambios_cos = {cos(th):sqrt(1-sin(th)**2) for th in [θ12,θ13,θ23]}
cambios_cos
# Out:
# ⎧                     _______________________                       __________
# ⎨                    ╱        2                                    ╱        2
# ⎩cos(\theta_{12}): ╲╱  1 - sin (\theta_{12}) , cos(\theta_{13}): ╲╱  1 - sin (
#
# _____________                       _______________________⎫
#                                    ╱        2              ⎬
# \theta_{13}) , cos(\theta_{23}): ╲╱  1 - sin (\theta_{23}) ⎭

# %%
Upmns = UpmnsStandardParametrization(θ12,θ13,θ23).subs(cambios_cos
                                                      ).subs(cambiospmns)
Upmns
# Out:
# ⎡0.821302075974486   0.550502406897554   0.149699699398496⎤
# ⎢                                                         ⎥
# ⎢-0.555381876513578  0.489988544456971   0.738576482160108⎥
# ⎢                                                         ⎥
# ⎣0.333236993293153   -0.675912957636513  0.657339166640784⎦

# %%
mnu1,mnu2,mnu3 = symbols(r'm_{\nu_1},m_{\nu_2},m_{\nu_3}',positive=True)
mnu = [mnu1,sqrt(mnu1**2 + d21),sqrt(mnu1**2 + d31)]

# %%
MLval = lambda i: MLtot.subs({mnul:mnu[i-1],Uν[l,2]:Upmns[i-1,1],
                               Uν[l,3]:Upmns[i-1,2]}).n()
MRval = lambda i: MRtot.subs({mnul:mnu[i-1],Uν[l,2]:Upmns[i-1,1],
                               Uν[l,3]:Upmns[i-1,2]}).n()

# %%
MLval(2).subs(mnu1,0.23e-9).n()
MRval(2).subs(mnu1,0.23e-9).n()
#MRval(3)#.atoms(Symbol)
# Out:
# 9.08081073667702e-7 + 1.1236350886311e-5⋅ⅈ
# 9.08081073667702e-7 + 1.1236350886311e-5⋅ⅈ

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
MLnu = MLval(1) + MLval(2) + MLval(3)
MRnu = MRval(1) + MRval(2) + MRval(3)

# %%
MLnu.subs(mnu1,7.1e-11).n()
MRnu.subs(mnu1,7.1e-11).n()
# Out:
# 1.08044814328124e-11 + 1.66439352719465e-10⋅ⅈ
# 1.08044814328124e-11 + 1.66439351640749e-10⋅ⅈ

# %%
mnunp = np.linspace(1e-16,1e-9,100)
MLlin = np.array([abs(complex(MLnu.subs(mnu1,m).n())) for m in mnunp])
MRlin = np.array([abs(complex(MRnu.subs(mnu1,m).n())) for m in mnunp])

# %%
MLlin
# Out:
# array([1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789673e-10,
#        1.66789673e-10, 1.66789673e-10, 1.66789673e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10])

# %%
MRlin
# Out:
# array([1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789672e-10, 1.66789672e-10, 1.66789672e-10,
#        1.66789672e-10, 1.66789671e-10, 1.66789671e-10, 1.66789671e-10,
#        1.66789671e-10, 1.66789671e-10, 1.66789671e-10, 1.66789671e-10,
#        1.66789671e-10, 1.66789671e-10, 1.66789671e-10, 1.66789671e-10,
#        1.66789671e-10, 1.66789671e-10, 1.66789671e-10, 1.66789671e-10,
#        1.66789671e-10, 1.66789671e-10, 1.66789671e-10, 1.66789671e-10,
#        1.66789671e-10, 1.66789671e-10, 1.66789671e-10, 1.66789671e-10,
#        1.66789671e-10, 1.66789671e-10, 1.66789671e-10, 1.66789671e-10])

# %%
plt.plot(mnunp,MLlin,label='$M_L$');
plt.plot(mnunp,MRlin,label='$M_R$',alpha=0.7);
plt.xlabel(r'$m_{\nu_1}$',fontsize=15)
plt.legend();

# %% [markdown]
# # Widht
#
# In general amplitudes to process as $S \rightarrow F_1\overline{F_2}$, where S and F denote scalar and fermion respectively, have the form [Goodsell 2017](https://arxiv.org/pdf/1512.03266.pdf):
#
# $$
# \mathcal{M} = M_L \overline{u}(p_1)P_L v(p_2) + M_R \overline{u}(p_1)P_R v(p_2)
# $$
#
# where $M_{L,R}$ are scalar factors, $u(p_1)$ and $v(p_2)$ are respective Dirac Spinors of the $F_1$ and $F_2$. Also, when $S = h$, $F_1 = \mu$ and $F_2=\tau$, the partial width of the decay is ([Hue:2015fbb](https://arxiv.org/pdf/1512.03266.pdf),[Thuc:2016](https://arxiv.org/pdf/1604.03285.pdf))
#
# $$
# \Gamma(h \rightarrow \mu \tau) \equiv \Gamma(h \rightarrow \mu^{-} \tau^{+}) + \Gamma(h \rightarrow \mu^{+} \tau^{-})
#  = \frac{1}{8 \pi m_h}\sqrt{\left[1-\left( \frac{m_1^2 + m_2^2}{m_h} \right)^2  \right]  \left[1-\left( \frac{m_1^2 - m_2^2}{m_h} \right)^2  \right]}
#  \left[ (m_h^2 -m_1^2 - m_2^2)(|M_L|^2 + |M_R|^2) - 4 m_1 m_2 \text{Re}(M_L M_R^{*}) \right]
# $$
# where $m_h$, $m_1$ and $m_2$ correspond to $h$, $\mu$ and $\tau$ masses, respectively. The onshell conditions to this process are $p_i^2 = m_i^2 $  and $p_0^2 \equiv (p_1 + p_2)^2 = m_h^2$.

# %%
# Definimos la formula para el ancho de decaimiento
#mh, m1, m2 = symbols('m_h, m_1, m_2',real=True)
ML,MR = symbols('ML,MR')
def Γhτμ(ML,MR,mh=125,m1=1.777,m2=0.1507): 
    return 1/(8 *np.pi* mh)*np.sqrt((1-((m1**2+m2**2)/mh)**2)*(1-((m1**2-m2**2)/mh)**2))*((mh**2 - m1**2 - m2**2)*(np.abs(ML)**2 + np.abs(MR)**2)-4*m1*m2*np.real(ML*np.conj(MR)))
Γhτμ(1+0.1j,1+0.1j)
# Out:
# 10.037856246657483

# %%
x = np.array([1+0.1j,1+0.1j])
y = np.array([1+0.1j,1+0.1j])
Γhτμ(x,y)
# Out:
# array([10.03785625, 10.03785625])

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }
plt.figure(figsize=(10,8))
plt.plot(mnunp,Γhτμ(MLlin ,MRlin)/(Γhτμ(MLlin ,MRlin) + 4.07e-3),
         'go-',alpha=0.4)
#plt.xticks([], [])
#plt.legend()
#plt.title('');
plt.xlabel(r'$m_{\nu_1}$',fontdict=font);
plt.ylabel(r'$BR(h\rightarrow \tau \mu)$',fontdict=font);
plt.grid();

# %% [markdown]
# usando
# $$
# \left|Y_{\ell \tau}\right|^{2}+\left|Y_{\tau \ell}\right|^{2}=\frac{8 \pi}{m_{h}} \frac{\mathcal{B}(h \rightarrow \ell \tau)}{1-\mathcal{B}(h \rightarrow \ell \tau)} \Gamma_{h}(\mathrm{SM})
# $$
# y
# $$
# \sqrt{\left|Y_{\tau e}\right|^{2}+\left|Y_{e \tau}\right|^{2}}<0.0020, \quad
# \sqrt{\left|Y_{\tau \mu}\right|^{2}+\left|Y_{\mu \tau}\right|^{2}}<0.0015
# $$
