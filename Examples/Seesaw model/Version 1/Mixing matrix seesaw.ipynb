# %% [markdown]
# # Lepton mixing matrix on Minimal Seesaw (MSS) model.

# %% [markdown]
# In this notebook we will understand how the lepton mixing matrix of MSS is parametrized in the reference [Lepton flavor violating Higgs boson decays in seesaw models: New discussions](https://www.sciencedirect.com/science/article/pii/S0550321317301785), for future numerical application to the form factors of LFV Higgs decays.

# %%
from OneLoopLFVHD.neutrinos import UpmnsStandardParametrization
from sympy import init_printing, symbols

# %%
init_printing()

# %% [markdown]
# First, we define the mixing matrix in the standard parametrization as follows

# %%
θ12,θ13,θ23 = symbols(r'\theta_{12},\theta_{13},\theta_{23}',real=True)
Upmns = UpmnsStandardParametrization(θ12,θ13,θ23)
Upmns
# Out:
# ⎡                           cos(\theta_{12})⋅cos(\theta_{13})
# ⎢
# ⎢-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\t
# ⎢
# ⎣sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\th
#
#                                        sin(\theta_{12})⋅cos(\theta_{13})
#
# heta_{12})  -sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{
#
# eta_{23})   -sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{
#
#                                sin(\theta_{13})         ⎤
#                                                         ⎥
# 12})⋅cos(\theta_{23})  sin(\theta_{23})⋅cos(\theta_{13})⎥
#                                                         ⎥
# 23})⋅cos(\theta_{12})  cos(\theta_{13})⋅cos(\theta_{23})⎦

# %% [markdown]
# ## Casas-Ibarra parametrization of $M_D$
#
# The we follo using the CI parametrization to define $M_D$ as follows
# $$M_{D}^{T}=i U_{N}^{*}\left(M_{N}^{d}\right)^{1 / 2} \xi\left(\hat{m}_{v}\right)^{1 / 2} U_{\mathrm{PMNS}}^{\dagger}$$
# where $M_N^d = \text{diag}(M_{N_1},M_{N_2},M_{N_3})$ and $m_\nu^d = \text{diag}(M_{n_1},M_{n_2},M_{n_3})$. In this particular analysis they choose $\xi = I_3$
#
# Then we define these atrices as folows

# %%
from sympy import Matrix,sqrt,I

# %%
mn4,mn5,mn6 = symbols('m_{n_4},m_{n_5},m_{n_6}',positive=True)
MNdsqrt = Matrix([[sqrt(mn4),0,0],[0,sqrt(mn5),0],[0,0,sqrt(mn6)]])
MNdsqrt
# Out:
# ⎡  _________                          ⎤
# ⎢╲╱ m_{n_4}        0            0     ⎥
# ⎢                                     ⎥
# ⎢               _________             ⎥
# ⎢     0       ╲╱ m_{n_5}        0     ⎥
# ⎢                                     ⎥
# ⎢                            _________⎥
# ⎣     0            0       ╲╱ m_{n_6} ⎦

# %%
mn1,mn2,mn3 = symbols('m_{n_1},m_{n_2},m_{n3}',positive=True)
mndsqrt = Matrix([[sqrt(mn1),0,0],[0,sqrt(mn2),0],[0,0,sqrt(mn3)]])
mndsqrt
# Out:
# ⎡  _________                         ⎤
# ⎢╲╱ m_{n_1}        0           0     ⎥
# ⎢                                    ⎥
# ⎢               _________            ⎥
# ⎢     0       ╲╱ m_{n_2}       0     ⎥
# ⎢                                    ⎥
# ⎢                            ________⎥
# ⎣     0            0       ╲╱ m_{n3} ⎦

# %%
MD = I*Upmns*MNdsqrt*mndsqrt
MD
# Out:
# ⎡                                _________   _________
# ⎢                            ⅈ⋅╲╱ m_{n_1} ⋅╲╱ m_{n_4} ⋅cos(\theta_{12})⋅cos(\t
# ⎢
# ⎢    _________   _________
# ⎢ⅈ⋅╲╱ m_{n_1} ⋅╲╱ m_{n_4} ⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{1
# ⎢
# ⎢    _________   _________
# ⎣ⅈ⋅╲╱ m_{n_1} ⋅╲╱ m_{n_4} ⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13
#
#                                                                         ______
# heta_{13})                                                          ⅈ⋅╲╱ m_{n_
#
#                                             _________   _________
# 3})⋅sin(\theta_{23})⋅cos(\theta_{12}))  ⅈ⋅╲╱ m_{n_2} ⋅╲╱ m_{n_5} ⋅(-sin(\theta
#
#                                             _________   _________
# })⋅cos(\theta_{12})⋅cos(\theta_{23}))   ⅈ⋅╲╱ m_{n_2} ⋅╲╱ m_{n_5} ⋅(-sin(\theta
#
# ___   _________
# 2} ⋅╲╱ m_{n_5} ⋅sin(\theta_{12})⋅cos(\theta_{13})
#
#
# _{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))
#
#
# _{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))
#
#              ________   _________                          ⎤
#          ⅈ⋅╲╱ m_{n3} ⋅╲╱ m_{n_6} ⋅sin(\theta_{13})         ⎥
#                                                            ⎥
#      ________   _________                                  ⎥
#  ⅈ⋅╲╱ m_{n3} ⋅╲╱ m_{n_6} ⋅sin(\theta_{23})⋅cos(\theta_{13})⎥
#                                                            ⎥
#      ________   _________                                  ⎥
#  ⅈ⋅╲╱ m_{n3} ⋅╲╱ m_{n_6} ⋅cos(\theta_{13})⋅cos(\theta_{23})⎦

# %% [markdown]
# # Total mixing matrix $U^{\nu}$

# %% [markdown]
# The total mixing matrix in the case of three extra right handed neutrinos can be parametrized by
# $$U^\nu = \Omega
# \begin{pmatrix}
# U & \mathbf{O}\\
# \mathbf{O} & V
# \end{pmatrix}
# $$
# where in this case $\mathbf{O}$ represents a $3 \times 3$ null matrix, also $U$, $V$ are $3 \times 3$ unitary matrices.
#
# To other side, $\Omega$ is a $6 \times 6$ unitary matrix given by
# $$
# \Omega=\exp\left(\begin{array}{cc}
# \mathbf{O} & R \\
# -R^{\dagger} & \mathbf{O}
# \end{array}\right)=\left(\begin{array}{cc}
# 1-\frac{1}{2} R R^{\dagger} & R \\
# -R^{\dagger} & 1-\frac{1}{2} R^{\dagger} R
# \end{array}\right)+\mathcal{O}\left(R^{3}\right)
# $$
# where $R$ is a $3 \times 3$ matrixwith absolute values of all elements smaller tha unity.
#
# The condition of seesaw mechanism for neutrino mass generation is $|M_D| \ll |M_N|$,  where $|M_D|$ and $|M_N|$ denote characteristic scales of $M_D$ and $M_N$, resulting in useful ralations
# $$
# \begin{array}{r}
# R^{*} \simeq M_{D} M_{N}^{-1}, \quad m_{v} \simeq-M_{D} M_{N}^{-1} M_{D}^{T} \\
# V^{*} \hat{M}_{N} V^{\dagger} \simeq M_{N}+\frac{1}{2} R^{T} R^{*} M_{N}+\frac{1}{2} M_{N} R^{\dagger} R
# \end{array}
# $$
#
# In the particular case of $\xi = U_N = I_3$, we have
# $$
# M_{N}^{d}=M_{N}, \quad R=-i U_{\mathrm{PMNS}} \hat{m}_{v}^{1 / 2}\left(M_{N}^{d}\right)^{-1 / 2}, \quad V=I_{3}, \quad \hat{M}_{N}=M_{N}^{d}+\hat{m}_{\nu}
# $$

# %%
from sympy import MatrixSymbol, BlockDiagMatrix,eye, BlockMatrix,S,block_collapse,I,lambdify
from sympy.physics.quantum.dagger import Dagger

# %%
U = MatrixSymbol('U',3,3)
V = eye(3,3)
Q = BlockDiagMatrix(U,V)
Q
# Out:
# ⎡⎡U₀₀  U₀₁  U₀₂⎤           ⎤
# ⎢⎢             ⎥           ⎥
# ⎢⎢U₁₀  U₁₁  U₁₂⎥      𝟘    ⎥
# ⎢⎢             ⎥           ⎥
# ⎢⎣U₂₀  U₂₁  U₂₂⎦           ⎥
# ⎢                          ⎥
# ⎢                 ⎡1  0  0⎤⎥
# ⎢                 ⎢       ⎥⎥
# ⎢       𝟘         ⎢0  1  0⎥⎥
# ⎢                 ⎢       ⎥⎥
# ⎣                 ⎣0  0  1⎦⎦

# %%
R = MatrixSymbol('R',3,3)
I3 = eye(3,3)
A = I3 - S(1)/2*R*Dagger(R)
D = I3 - S(1)/2*Dagger(R)*R
Ω = BlockMatrix([[A,R],[-Dagger(R),D]])
Ω
# Out:
# ⎡            ⎡1  0  0⎤                       ⎤
# ⎢        †   ⎢       ⎥                       ⎥
# ⎢-1/2⋅R⋅R  + ⎢0  1  0⎥            R          ⎥
# ⎢            ⎢       ⎥                       ⎥
# ⎢            ⎣0  0  1⎦                       ⎥
# ⎢                                            ⎥
# ⎢                                   ⎡1  0  0⎤⎥
# ⎢           †                 †     ⎢       ⎥⎥
# ⎢         -R            -1/2⋅R ⋅R + ⎢0  1  0⎥⎥
# ⎢                                   ⎢       ⎥⎥
# ⎣                                   ⎣0  0  1⎦⎦

# %%
MNdsqrtinv = Matrix([[1/sqrt(mn4),0,0],[0,1/sqrt(mn5),0],[0,0,1/sqrt(mn6)]])
Rexp = -I*Upmns*mndsqrt*MNdsqrtinv 
Rexp
# Out:
# ⎡                                 _________
# ⎢                            -ⅈ⋅╲╱ m_{n_1} ⋅cos(\theta_{12})⋅cos(\theta_{13})
# ⎢                            ─────────────────────────────────────────────────
# ⎢                                                 _________
# ⎢                                               ╲╱ m_{n_4}
# ⎢
# ⎢     _________
# ⎢-ⅈ⋅╲╱ m_{n_1} ⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\th
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                                 _________
# ⎢                                               ╲╱ m_{n_4}
# ⎢
# ⎢     _________
# ⎢-ⅈ⋅╲╱ m_{n_1} ⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\the
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                                _________
# ⎣                                              ╲╱ m_{n_4}
#
#                                                                _________
#                                                           -ⅈ⋅╲╱ m_{n_2} ⋅sin(\
#                                                           ────────────────────
#
#                                                                              ╲
#
#                                    _________
# eta_{23})⋅cos(\theta_{12}))   -ⅈ⋅╲╱ m_{n_2} ⋅(-sin(\theta_{12})⋅sin(\theta_{13
# ────────────────────────────  ────────────────────────────────────────────────
#
#                                                                              ╲
#
#                                    _________
# ta_{12})⋅cos(\theta_{23}))    -ⅈ⋅╲╱ m_{n_2} ⋅(-sin(\theta_{12})⋅sin(\theta_{13
# ───────────────────────────   ────────────────────────────────────────────────
#
#                                                                              ╲
#
#                                                                         ______
# theta_{12})⋅cos(\theta_{13})                                       -ⅈ⋅╲╱ m_{n3
# ─────────────────────────────                                      ───────────
#  _________
# ╱ m_{n_5}                                                                    ╲
#
#                                                                 ________
# })⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))   -ⅈ⋅╲╱ m_{n3} ⋅sin(\
# ─────────────────────────────────────────────────────────  ───────────────────
#  _________
# ╱ m_{n_5}                                                                    ╲
#
#                                                                 ________
# })⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))   -ⅈ⋅╲╱ m_{n3} ⋅cos(\
# ─────────────────────────────────────────────────────────  ───────────────────
#  _________
# ╱ m_{n_5}                                                                    ╲
#
# __                           ⎤
# } ⋅sin(\theta_{13})          ⎥
# ────────────────────         ⎥
#  _________                   ⎥
# ╱ m_{n_6}                    ⎥
#                              ⎥
#                              ⎥
# theta_{23})⋅cos(\theta_{13}) ⎥
# ─────────────────────────────⎥
#  _________                   ⎥
# ╱ m_{n_6}                    ⎥
#                              ⎥
#                              ⎥
# theta_{13})⋅cos(\theta_{23}) ⎥
# ─────────────────────────────⎥
#  _________                   ⎥
# ╱ m_{n_6}                    ⎦

# %%
Aexp = I3 - S(1)/2*Rexp*Dagger(Rexp)
Dexp = I3 - S(1)/2*Dagger(Rexp)*Rexp
Aexp
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{13})   m_{n_1}⋅(-sin(\
# ⎢- ───────────────────────────────────────────────────────── - ───────────────
# ⎢                          2⋅m_{n_6}
# ⎢
# ⎢
# ⎢  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{23})   m_{n_1}⋅(sin(\t
# ⎢- ───────────────────────────────────────────────────────── - ───────────────
# ⎣                          2⋅m_{n_6}
#
#                                      2                           2
#                            m_{n3}⋅sin (\theta_{13})   m_{n_1}⋅cos (\theta_{12}
#                          - ──────────────────────── - ────────────────────────
#                                   2⋅m_{n_6}                            2⋅m_{n_
#
#
# theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{1
# ──────────────────────────────────────────────────────────────────────────────
#                                               2⋅m_{n_4}
#
#
# heta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23
# ──────────────────────────────────────────────────────────────────────────────
#                                              2⋅m_{n_4}
#
#      2                           2                 2
# )⋅cos (\theta_{13})   m_{n_2}⋅sin (\theta_{12})⋅cos (\theta_{13})
# ─────────────────── - ─────────────────────────────────────────── + 1
# 4}                                     2⋅m_{n_5}
#
#
# 2}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta
# ────────────────────────────────────── - ─────────────────────────────────────
#
#
#
# }))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_
# ───────────────────────────────────── - ──────────────────────────────────────
#
#
#
#
#
#
#
#
# _{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_{12})⋅
# ──────────────────────────────────────────────────────────────────────────────
#                         2⋅m_{n_5}
#
#
# {13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(\theta_{12})⋅c
# ──────────────────────────────────────────────────────────────────────────────
#                        2⋅m_{n_5}
#
#
#                                                                             m_
#                                                                           - ──
#
#
#
# cos(\theta_{13})
# ────────────────
#
#
#                                                2
# os(\theta_{13})     m_{n3}⋅sin(\theta_{23})⋅cos (\theta_{13})⋅cos(\theta_{23})
# ───────────────   - ──────────────────────────────────────────────────────────
#                                             2⋅m_{n_6}
#
#
# {n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{13})   m_{n_1}⋅(-sin(\theta
# ─────────────────────────────────────────────────────── - ────────────────────
#                       2⋅m_{n_6}
#
#                                               2                 2
#                                     m_{n3}⋅sin (\theta_{23})⋅cos (\theta_{13})
#                                   - ──────────────────────────────────────────
#                                                     2⋅m_{n_6}
#
#
#    m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{1
#  - ───────────────────────────────────────────────────────────────────────────
#
#
#
# _{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                          2⋅m_{n_4}
#
#
#    m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{
#  - ───────────────────────────────────────────────────────────────────────────
#                                                2⋅m_{n_4}
#
#
# 2})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅s
# ──────────────────────────────────────────────────────────────────────────────
#              2⋅m_{n_4}
#
#
# cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13}
# ───────────────────────────────── - ──────────────────────────────────────────
#
#
#                       2
# 23})⋅cos(\theta_{12}))    m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\the
# ─────────────────────── - ────────────────────────────────────────────────────
#                                                                       2⋅m_{n_5
#
#
# in(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13}
# ───────────────────────────────── - ──────────────────────────────────────────
#
#
#
# )⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_{12})⋅cos(\
# ──────────────────────────────────────────────────────────────────────────────
#                    2⋅m_{n_5}
#
#                                              2
# ta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))
# ────────────────────────────────────────────── + 1
# }
#
#
# )⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#                                                2⋅m_{n_5}
#
#
# theta_{13})
# ───────────
#
#
#
#                                                                        m_{n3}⋅
#                                                                      - ───────
#
#
#
# (\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))
# ───────────────────────────────────────────────────────────────────
#
#
#
#                                                  m_{n3}⋅sin(\theta_{13})⋅cos(\
#                                                - ─────────────────────────────
#                                                                          2⋅m_{
#
#                     2
# sin(\theta_{23})⋅cos (\theta_{13})⋅cos(\theta_{23})   m_{n_1}⋅(sin(\theta_{12}
# ─────────────────────────────────────────────────── - ────────────────────────
#                  2⋅m_{n_6}
#
#
#
#
#
#
#
# theta_{13})⋅cos(\theta_{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - si
# ──────────────────────────── - ───────────────────────────────────────────────
# n_6}
#
#
# )⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin
# ──────────────────────────────────────────────────────────────────────────────
#                                                                 2⋅m_{n_4}
#
#                     2                 2
#           m_{n3}⋅cos (\theta_{13})⋅cos (\theta_{23})   m_{n_1}⋅(sin(\theta_{12
#         - ────────────────────────────────────────── - ───────────────────────
#                           2⋅m_{n_6}
#
#
# n(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_
# ──────────────────────────────────────────────────────────────────────────────
#              2⋅m_{n_4}
#
#
# (\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                          2
# })⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))    m
# ────────────────────────────────────────────────────────────────────────── - ─
#                      2⋅m_{n_4}
#
#
# {13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\th
# ───── - ──────────────────────────────────────────────────────────────────────
#                                                                      2⋅m_{n_5}
#
#
# {12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\t
# ────── - ─────────────────────────────────────────────────────────────────────
#
#
#
# _{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})
# ──────────────────────────────────────────────────────────────────────────────
#                                            2⋅m_{n_5}
#
#
# eta_{23})⋅cos(\theta_{12}))⋅sin(\theta_{12})⋅cos(\theta_{13})
# ─────────────────────────────────────────────────────────────
#
#
#
# heta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{2
# ──────────────────────────────────────────────────────────────────────────────
#                     2⋅m_{n_5}
#
#                   2
# ⋅cos(\theta_{12}))
# ─────────────────── + 1
#
#
#                                         ⎤
#                                         ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
# 3}) - sin(\theta_{23})⋅cos(\theta_{12}))⎥
# ────────────────────────────────────────⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎥
#                                         ⎦

# %%
Dexp
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢    _________   _________
# ⎢  ╲╱ m_{n_1} ⋅╲╱ m_{n_2} ⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13
# ⎢- ───────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢                                                              ________   ____
# ⎢                                                            ╲╱ m_{n3} ⋅╲╱ m_{
# ⎢                                                          - ─────────────────
# ⎢
# ⎣
#
#
#                                             m_{n_1}⋅(sin(\theta_{12})⋅sin(\the
#                                           - ──────────────────────────────────
#
#
#
#
# })⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#                  _________   _________
#              2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_5}
#
# _____
# n_1} ⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅c
# ──────────────────────────────────────────────────────────────────────────────
#                                                _________   _________
#                                            2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_6}
#
#                                                               2
# ta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))    m_{n_1}⋅(-si
# ─────────────────────────────────────────────────────────────── - ────────────
#           2⋅m_{n_4}
#
#
#                                                       _________   _________
# \theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))   ╲╱ m_{n_1} ⋅╲╱ m_{n_2} ⋅(-
# ───────────────────────────────────────────────── - ──────────────────────────
#
#
#
#                                                        ________   _________
# os(\theta_{23}))⋅cos(\theta_{13})⋅cos(\theta_{23})   ╲╱ m_{n3} ⋅╲╱ m_{n_1} ⋅(-
# ────────────────────────────────────────────────── - ─────────────────────────
#
#
#
#
# n(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta
# ──────────────────────────────────────────────────────────────────────────────
#                                 2⋅m_{n_4}
#
#
#
# sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\the
# ──────────────────────────────────────────────────────────────────────────────
#                                                                    _________
#                                                                2⋅╲╱ m_{n_4} ⋅╲
#
#
# sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\the
# ──────────────────────────────────────────────────────────────────────────────
#                                        _________   _________
#                                    2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_6}
#
#        2              2                 2
# _{12}))    m_{n_1}⋅cos (\theta_{12})⋅cos (\theta_{13})
# ──────── - ─────────────────────────────────────────── + 1
#                             2⋅m_{n_4}
#
#
#
# ta_{12}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{1
# ──────────────────────────────────────────────────────────────────────────────
#  _________
# ╱ m_{n_5}
#
#                                                 ________   _________
# ta_{12}))⋅sin(\theta_{23})⋅cos(\theta_{13})   ╲╱ m_{n3} ⋅╲╱ m_{n_1} ⋅sin(\thet
# ─────────────────────────────────────────── - ────────────────────────────────
#                                                                           ____
#                                                                       2⋅╲╱ m_{
#
#
#
#
#
#
#
#                           _________   _________
# 2})⋅cos(\theta_{23}))   ╲╱ m_{n_1} ⋅╲╱ m_{n_2} ⋅sin(\theta_{12})⋅cos(\theta_{1
# ───────────────────── - ──────────────────────────────────────────────────────
#                                                      _________   _________
#                                                  2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_5}
#
#
# a_{13})⋅cos(\theta_{12})⋅cos(\theta_{13})
# ─────────────────────────────────────────
# _____   _________
# n_4} ⋅╲╱ m_{n_6}
#
#                            _________   _________
#                          ╲╱ m_{n_1} ⋅╲╱ m_{n_2} ⋅(sin(\theta_{12})⋅sin(\theta_
#                        - ─────────────────────────────────────────────────────
#
#
#
#        2
# 2})⋅cos (\theta_{13})
# ─────────────────────
#
#
#
#
#
#
#
#
#
#
# {23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})
# ──────────────────────────────────────────────────────────────────────────────
#                                        _________   _________
#                                    2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_5}
#
#
#                                                                  m_{n_2}⋅(-sin
#                                                                - ─────────────
#
#
#
#       ________   _________
#     ╲╱ m_{n3} ⋅╲╱ m_{n_2} ⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}
#   - ──────────────────────────────────────────────────────────────────────────
#                                                                     _________
#                                                                 2⋅╲╱ m_{n_5} ⋅
#
#                                                                             __
# ⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))   ╲╱ m
# ─────────────────────────────────────────────────────────────────────── - ────
#
#
#
#
# (\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_
# ──────────────────────────────────────────────────────────────────────────────
#                                2⋅m_{n_5}
#
#
#                                                                              _
# ) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_{23})⋅cos(\theta_{13})   ╲╱
# ──────────────────────────────────────────────────────────────────────── - ───
#   _________
# ╲╱ m_{n_6}
#
# _______   _________
# _{n_1} ⋅╲╱ m_{n_2} ⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2
# {23}))    m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\
# ─────── - ────────────────────────────────────────────────────────────────────
#                                                       2⋅m_{n_5}
#
#
# _______   _________
# m_{n3} ⋅╲╱ m_{n_2} ⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin
# ──────────────────────────────────────────────────────────────────────────────
#                                                              _________   _____
#                                                          2⋅╲╱ m_{n_5} ⋅╲╱ m_{n
#
#
# (\theta_{23})⋅cos(\theta_{12}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta
# ──────────────────────────────────────────────────────────────────────────────
#            _________   _________
#        2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_5}
#
#                              2              2                 2
# theta_{23})⋅cos(\theta_{12}))    m_{n_2}⋅sin (\theta_{12})⋅cos (\theta_{13})
# ────────────────────────────── - ─────────────────────────────────────────── +
#                                                   2⋅m_{n_5}
#
#
#                                                                       ________
# (\theta_{23})⋅cos(\theta_{12}))⋅cos(\theta_{13})⋅cos(\theta_{23})   ╲╱ m_{n3}
# ───────────────────────────────────────────────────────────────── - ──────────
# ____
# _6}
#
#                                                 _________   _________
# _{23}) + cos(\theta_{12})⋅cos(\theta_{23}))   ╲╱ m_{n_1} ⋅╲╱ m_{n_2} ⋅sin(\the
# ─────────────────────────────────────────── - ────────────────────────────────
#                                                                            ___
#                                                                        2⋅╲╱ m_
#
#
#
#  1
#
#
#
#    _________
# ⋅╲╱ m_{n_2} ⋅sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{13})
# ───────────────────────────────────────────────────────────────
#                   _________   _________
#               2⋅╲╱ m_{n_5} ⋅╲╱ m_{n_6}
#
#                              2                   ________   _________
# ta_{12})⋅cos(\theta_{12})⋅cos (\theta_{13})    ╲╱ m_{n3} ⋅╲╱ m_{n_1} ⋅(sin(\th
# ───────────────────────────────────────────  - ───────────────────────────────
# ______   _________
# {n_4} ⋅╲╱ m_{n_5}
#
#                                                  ________   _________
#                                                ╲╱ m_{n3} ⋅╲╱ m_{n_2} ⋅(-sin(\t
#                                              - ───────────────────────────────
#
#
#
#
#
#
#
#
#
#
# eta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}
# ──────────────────────────────────────────────────────────────────────────────
#                                  _________   _________
#                              2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_6}
#
#
# heta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23
# ──────────────────────────────────────────────────────────────────────────────
#                                  _________   _________
#                              2⋅╲╱ m_{n_5} ⋅╲╱ m_{n_6}
#
#
#
#
#
#
#
#                                          ________   _________
# ))⋅cos(\theta_{13})⋅cos(\theta_{23})   ╲╱ m_{n3} ⋅╲╱ m_{n_1} ⋅(-sin(\theta_{12
# ──────────────────────────────────── - ───────────────────────────────────────
#
#
#
#                                           ________   _________
# }))⋅sin(\theta_{23})⋅cos(\theta_{13})   ╲╱ m_{n3} ⋅╲╱ m_{n_2} ⋅(-sin(\theta_{1
# ───────────────────────────────────── - ──────────────────────────────────────
#
#
#
#                            2                          2                 2
#                  m_{n3}⋅sin (\theta_{13})   m_{n3}⋅sin (\theta_{23})⋅cos (\the
#                - ──────────────────────── - ──────────────────────────────────
#                         2⋅m_{n_6}                           2⋅m_{n_6}
#
#
#
# })⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#                          _________   _________
#                      2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_6}
#
#
# 2})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                           _________   _________
#                       2⋅╲╱ m_{n_5} ⋅╲╱ m_{n_6}
#
#                      2                 2
# ta_{13})   m_{n3}⋅cos (\theta_{13})⋅cos (\theta_{23})
# ──────── - ────────────────────────────────────────── + 1
#                            2⋅m_{n_6}
#
#
#                                   ________   _________
# \theta_{23})⋅cos(\theta_{13})   ╲╱ m_{n3} ⋅╲╱ m_{n_1} ⋅sin(\theta_{13})⋅cos(\t
# ───────────────────────────── - ──────────────────────────────────────────────
#                                                             _________   ______
#                                                         2⋅╲╱ m_{n_4} ⋅╲╱ m_{n_
#
#                                    ________   _________
# (\theta_{13})⋅cos(\theta_{23})   ╲╱ m_{n3} ⋅╲╱ m_{n_2} ⋅sin(\theta_{12})⋅sin(\
# ────────────────────────────── - ─────────────────────────────────────────────
#                                                              _________   _____
#                                                          2⋅╲╱ m_{n_5} ⋅╲╱ m_{n
#
#
#
#
#
#
#
#                             ⎤
# heta_{12})⋅cos(\theta_{13}) ⎥
# ─────────────────────────── ⎥
# ___                         ⎥
# 6}                          ⎥
#                             ⎥
#                             ⎥
# theta_{13})⋅cos(\theta_{13})⎥
# ────────────────────────────⎥
# ____                        ⎥
# _6}                         ⎥
#                             ⎥
#                             ⎥
#                             ⎥
#                             ⎥
#                             ⎥
#                             ⎦

# %%
U11 = Aexp*Upmns
U12 = Rexp*V
U21 = -Dagger(Rexp)*Upmns
U22 = Dexp*V
U11
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\t
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢ (sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\
# ⎣
#
#
#
#                                            (sin(\theta_{12})⋅sin(\theta_{23})
#
#
#             ⎛                             2
#             ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\theta_{13})⋅cos(\theta_{23})   m_
# heta_{23}))⋅⎜- ────────────────────────────────────────────────────────── - ──
#             ⎝                          2⋅m_{n_6}
#
#              ⎛            2                 2
#              ⎜  m_{n3}⋅cos (\theta_{13})⋅cos (\theta_{23})   m_{n_1}⋅(sin(\the
# theta_{23}))⋅⎜- ────────────────────────────────────────── - ─────────────────
#              ⎝                  2⋅m_{n_6}
#
#
#                                                       ⎛  m_{n3}⋅sin(\theta_{13
# - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅⎜- ─────────────────────
#                                                       ⎝
#
#
# {n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅c
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23})
# ──────────────────────────────────────────────────────────────────────────────
#                            2⋅m_{n_4}
#
#
# })⋅cos(\theta_{13})⋅cos(\theta_{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{2
# ──────────────────────────────────── - ───────────────────────────────────────
#    2⋅m_{n_6}
#
#
# os(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\t
# ──────────────────────────────────────────────────────────────────────────────
#         2⋅m_{n_4}
#
#  2
# )    m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta
# ── - ─────────────────────────────────────────────────────────────────────────
#                                                  2⋅m_{n_5}
#
#
# 3}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                      2⋅m_{n_4}
#
#
# heta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin
# ──────────────────────────── - ───────────────────────────────────────────────
#
#
#                         2    ⎞
# _{23})⋅cos(\theta_{12}))     ⎟
# ───────────────────────── + 1⎟ + (-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\th
#                              ⎠
#
#
# (\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) -
# ───────────── - ──────────────────────────────────────────────────────────────
#                                                                              2
#
#
# (\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅sin(\the
# ──────────────────────────────────────────────────────────────────────────────
#                                           2⋅m_{n_5}
#
#                                              ⎛                             2
#                                              ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\
# eta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅⎜- ──────────────────────────────
#                                              ⎝                          2⋅m_{n
#
#
#  sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ─────────────────────────────────────────────────────────────────────⎟ + (-sin
# ⋅m_{n_5}                                                             ⎠
#
#                                                               ⎞
# ta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⎟
# ──────────────────────────────────────────────────────────────⎟ + (-sin(\theta
#                                                               ⎠
#
#
# theta_{13})⋅cos(\theta_{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - si
# ──────────────────────────── - ───────────────────────────────────────────────
# _6}
#
#
#
# (\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_
#
#
#
#
# _{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅
#
#
#
# n(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\thet
# ──────────────────────────────────────────────────────────────────────────────
#                                          2⋅m_{n_4}
#
#
#        ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{13})   m_{n_1}⋅
# {12}))⋅⎜- ───────────────────────────────────────────────────────── - ────────
#        ⎝                          2⋅m_{n_6}
#
# ⎛            2                 2
# ⎜  m_{n3}⋅sin (\theta_{23})⋅cos (\theta_{13})   m_{n_1}⋅(-sin(\theta_{12})⋅cos
# ⎜- ────────────────────────────────────────── - ──────────────────────────────
# ⎝                  2⋅m_{n_6}
#
#
# a_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(
# ───────────────────────────────────────────────────────────── - ──────────────
#
#
#
# (-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\t
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2⋅m_{n_4}
#
#                                                                    2
# (\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))    m_{n_2}
# ──────────────────────────────────────────────────────────────────── - ───────
#               2⋅m_{n_4}
#
#
# \theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            2⋅m
#
#
# heta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin
# ───────────────────────────────────────────── - ──────────────────────────────
#
#
#
# ⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\
# ──────────────────────────────────────────────────────────────────────────────
#                                      2⋅m_{n_5}
#
#
# 23}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅
# ──────────────────────────────────────────────────────────────────────────────
# _{n_5}
#
#
# (\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta
# ──────────────────────────────────────────────────────────────────────────────
#                                2⋅m_{n_5}
#
#             2    ⎞
# theta_{23}))     ⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{1
# ───────────── + 1⎟ + ⎜- ──────────────────────────────────────────────────────
#                  ⎠   ⎝                          2⋅m_{n_6}
#
#                  ⎞
# cos(\theta_{12}))⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{2
# ─────────────────⎟ + ⎜- ──────────────────────────────────────────────────────
#                  ⎠   ⎝                          2⋅m_{n_6}
#
#                            ⎛            2                           2
# _{12})⋅cos(\theta_{13})⎞   ⎜  m_{n3}⋅sin (\theta_{13})   m_{n_1}⋅cos (\theta_{
# ───────────────────────⎟ + ⎜- ──────────────────────── - ─────────────────────
#                        ⎠   ⎝         2⋅m_{n_6}                            2⋅m_
#
#
# 3})   m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\thet
# ─── - ────────────────────────────────────────────────────────────────────────
#                                                                    2⋅m_{n_4}
#
#
# 3})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta
# ─── - ────────────────────────────────────────────────────────────────────────
#                                                                   2⋅m_{n_4}
#
#         2                           2                 2                 ⎞
# 12})⋅cos (\theta_{13})   m_{n_2}⋅sin (\theta_{12})⋅cos (\theta_{13})    ⎟
# ────────────────────── - ─────────────────────────────────────────── + 1⎟⋅cos(
# {n_4}                                     2⋅m_{n_5}                     ⎠
#
#
# a_{23})⋅cos(\theta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\t
# ─────────────────────────────────────────────────────────── - ────────────────
#
#
#
# _{12})⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\th
# ────────────────────────────────────────────────────────── - ─────────────────
#
#
#
#
# \theta_{12})⋅cos(\theta_{13})
#
#
#
# heta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23
# ──────────────────────────────────────────────────────────────────────────────
#                                              2⋅m_{n_5}
#
#
# eta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}
# ──────────────────────────────────────────────────────────────────────────────
#                                             2⋅m_{n_5}
#
#
#
#
#
#
#
# }))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ─────────────────────────────────────⎟⋅cos(\theta_{12})⋅cos(\theta_{13})  (-si
#                                      ⎠
#
#
# ))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ────────────────────────────────────⎟⋅cos(\theta_{12})⋅cos(\theta_{13})    (-s
#                                     ⎠
#
#
#
#
#
#
#
#
# n(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta
#
#
#
#
# in(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\thet
#
#
#
#
#                                       (-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(
#
#
#         ⎛            2                 2
#         ⎜  m_{n3}⋅sin (\theta_{23})⋅cos (\theta_{13})   m_{n_1}⋅(-sin(\theta_{
# _{23}))⋅⎜- ────────────────────────────────────────── - ──────────────────────
#         ⎝                  2⋅m_{n_6}
#
#          ⎛                             2
#          ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\theta_{13})⋅cos(\theta_{23})   m_{n_
# a_{23}))⋅⎜- ────────────────────────────────────────────────────────── - ─────
#          ⎝                          2⋅m_{n_6}
#
#
#                                                   ⎛  m_{n3}⋅sin(\theta_{13})⋅s
# \theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅⎜- ─────────────────────────
#                                                   ⎝                          2
#
#                                                                            2
# 12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))
# ──────────────────────────────────────────────────────────────────────────── -
#                       2⋅m_{n_4}
#
#
# 1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# in(\theta_{23})⋅cos(\theta_{13})   m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23})
# ──────────────────────────────── - ───────────────────────────────────────────
# ⋅m_{n_6}
#
#
#  m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12
#  ─────────────────────────────────────────────────────────────────────────────
#                                              2⋅m_{n_5}
#
#
# \theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\thet
# ──────────────────────────────────────────────────────────────────────────────
#      2⋅m_{n_4}
#
#
#  - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅cos(\theta_{12})⋅cos(\t
# ──────────────────────────────────────────────────────────────────────────────
#                   2⋅m_{n_4}
#
#                     2    ⎞
# })⋅cos(\theta_{23}))     ⎟
# ───────────────────── + 1⎟ + (-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{2
#                          ⎠
#
#
# a_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\t
# ───────────────────────── - ──────────────────────────────────────────────────
#
#
#
# heta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + co
# ────────── - ─────────────────────────────────────────────────────────────────
#                                                                           2⋅m_
#
#                                          ⎛                             2
#                                          ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\thet
# 3}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅⎜- ──────────────────────────────────
#                                          ⎝                          2⋅m_{n_6}
#
#
# heta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅sin(\theta_
# ──────────────────────────────────────────────────────────────────────────────
#                                        2⋅m_{n_5}
#
#
# s(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ──────────────────────────────────────────────────────────────────⎟ + (-sin(\t
# {n_5}                                                             ⎠
#
#
# a_{13})⋅cos(\theta_{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\t
# ──────────────────────── - ───────────────────────────────────────────────────
#
#
#                                                            ⎞
# {13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⎟
# ───────────────────────────────────────────────────────────⎟ + (-sin(\theta_{1
#                                                            ⎠
#
#
#
# heta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12
#
#
#
# heta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{2
# ──────────────────────────────────────────────────────────────────────────────
#                                      2⋅m_{n_4}
#
#                                                                            ⎛
#                                                                            ⎜
# 2})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅⎜-
#                                                                            ⎝
#
#
#     ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{23})   m_{n_1}⋅(si
# }))⋅⎜- ───────────────────────────────────────────────────────── - ───────────
#     ⎝                          2⋅m_{n_6}
#
#
# 3}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\the
# ───────────────────────────────────────────────────────── - ──────────────────
#
#
#           2                 2
# m_{n3}⋅cos (\theta_{13})⋅cos (\theta_{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\th
# ────────────────────────────────────────── - ─────────────────────────────────
#                 2⋅m_{n_6}
#
#
# n(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2⋅m_{n_4}
#
#
# ta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23})
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        2⋅m_{n_
#
#                                                                2
# eta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))    m_{n_2}⋅(-s
# ──────────────────────────────────────────────────────────────── - ───────────
#            2⋅m_{n_4}
#
#
# _{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\th
# ───────────────────────────────────────── - ──────────────────────────────────
#
#
#
# )⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
# 5}
#
#
# in(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\thet
# ──────────────────────────────────────────────────────────────────────────────
#                                  2⋅m_{n_5}
#
#
# eta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(\theta_{12
# ──────────────────────────────────────────────────────────────────────────────
#                            2⋅m_{n_5}
#
#              ⎞
# \theta_{12}))⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{13})
# ─────────────⎟ + ⎜- ─────────────────────────────────────────────────────────
#              ⎠   ⎝                          2⋅m_{n_6}
#
#         2    ⎞
# a_{12}))     ⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{23})
# ───────── + 1⎟ + ⎜- ─────────────────────────────────────────────────────────
#              ⎠   ⎝                          2⋅m_{n_6}
#
#                        ⎛            2                           2
# })⋅cos(\theta_{13})⎞   ⎜  m_{n3}⋅sin (\theta_{13})   m_{n_1}⋅cos (\theta_{12})
# ───────────────────⎟ + ⎜- ──────────────────────── - ─────────────────────────
#                    ⎠   ⎝         2⋅m_{n_6}                            2⋅m_{n_4
#
#
#   m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{2
# - ────────────────────────────────────────────────────────────────────────────
#                                                                2⋅m_{n_4}
#
#
#   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12
# - ────────────────────────────────────────────────────────────────────────────
#                                                               2⋅m_{n_4}
#
#     2                           2                 2                 ⎞
# ⋅cos (\theta_{13})   m_{n_2}⋅sin (\theta_{12})⋅cos (\theta_{13})    ⎟
# ────────────────── - ─────────────────────────────────────────── + 1⎟⋅sin(\the
# }                                     2⋅m_{n_5}                     ⎠
#
#
# 3})⋅cos(\theta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta
# ─────────────────────────────────────────────────────── - ────────────────────
#
#
#
# })⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_
# ────────────────────────────────────────────────────── - ─────────────────────
#
#
#
#
# ta_{12})⋅cos(\theta_{13})
#
#
#
# _{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                          2⋅m_{n_5}
#
#
# {12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅s
# ──────────────────────────────────────────────────────────────────────────────
#                                         2⋅m_{n_5}
#
#
#
#
#
#
#
# sin(\theta_{12})⋅cos(\theta_{13})⎞                                    ⎛  m_{n3
# ─────────────────────────────────⎟⋅sin(\theta_{12})⋅cos(\theta_{13})  ⎜- ─────
#                                  ⎠                                    ⎝
#
#
# in(\theta_{12})⋅cos(\theta_{13})⎞                                      ⎛  m_{n
# ────────────────────────────────⎟⋅sin(\theta_{12})⋅cos(\theta_{13})    ⎜- ────
#                                 ⎠                                      ⎝
#
#
#
#
#
#
#
# }⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{13})   m_{n_1}⋅(-sin(\theta_{1
# ──────────────────────────────────────────────────── - ───────────────────────
#                    2⋅m_{n_6}
#
#
# 3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{23})   m_{n_1}⋅(sin(\theta_{1
# ───────────────────────────────────────────────────── - ──────────────────────
#                     2⋅m_{n_6}
#
#
#                                   ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅
#                                   ⎜- ─────────────────────────────────────────
#                                   ⎝                          2⋅m_{n_6}
#
#
# 2})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                                       2⋅m_{n_4}
#
#
# 2})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                                       2⋅m_{n_4}
#
#
# cos(\theta_{13})   m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{1
# ──────────────── - ───────────────────────────────────────────────────────────
#
#
#
# (\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅s
# ────────────────────────────── - ─────────────────────────────────────────────
#
#
#
# (\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅c
# ────────────────────────────── - ─────────────────────────────────────────────
#
#
#
# 3})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{
# ──────────────────────────────────────────────────────────────────────── - ───
#   2⋅m_{n_4}
#
#
# in(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_{12})⋅cos(\the
# ──────────────────────────────────────────────────────────────────────────────
#                 2⋅m_{n_5}
#
#
# os(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(\theta_{12})⋅cos(\the
# ──────────────────────────────────────────────────────────────────────────────
#                 2⋅m_{n_5}
#
#
# n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅c
# ──────────────────────────────────────────────────────────────────────────────
#                                                           2⋅m_{n_5}
#
#                              ⎛                             2
# ta_{13})⎞                    ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\theta_{13})⋅cos(
# ────────⎟⋅sin(\theta_{13}) + ⎜- ──────────────────────────────────────────────
#         ⎠                    ⎝                          2⋅m_{n_6}
#
#                              ⎛                             2
# ta_{13})⎞                    ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\theta_{13})⋅cos(
# ────────⎟⋅sin(\theta_{13}) + ⎜- ──────────────────────────────────────────────
#         ⎠                    ⎝                          2⋅m_{n_6}
#
#
# os(\theta_{23}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ──────────────────────────────────────────────────⎟⋅sin(\theta_{23})⋅cos(\thet
#                                                   ⎠
#
#
# \theta_{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅c
# ──────────── - ───────────────────────────────────────────────────────────────
#
#
#
# \theta_{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅c
# ──────────── - ───────────────────────────────────────────────────────────────
#
#
#
#           ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{23})   m_{n_
# a_{13}) + ⎜- ───────────────────────────────────────────────────────── - ─────
#           ⎝                          2⋅m_{n_6}
#
#
# os(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\t
# ──────────────────────────────────────────────────────────────────────────────
#                          2⋅m_{n_4}
#
#
# os(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\t
# ──────────────────────────────────────────────────────────────────────────────
#                          2⋅m_{n_4}
#
#
# 1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(
# ──────────────────────────────────────────────────────────────────────────────
#                                                        2⋅m_{n_4}
#
#
# heta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin
# ───────────────────────────────────────────── - ──────────────────────────────
#
#
#
# heta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin
# ───────────────────────────────────────────── - ──────────────────────────────
#
#
#
# \theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅s
# ─────────────────────────────────────────────── - ────────────────────────────
#
#
#
# (\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\the
# ──────────────────────────────────────────────────────────────────────────────
#                                                            2⋅m_{n_5}
#
#
# (\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\the
# ──────────────────────────────────────────────────────────────────────────────
#                                                            2⋅m_{n_5}
#
#
# in(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(\the
# ──────────────────────────────────────────────────────────────────────────────
#                                  2⋅m_{n_5}
#
#
# ta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12})
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12})
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                ⎛            2
# ta_{12})⋅cos(\theta_{13})⎞                                     ⎜  m_{n3}⋅sin (
# ─────────────────────────⎟⋅cos(\theta_{13})⋅cos(\theta_{23}) + ⎜- ────────────
#                          ⎠                                     ⎝         2⋅m_{
#
#  ⎞                                     ⎛            2                 2
# )⎟                                     ⎜  m_{n3}⋅sin (\theta_{23})⋅cos (\theta
# ─⎟⋅cos(\theta_{13})⋅cos(\theta_{23}) + ⎜- ────────────────────────────────────
#  ⎠                                     ⎝                  2⋅m_{n_6}
#
#  ⎞                                     ⎛            2                 2
# )⎟                                     ⎜  m_{n3}⋅cos (\theta_{13})⋅cos (\theta
# ─⎟⋅sin(\theta_{23})⋅cos(\theta_{13}) + ⎜- ────────────────────────────────────
#  ⎠                                     ⎝                  2⋅m_{n_6}
#
#                           2                 2                           2
# \theta_{13})   m_{n_1}⋅cos (\theta_{12})⋅cos (\theta_{13})   m_{n_2}⋅sin (\the
# ──────────── - ─────────────────────────────────────────── - ─────────────────
# n_6}                            2⋅m_{n_4}
#
#
# _{13})   m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\t
# ────── - ─────────────────────────────────────────────────────────────────────
#                                                      2⋅m_{n_4}
#
#
# _{23})   m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\th
# ────── - ─────────────────────────────────────────────────────────────────────
#                                                      2⋅m_{n_4}
#
#             2                 ⎞
# ta_{12})⋅cos (\theta_{13})    ⎟
# ────────────────────────── + 1⎟⋅sin(\theta_{13})
# 2⋅m_{n_5}                     ⎠
#
#                             2
# heta_{23})⋅cos(\theta_{12}))    m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅si
# ───────────────────────────── - ──────────────────────────────────────────────
#                                                                             2⋅
#
#                            2
# eta_{12})⋅cos(\theta_{23}))    m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos
# ──────────────────────────── - ───────────────────────────────────────────────
#                                                                            2⋅m
#
#
#
#
#
#
#                                                    2    ⎞
# n(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))     ⎟
# ──────────────────────────────────────────────────── + 1⎟⋅sin(\theta_{23})⋅cos
# m_{n_5}                                                 ⎠
#
#                                                   2    ⎞
# (\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))     ⎟
# ─────────────────────────────────────────────────── + 1⎟⋅cos(\theta_{13})⋅cos(
# _{n_5}                                                 ⎠
#
#              ⎤
#              ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
# (\theta_{13})⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎥
# \theta_{23}) ⎥
#              ⎦

# %%
mheavy = {mn4:mn6/3,mn5:mn6/2}
U11.subs(mheavy)
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\t
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢ (sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\
# ⎣
#
#
#
#                                            (sin(\theta_{12})⋅sin(\theta_{23})
#
#
#             ⎛                             2
#             ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\theta_{13})⋅cos(\theta_{23})   3⋅
# heta_{23}))⋅⎜- ────────────────────────────────────────────────────────── - ──
#             ⎝                          2⋅m_{n_6}
#
#              ⎛            2                 2
#              ⎜  m_{n3}⋅cos (\theta_{13})⋅cos (\theta_{23})   3⋅m_{n_1}⋅(sin(\t
# theta_{23}))⋅⎜- ────────────────────────────────────────── - ─────────────────
#              ⎝                  2⋅m_{n_6}
#
#
#                                                       ⎛  m_{n3}⋅sin(\theta_{13
# - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅⎜- ─────────────────────
#                                                       ⎝
#
#
# m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# heta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23
# ──────────────────────────────────────────────────────────────────────────────
#                             2⋅m_{n_6}
#
#
# })⋅cos(\theta_{13})⋅cos(\theta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_
# ──────────────────────────────────── - ───────────────────────────────────────
#    2⋅m_{n_6}
#
#
# ⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#          2⋅m_{n_6}
#
#    2
# }))    m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\the
# ──── - ───────────────────────────────────────────────────────────────────────
#                                                     m_{n_6}
#
#
# {23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅c
# ──────────────────────────────────────────────────────────────────────────────
#                       2⋅m_{n_6}
#
#
# \theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅s
# ────────────────────────────── - ─────────────────────────────────────────────
#
#
#                           2    ⎞
# ta_{23})⋅cos(\theta_{12}))     ⎟
# ─────────────────────────── + 1⎟ + (-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\
#                                ⎠
#
#
# os(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23})
# ─────────────── - ────────────────────────────────────────────────────────────
#
#
#
# in(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅sin(\t
# ──────────────────────────────────────────────────────────────────────────────
#                                              m_{n_6}
#
#                                                ⎛                             2
#                                                ⎜  m_{n3}⋅sin(\theta_{23})⋅cos
# theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅⎜- ────────────────────────────
#                                                ⎝                          2⋅m_
#
#
#  - sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ───────────────────────────────────────────────────────────────────────⎟ + (-s
#   m_{n_6}                                                              ⎠
#
#                                                                 ⎞
# heta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⎟
# ────────────────────────────────────────────────────────────────⎟ + (-sin(\the
#                                                                 ⎠
#
#
# (\theta_{13})⋅cos(\theta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23})
# ────────────────────────────── - ─────────────────────────────────────────────
# {n_6}
#
#
#
# in(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\thet
#
#
#
#
# ta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12})
#
#
#
# - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\
# ──────────────────────────────────────────────────────────────────────────────
#                                             2⋅m_{n_6}
#
#
#          ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{13})   3⋅m_{n
# a_{12}))⋅⎜- ───────────────────────────────────────────────────────── - ──────
#          ⎝                          2⋅m_{n_6}
#
#   ⎛            2                 2
#   ⎜  m_{n3}⋅sin (\theta_{23})⋅cos (\theta_{13})   3⋅m_{n_1}⋅(-sin(\theta_{12})
# )⋅⎜- ────────────────────────────────────────── - ────────────────────────────
#   ⎝                  2⋅m_{n_6}
#
#
# theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-
# ───────────────────────────────────────────────────────────────── - ──────────
#
#
#
# _1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅co
# ──────────────────────────────────────────────────────────────────────────────
#                                                         2⋅m_{n_6}
#
#                                                                        2
# ⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))    m_{
# ──────────────────────────────────────────────────────────────────────── - ───
#                  2⋅m_{n_6}
#
#
# sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\the
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# s(\theta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})
# ───────────────────────────────────────────────── - ──────────────────────────
#
#
#
# n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅c
# ──────────────────────────────────────────────────────────────────────────────
#                                           m_{n_6}
#
#
# ta_{23}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{2
# ──────────────────────────────────────────────────────────────────────────────
#   m_{n_6}
#
#
# ⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\t
# ──────────────────────────────────────────────────────────────────────────────
#                                     m_{n_6}
#
#                 2    ⎞
# os(\theta_{23}))     ⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\thet
# ───────────────── + 1⎟ + ⎜- ──────────────────────────────────────────────────
#                      ⎠   ⎝                          2⋅m_{n_6}
#
#                      ⎞
# 3})⋅cos(\theta_{12}))⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\thet
# ─────────────────────⎟ + ⎜- ──────────────────────────────────────────────────
#                      ⎠   ⎝                          2⋅m_{n_6}
#
#                                ⎛            2                             2
# heta_{12})⋅cos(\theta_{13})⎞   ⎜  m_{n3}⋅sin (\theta_{13})   3⋅m_{n_1}⋅cos (\t
# ───────────────────────────⎟ + ⎜- ──────────────────────── - ─────────────────
#                            ⎠   ⎝         2⋅m_{n_6}
#
#
# a_{13})   3⋅m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin
# ─────── - ────────────────────────────────────────────────────────────────────
#                                                                         2⋅m_{n
#
#
# a_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(
# ─────── - ────────────────────────────────────────────────────────────────────
#                                                                        2⋅m_{n_
#
#               2                           2                 2
# heta_{12})⋅cos (\theta_{13})   m_{n_2}⋅sin (\theta_{12})⋅cos (\theta_{13})
# ──────────────────────────── - ─────────────────────────────────────────── + 1
#  2⋅m_{n_6}                                       m_{n_6}
#
#
# (\theta_{23})⋅cos(\theta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-
# ───────────────────────────────────────────────────────────────── - ──────────
# _6}
#
#
# \theta_{12})⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-s
# ──────────────────────────────────────────────────────────────── - ───────────
# 6}
#
# ⎞
# ⎟
# ⎟⋅cos(\theta_{12})⋅cos(\theta_{13})
# ⎠
#
#
# sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\the
# ──────────────────────────────────────────────────────────────────────────────
#                                                     m_{n_6}
#
#
# in(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\thet
# ──────────────────────────────────────────────────────────────────────────────
#                                                    m_{n_6}
#
#
#
#
#
#
#
# ta_{23}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ───────────────────────────────────────────⎟⋅cos(\theta_{12})⋅cos(\theta_{13})
#                                            ⎠
#
#
# a_{12}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ──────────────────────────────────────────⎟⋅cos(\theta_{12})⋅cos(\theta_{13})
#                                           ⎠
#
#
#
#
#
#
#
#
#   (-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(
#
#
#
#
#    (-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos
#
#
#
#
#                                             (-sin(\theta_{12})⋅sin(\theta_{13}
#
#
#               ⎛            2                 2
#               ⎜  m_{n3}⋅sin (\theta_{23})⋅cos (\theta_{13})   3⋅m_{n_1}⋅(-sin(
# \theta_{23}))⋅⎜- ────────────────────────────────────────── - ────────────────
#               ⎝                  2⋅m_{n_6}
#
#                ⎛                             2
#                ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\theta_{13})⋅cos(\theta_{23})
# (\theta_{23}))⋅⎜- ────────────────────────────────────────────────────────── -
#                ⎝                          2⋅m_{n_6}
#
#
#                                                         ⎛  m_{n3}⋅sin(\theta_{
# )⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅⎜- ───────────────────
#                                                         ⎝
#
#
# \theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{
# ──────────────────────────────────────────────────────────────────────────────
#                              2⋅m_{n_6}
#
#
#  3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{1
#  ─────────────────────────────────────────────────────────────────────────────
#
#
#
# 13})⋅sin(\theta_{23})⋅cos(\theta_{13})   3⋅m_{n_1}⋅(-sin(\theta_{12})⋅cos(\the
# ────────────────────────────────────── - ─────────────────────────────────────
#      2⋅m_{n_6}
#
#      2
# 12}))    m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\t
# ────── - ─────────────────────────────────────────────────────────────────────
#                                                       m_{n_6}
#
#
# 2})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅s
# ──────────────────────────────────────────────────────────────────────────────
#             2⋅m_{n_6}
#
#
# ta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅cos(\theta_{12}
# ──────────────────────────────────────────────────────────────────────────────
#                          2⋅m_{n_6}
#
#                             2    ⎞
# heta_{12})⋅cos(\theta_{23}))     ⎟
# ───────────────────────────── + 1⎟ + (-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\
#                                  ⎠
#
#
# in(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13}
# ───────────────────────────────── - ──────────────────────────────────────────
#
#
#
# )⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{2
# ────────────────── - ─────────────────────────────────────────────────────────
#
#
#                                                  ⎛
#                                                  ⎜  m_{n3}⋅sin(\theta_{23})⋅co
# theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅⎜- ──────────────────────────
#                                                  ⎝                          2⋅
#
#
# )⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅sin
# ──────────────────────────────────────────────────────────────────────────────
#                                                 m_{n_6}
#
#
# 3}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ──────────────────────────────────────────────────────────────────────────⎟ +
#      m_{n_6}                                                              ⎠
#
#  2
# s (\theta_{13})⋅cos(\theta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}
# ──────────────────────────────── - ───────────────────────────────────────────
# m_{n_6}
#
#                                                                    ⎞
# (\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⎟
# ───────────────────────────────────────────────────────────────────⎟ + (-sin(\
#                                                                    ⎠
#
#
#
# (-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\t
#
#
#
# ) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#                                               2⋅m_{n_6}
#
#
#
# theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{1
#
#
#
#             ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{23})   3⋅m
# heta_{12}))⋅⎜- ───────────────────────────────────────────────────────── - ───
#             ⎝                          2⋅m_{n_6}
#
#
# (\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅
# ─────────────────────────────────────────────────────────────────── - ────────
#
#
#      ⎛            2                 2
#      ⎜  m_{n3}⋅cos (\theta_{13})⋅cos (\theta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12
# 2}))⋅⎜- ────────────────────────────────────────── - ─────────────────────────
#      ⎝                  2⋅m_{n_6}
#
#
# _{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                           2⋅m_{n_6}
#
#
# (-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\t
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                          2
# })⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))    m
# ────────────────────────────────────────────────────────────────────────── - ─
#                     2⋅m_{n_6}
#
#
# cos(\theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12
# ─────────────────────────────────────────────────── - ────────────────────────
#
#
#
# heta_{23}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_
# ──────────────────────────────────────────────────────────────────────────────
#     m_{n_6}
#
#
# _{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})
# ──────────────────────────────────────────────────────────────────────────────
#                                             m_{n_6}
#
#
# })⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(
# ──────────────────────────────────────────────────────────────────────────────
#                                       m_{n_6}
#
#                        ⎞
# {23})⋅cos(\theta_{12}))⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\th
# ───────────────────────⎟ + ⎜- ────────────────────────────────────────────────
#                        ⎠   ⎝                          2⋅m_{n_6}
#
#                   2    ⎞
# ⋅cos(\theta_{12}))     ⎟   ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\th
# ─────────────────── + 1⎟ + ⎜- ────────────────────────────────────────────────
#                        ⎠   ⎝                          2⋅m_{n_6}
#
#                                  ⎛            2                             2
# \theta_{12})⋅cos(\theta_{13})⎞   ⎜  m_{n3}⋅sin (\theta_{13})   3⋅m_{n_1}⋅cos (
# ─────────────────────────────⎟ + ⎜- ──────────────────────── - ───────────────
#                              ⎠   ⎝         2⋅m_{n_6}
#
#
# eta_{13})   3⋅m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅s
# ───────── - ──────────────────────────────────────────────────────────────────
#                                                                           2⋅m_
#
#
# eta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅co
# ───────── - ──────────────────────────────────────────────────────────────────
#                                                                          2⋅m_{
#
#                 2                           2                 2
# \theta_{12})⋅cos (\theta_{13})   m_{n_2}⋅sin (\theta_{12})⋅cos (\theta_{13})
# ────────────────────────────── - ─────────────────────────────────────────── +
#    2⋅m_{n_6}                                       m_{n_6}
#
#
# in(\theta_{23})⋅cos(\theta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅
# ─────────────────────────────────────────────────────────────────── - ────────
# {n_6}
#
#
# s(\theta_{12})⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(
# ────────────────────────────────────────────────────────────────── - ─────────
# n_6}
#
#   ⎞
#   ⎟
#  1⎟⋅sin(\theta_{12})⋅cos(\theta_{13})
#   ⎠
#
#
# (-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\t
# ──────────────────────────────────────────────────────────────────────────────
#                                                       m_{n_6}
#
#
# -sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\th
# ──────────────────────────────────────────────────────────────────────────────
#                                                      m_{n_6}
#
#
#
#
#
#
#
# heta_{23}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ─────────────────────────────────────────────⎟⋅sin(\theta_{12})⋅cos(\theta_{13
#                                              ⎠
#
#
# eta_{12}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ────────────────────────────────────────────⎟⋅sin(\theta_{12})⋅cos(\theta_{13}
#                                             ⎠
#
#
#
#
#
#
#
#     ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{13})   3⋅m_{n_1}⋅(
# })  ⎜- ───────────────────────────────────────────────────────── - ───────────
#     ⎝                          2⋅m_{n_6}
#
#
#      ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta_{23})   3⋅m_{n_1}⋅
# )    ⎜- ───────────────────────────────────────────────────────── - ──────────
#      ⎝                          2⋅m_{n_6}
#
#
#                                               ⎛  m_{n3}⋅sin(\theta_{13})⋅sin(\
#                                               ⎜- ─────────────────────────────
#                                               ⎝                          2⋅m_{
#
#
# -sin(\theta_{12})⋅cos(\theta_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\th
# ──────────────────────────────────────────────────────────────────────────────
#                                                    2⋅m_{n_6}
#
#
# (sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\theta_{12})⋅cos(\th
# ──────────────────────────────────────────────────────────────────────────────
#                                                    2⋅m_{n_6}
#
#
# theta_{23})⋅cos(\theta_{13})   3⋅m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) -
# ──────────────────────────── - ───────────────────────────────────────────────
# n_6}
#
#
# eta_{12}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(
# ──────────────────────────────────────────── - ───────────────────────────────
#
#
#
# eta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(
# ──────────────────────────────────────────── - ───────────────────────────────
#
#
#
#  sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))⋅cos(\theta_{12})⋅cos(\the
# ──────────────────────────────────────────────────────────────────────────────
#                2⋅m_{n_6}
#
#
# \theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_
# ──────────────────────────────────────────────────────────────────────────────
#                                m_{n_6}
#
#
# \theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))⋅sin(\theta_
# ──────────────────────────────────────────────────────────────────────────────
#                                m_{n_6}
#
#
# ta_{13})   m_{n_2}⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(
# ──────── - ───────────────────────────────────────────────────────────────────
#                                                                          m_{n_
#
#                                            ⎛                             2
# {12})⋅cos(\theta_{13})⎞                    ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\th
# ──────────────────────⎟⋅sin(\theta_{13}) + ⎜- ────────────────────────────────
#                       ⎠                    ⎝                          2⋅m_{n_6
#
#                                            ⎛                             2
# {12})⋅cos(\theta_{13})⎞                    ⎜  m_{n3}⋅sin(\theta_{23})⋅cos (\th
# ──────────────────────⎟⋅sin(\theta_{13}) + ⎜- ────────────────────────────────
#                       ⎠                    ⎝                          2⋅m_{n_6
#
#
# \theta_{12})⋅cos(\theta_{23}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ────────────────────────────────────────────────────────────────⎟⋅sin(\theta_{
# 6}                                                              ⎠
#
#
# eta_{13})⋅cos(\theta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - si
# ────────────────────────── - ─────────────────────────────────────────────────
# }
#
#
# eta_{13})⋅cos(\theta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - si
# ────────────────────────── - ─────────────────────────────────────────────────
# }
#
#
#                         ⎛  m_{n3}⋅sin(\theta_{13})⋅cos(\theta_{13})⋅cos(\theta
# 23})⋅cos(\theta_{13}) + ⎜- ───────────────────────────────────────────────────
#                         ⎝                          2⋅m_{n_6}
#
#
# n(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\thet
# ──────────────────────────────────────────────────────────────────────────────
#                                         2⋅m_{n_6}
#
#
# n(\theta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))⋅(-sin(\theta_{12})⋅cos(\thet
# ──────────────────────────────────────────────────────────────────────────────
#                                         2⋅m_{n_6}
#
#
# _{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\theta_{13})⋅cos(\
# ────── - ─────────────────────────────────────────────────────────────────────
#                                                                       2⋅m_{n_6
#
#
# a_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(
# ───────────────────────────────────────────────────────────── - ──────────────
#
#
#
# a_{23}) - sin(\theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))   m_{n_2}⋅(-sin(
# ───────────────────────────────────────────────────────────── - ──────────────
#
#
#
# theta_{12})⋅cos(\theta_{23}))⋅cos(\theta_{12})⋅cos(\theta_{13})   m_{n_2}⋅(-si
# ─────────────────────────────────────────────────────────────── - ────────────
# }
#
#
# \theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             m_
#
#
# \theta_{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             m_
#
#
# n(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta
# ──────────────────────────────────────────────────────────────────────────────
#                                                   m_{n_6}
#
#
# 23}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅
# ──────────────────────────────────────────────────────────────────────────────
# {n_6}
#
#
# 23}))⋅(-sin(\theta_{12})⋅sin(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅
# ──────────────────────────────────────────────────────────────────────────────
# {n_6}
#
#
# _{12}))⋅sin(\theta_{12})⋅cos(\theta_{13})⎞
# ─────────────────────────────────────────⎟⋅cos(\theta_{13})⋅cos(\theta_{23}) +
#                                          ⎠
#
#                  ⎞                                     ⎛            2
# cos(\theta_{12}))⎟                                     ⎜  m_{n3}⋅sin (\theta_{
# ─────────────────⎟⋅cos(\theta_{13})⋅cos(\theta_{23}) + ⎜- ────────────────────
#                  ⎠                                     ⎝                  2⋅m_
#
#                  ⎞                                     ⎛            2
# cos(\theta_{12}))⎟                                     ⎜  m_{n3}⋅cos (\theta_{
# ─────────────────⎟⋅sin(\theta_{23})⋅cos(\theta_{13}) + ⎜- ────────────────────
#                  ⎠                                     ⎝                  2⋅m_
#
#  ⎛            2                             2                 2
#  ⎜  m_{n3}⋅sin (\theta_{13})   3⋅m_{n_1}⋅cos (\theta_{12})⋅cos (\theta_{13})
#  ⎜- ──────────────────────── - ───────────────────────────────────────────── -
#  ⎝         2⋅m_{n_6}                             2⋅m_{n_6}
#
#         2
# 23})⋅cos (\theta_{13})   3⋅m_{n_1}⋅(-sin(\theta_{12})⋅cos(\theta_{23}) - sin(\
# ────────────────────── - ─────────────────────────────────────────────────────
# {n_6}                                                                 2⋅m_{n_6
#
#         2
# 13})⋅cos (\theta_{23})   3⋅m_{n_1}⋅(sin(\theta_{12})⋅sin(\theta_{23}) - sin(\t
# ────────────────────── - ─────────────────────────────────────────────────────
# {n_6}                                                                 2⋅m_{n_6
#
#             2                 2                 ⎞
#  m_{n_2}⋅sin (\theta_{12})⋅cos (\theta_{13})    ⎟
#  ─────────────────────────────────────────── + 1⎟⋅sin(\theta_{13})
#                    m_{n_6}                      ⎠
#
#                                               2
# theta_{13})⋅sin(\theta_{23})⋅cos(\theta_{12}))    m_{n_2}⋅(-sin(\theta_{12})⋅s
# ─────────────────────────────────────────────── - ────────────────────────────
# }
#
#                                              2
# heta_{13})⋅cos(\theta_{12})⋅cos(\theta_{23}))    m_{n_2}⋅(-sin(\theta_{12})⋅si
# ────────────────────────────────────────────── - ─────────────────────────────
# }
#
#
#
#
#
#
#                                                                      2    ⎞
# in(\theta_{13})⋅sin(\theta_{23}) + cos(\theta_{12})⋅cos(\theta_{23}))     ⎟
# ────────────────────────────────────────────────────────────────────── + 1⎟⋅si
#                  m_{n_6}                                                  ⎠
#
#                                                                     2    ⎞
# n(\theta_{13})⋅cos(\theta_{23}) - sin(\theta_{23})⋅cos(\theta_{12}))     ⎟
# ───────────────────────────────────────────────────────────────────── + 1⎟⋅cos
#                 m_{n_6}                                                  ⎠
#
#                                ⎤
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
# n(\theta_{23})⋅cos(\theta_{13})⎥
#                                ⎥
#                                ⎥
#                                ⎥
#                                ⎥
# (\theta_{13})⋅cos(\theta_{23}) ⎥
#                                ⎦

# %%
from OneLoopLFVHD.neutrinos import NuOscObservables
import numpy as np

# %%
Nudata = NuOscObservables
Nudata
# Out:
# OneLoopLFVHD.neutrinos.NuOscObservables

# %%
d21 = Nudata.squareDm21.central
d21
d31 = Nudata.squareDm31.central
d31
mlight ={mn2:sqrt(mn1**2 + d21),mn3:sqrt(mn1**2 + d31)}
mlight
# Out:
# ⎧           _____________________              ____________________⎫
# ⎨          ╱        2                         ╱        2           ⎬
# ⎩m_{n3}: ╲╱  m_{n_1}  + 0.002523 , m_{n_2}: ╲╱  m_{n_1}  + 7.39e-5 ⎭

# %%
U22.subs(Nudata().substitutions(
    θ12,θ13,θ23)).subs(mheavy).subs(mlight).subs(mn1,1e-12).n()
# Out:
# ⎡          1.5e-12        -3.15178785437788e-24      -1.07743276513802e-23  ⎤
# ⎢    1.0 - ───────        ──────────────────────     ────────────────────── ⎥
# ⎢          m_{n_6}               m_{n_6}                    m_{n_6}         ⎥
# ⎢                                                                           ⎥
# ⎢-3.15178785437788e-24         0.00859651092013498    8.15653414434109e-19  ⎥
# ⎢──────────────────────  1.0 - ───────────────────    ────────────────────  ⎥
# ⎢       m_{n_6}                      m_{n_6}                m_{n_6}         ⎥
# ⎢                                                                           ⎥
# ⎢-1.07743276513802e-23     8.15653414434109e-19           0.0251147367097487⎥
# ⎢──────────────────────    ────────────────────     1.0 - ──────────────────⎥
# ⎣       m_{n_6}                  m_{n_6}                       m_{n_6}      ⎦

# %%
U11num = lambdify([mn6],U11.subs(Nudata().substitutions(
    θ12,θ13,θ23)).subs(mheavy).subs(mlight).subs(mn1,1e-12).n(),'numpy')
U12num = lambdify([mn6],U12.subs(Nudata().substitutions(
    θ12,θ13,θ23)).subs(mheavy).subs(mlight).subs(mn1,1e-12).n(),'numpy')
U21num = lambdify([mn6],U21.subs(Nudata().substitutions(
    θ12,θ13,θ23)).subs(mheavy).subs(mlight).subs(mn1,1e-12).n(),'numpy')
U22num = lambdify([mn6],U22.subs(Nudata().substitutions(
    θ12,θ13,θ23)).subs(mheavy).subs(mlight).subs(mn1,1e-12).n(),'numpy')

def Unu(m6,i,j):
    if i<=3 and j<=3:
        U = U11num(m6)[i-1,j-1]
    elif i<=3 and j>3:
        U = U12num(m6)[i-1,j-4]
    elif i>3 and j<=3:
        U = U21num(m6)[i-4,j-1]
    elif i>3 and j>3:
        U = U22num(m6)[i-4,j-4]
    else:
        ValueError('The index i and j must be in range [1,6]')
    return U

# %%
def Unu_sp(i,j):
    if i<=3 and j<=3:
        U = U11[i-1,j-1]
    elif i<=3 and j>3:
        U = U12[i-1,j-4]
    elif i>3 and j<=3:
        U = U21[i-4,j-1]
    elif i>3 and j>3:
        U = U22[i-4,j-4]
    else:
        ValueError('The index i and j must be in range [1,6]')
    return U
from sympy import conjugate,Add
#from sympy.physics import Dagger

# %%
Unu = Matrix([[Unu_sp(i-1,j-1).simplify() for j in range(1,7)] for i in range(1,7)])

# %%
Unu_deg = Unu.subs({mn4:mn6,mn5:mn6})

# %%
UU_deg = (Unu_deg*conjugate(Unu_deg.T)).simplify()

# %%
UU_deg[2-1,3-1].simplify()
# Out:
# ⎛
# ⎜        2
# ⎜2⋅m_{n3} ⋅sin(\theta_{13})⋅sin(\theta_{23}) - 8⋅m_{n3}⋅m_{n_6}⋅sin(\theta_{13
# ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                              2
#                       m_{n_1} ⋅(sin(2⋅\theta_{12} - \theta_{23}) + sin(2⋅\thet
# })⋅sin(\theta_{23}) - ────────────────────────────────────────────────────────
#                                                             4
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# a_{12} + \theta_{23}))          2    2
# ────────────────────── + m_{n_1} ⋅sin (\theta_{12})⋅sin(\theta_{13})⋅sin(\thet
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                               2
#                  2                                     m_{n_2} ⋅(sin(2⋅\theta_
# a_{23}) - m_{n_1} ⋅sin(\theta_{13})⋅sin(\theta_{23}) + ───────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
#                   2
#          4⋅m_{n_6}
#
#
# {12} - \theta_{23}) + sin(2⋅\theta_{12} + \theta_{23}))          2    2
# ─────────────────────────────────────────────────────── - m_{n_2} ⋅sin (\theta
#                4
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                     2
# _{12})⋅sin(\theta_{13})⋅sin(\theta_{23}) + 4⋅m_{n_6} ⋅sin(\theta_{13})⋅sin(\th
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          ⎞
#          ⎟
# eta_{23})⎟⋅cos(\theta_{13})
#          ⎠
# ───────────────────────────

# %%
UU_deg[2-1,3-1].subs({mn2:mn1,mn3:mn1}).simplify()
# Out:
#                                                                       ⎛
# (cos(2⋅\theta_{13} - \theta_{23}) - cos(2⋅\theta_{13} + \theta_{23}))⋅⎝m_{n_1}
# ──────────────────────────────────────────────────────────────────────────────
#                                                              2
#                                                    16⋅m_{n_6}
#
# 2                                2⎞
#   - 8⋅m_{n_1}⋅m_{n_6} + 4⋅m_{n_6} ⎠
# ───────────────────────────────────

# %%
UU_deg[1-1,3-1].subs({mn2:mn1,mn3:mn1}).simplify()
# Out:
# ⎛       2                                2⎞                     2
# ⎝m_{n_1}  - 8⋅m_{n_1}⋅m_{n_6} + 4⋅m_{n_6} ⎠⋅sin(\theta_{23})⋅cos (\theta_{13})
# ──────────────────────────────────────────────────────────────────────────────
#                                                     2
#                                            4⋅m_{n_6}
#
#
# ⋅cos(\theta_{23})
# ─────────────────

# %%
i = 6
j = 6
#if i>3 and j<=3:
m6 = np.linspace(1,10,3)
X = U12num(m6)[i-4,j-4]#
X
# Out:
# array([-0.-0.14732241j, -0.-0.06281849j, -0.-0.04658744j])

# %%
Unu(m6,0,1)
# Out:
# array([0.33323699, 0.33323699, 0.33323699])

# %%
for i in range(len(m6)):
    display(U12num(m6[i])[0,0])
# Out:
# (-0-1.4225369239496e-06j)
# (-0-6.065717824567226e-07j)
# (-0-4.498456735370465e-07j)

# %%
Unu(2,4,4)
# Out:
# 0.99999999999925

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from Unu_seesaw import Unu #as Unu1

# %%
U21num(m6)[0,0]
# Out:
# array([-0.-1.73205081e-06j, -0.-7.38548946e-07j, -0.-5.47722558e-07j])

# %%
Unu(1e-12,6,4,1)
# Out:
# -7.071067811865486e-07j

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
m6 = np.linspace(5e-11,8e15,10000)
plt.loglog(m6,np.abs(Unu(1e-12,m6,4,1)))

# %%
def Cij(m6,i,j):
    suma = 0
    for c in range(1,4):
        suma += Unu(1e-12,m6,c,i)*np.conjugate(Unu(1e-12,m6,c,j))
    return suma

# %%
Cij(6,1,1)
# Out:
# 0.9999999999995007

# %%
plt.loglog(m6,abs(Cij(m6,2,3)),'o')
