# %% [markdown]
# # LFV Higgs decays in SeeSaw model ( Thao et al results) First numeric results no compatibles con seesaw new discussions.

# %% [markdown]
# ## In this notebook we use the mpmath implementations of PaVe functions

# %%
from sympy import init_printing, Symbol,lambdify, symbols
init_printing()
import OneLoopLFVHD as lfvhd

# %%
from seesaw_FF import AaL, AaR, AbL, AbR, AcdL, AcdR
from seesaw_FF import g, mW, Uν, Uνc, mn, m, C, Cc, a,b,i,j,h
from seesaw_FF import j as jj

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from mpmath import *

# %%
mp.dps = 15; mp.pretty = True

# %%
import numpy as np

# %% [markdown]
# ## Numeric implementation of form factors

# %% [markdown]
# **Neutrino benchmark** is given by

# %%
from OneLoopLFVHD.neutrinos import NuOscObservables
Nudata = NuOscObservables

# %%
m1 = mpf('1e-12')  #GeV 

#current values to Square mass differences
d21 = mpf(str(Nudata.squareDm21.central))*mpf('1e-18')# factor to convert eV^2 to GeV^2
d31 = mpf(str(Nudata.squareDm31.central))*mpf('1e-18')

#d21 = 7.5e-5*1e-18
#d31 = 2.457e-3*1e-18
m2 = sqrt(m1**2 + d21)
m3 = sqrt(m1**2 + d31)

m4 = lambda m6: m6/3
m5 = lambda m6: m6/2

# %% [markdown]
# ### Form factor with one fermion in the loop.

# %% [markdown]
# #### AL one fermion

# %%
from OneLoopLFVHD.data import ml

# %%
def GIM_One(exp):
    from sympy import Add
    args = exp.expand().args
    func = exp.expand().func
    if isinstance(func,Add):
        X = Add(*[t for t in args if t.has(mni)]).simplify()
    else:
        X = exp
    #X1 = X.collect([mni],evaluate=False)
    return X#mni**2*X1[mni**2]

# %%
def sumOne(m6,Aab,a,b): 
    mnk = [m1,m2,m3,m6/3,m6/2,m6]
    AL = 0.0
    for i in range(1,4):
        A = Aab(mnk[i-1],Unu(m1,m6,b,i),conj(Unu(m1,m6,a,i)))
        #print('Ai = ',A)
        AL += A
    return AL

# %%
mh,ma,mb = symbols('m_h,m_a,m_b',real=True)
valores ={mW:mpf(80.379),mh:mpf(125.10),g:(2*mpf(80.379))/mpf(246)}

cambios_hab = lambda a,b:{lfvhd.ma:valores[mh],lfvhd.mi:ml[a],lfvhd.mj:ml[b]}


Ubi, Ucai,mni = symbols('U_{bi}, {{U_{ai}^*}},m_{n_i}')
UnuOne = {mn[i]:mni,Uν[b,i]:Ubi,Uνc[a,i]:Ucai}

#from Unu_seesaw import Unu, Cij, Unusym, Cijsym, Unu1, Cij1
from Unu_seesaw import Unump as Unu # no mixing
from Unu_seesaw import Cijmp as Cij # no mixing

# %%
from OneLoopLFVHD.data import replaceBs, pave_functions

# %%
def numeric_sum_diagramsOne(Diagramas,a,b):
    FdiagOneFer = []
    for dia in Diagramas:
        x = GIM_One(dia.subs(lfvhd.D,4).subs(cambios_hab(a,b)).subs(valores).subs(UnuOne))
        f = lambdify([mni,Ubi,Ucai],replaceBs(x),
                     modules=[pave_functions(valores[mh],a,b,lib='mpmath'),'mpmath'])
        #print(f(1,2,3))
        #fsum = lambda m6:sumOne(m6,f,a,b)
        FdiagOneFer.append(f)
    def suma(m6):
        out = 0.0
        xs = []
        for g in FdiagOneFer:
            #print('inside of sumOne')
            #x = g(m6)
            x = sumOne(m6,g,a,b)
            out += x
            xs.append(x)
        return np.array(xs),out
    return suma

# %%
DiagramasOneL = [AaL,AcdL]
DiagramasOneR = [AaR,AcdR]
#a = 2, b = 3
ALOneTot23 = numeric_sum_diagramsOne(DiagramasOneL,2,3)
AROneTot23 = numeric_sum_diagramsOne(DiagramasOneR,2,3)

#a = 3, b = 2
ALOneTot32 = numeric_sum_diagramsOne(DiagramasOneL,3,2)
AROneTot32 = numeric_sum_diagramsOne(DiagramasOneR,3,2)

#a = 1, b = 3
ALOneTot13 = numeric_sum_diagramsOne(DiagramasOneL,1,3)
AROneTot13 = numeric_sum_diagramsOne(DiagramasOneR,1,3)

#a = 3, b = 1
ALOneTot31 = numeric_sum_diagramsOne(DiagramasOneL,3,1)
AROneTot31 = numeric_sum_diagramsOne(DiagramasOneR,3,1)

#a = 1, b = 2
ALOneTot12 = numeric_sum_diagramsOne(DiagramasOneL,1,2)
AROneTot12 = numeric_sum_diagramsOne(DiagramasOneR,1,2)

#a = 2, b = 1
ALOneTot21 = numeric_sum_diagramsOne(DiagramasOneL,2,1)
AROneTot21 = numeric_sum_diagramsOne(DiagramasOneR,2,1)

# %%
n = 100
m6np = np.logspace(-1,15,n)

# %%
YLOne23 = np.array([np.abs(ALOneTot23(mpf(str(m6)))[1]) for m6 in m6np])
YLOne32 = np.array([np.abs(ALOneTot32(mpf(str(m6)))[1])for m6 in m6np])

YLOne13 = np.array([np.abs(ALOneTot13(mpf(str(m6)))[1])for m6 in m6np])
YLOne31 = np.array([np.abs(ALOneTot31(mpf(str(m6)))[1])for m6 in m6np])

YLOne12 = np.array([np.abs(ALOneTot12(mpf(str(m6)))[1])for m6 in m6np])
YLOne21 = np.array([np.abs(ALOneTot21(mpf(str(m6)))[1])for m6 in m6np])

# %%
plt.figure(figsize=(15,8))
plt.loglog(np.real(m6np),YLOne23,'-.',label='$A_L^{(1)}(2,3)$')
plt.loglog(np.real(m6np),YLOne32,'--',label='$A_L^{(1)}(3,2)$')

plt.loglog(np.real(m6np),YLOne13,'-.',label='$A_L^{(1)}(1,3)$')
plt.loglog(np.real(m6np),YLOne31,'--',label='$A_L^{(1)}(3,1)$')

plt.loglog(np.real(m6np),YLOne12,'-.',label='$A_L^{(1)}(1,2)$')
plt.loglog(np.real(m6np),YLOne21,'--',label='$A_L^{(1)}(2,1)$')
# plt.vlines(80.379,1e-34,1e-2,linestyles='--',color='r',label=r'$m_W$')

plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.legend(fontsize=15)

# %%
abs(Unu(mpf('1e-10'),mpf('1e15'),2,6)-Unu(1e-10,1e15,2,6))
# Out:
# 0.0

# %%
Unu(mpf('1e-10'),mpf('1e15'),1,6)
# Out:
# (0.149699699398496 + 0.0j)

# %%
from Unu_seesaw import Ununp, MD, mlight, mheavy, Osc_data,mn1,mn6,Dexp, Dexp_mp # no mixing
from Unu_seesaw import Cijnp, MD_mp # no mixing

# %%
Dexp.subs(Osc_data).subs(mheavy).subs(mlight).subs({mn1:m1,mn6:100}).n()[0,0]
# Out:
# 0.999999999999984

# %%
Dexp_mp(m1,m2,m3,100/3,100/2,100)[0,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8faa7f54a24d> in <module>
# ----> 1 Dexp_mp(1,2,3,4,5,6)[0,0]
#
# ~/Escritorio/ProyectoLFVHD/LFVHD/Examples/Seesaw model/Version 2/Unu_seesaw.py in <lambda>(mn1, mn2, mn3, mn4, mn5, mn6)
#     134 Aexp_mp = lambda mn1,mn2,mn3,mn4,mn5,mn6: (I3_mp - mp.mpf('0.5')*Eexp_mp(mn1,mn2,mn3,mn4,mn5,mn6).conjugate()*Eexp_mp(mn1,mn2,mn3,mn4,mn5,mn6).transpose())
#     135
# --> 136 Dexp_mp = lambda mn1,mn2,mn3,mn4,mn5,mn6: (I3_mp - mp.mpf('0.5')*Eexp_mp(mn1,mn2,mn3,mn4,mn5,mn6).transpose*Eexp_mp(mn1,mn2,mn3,mn4,mn5,mn6).conjugate())
#     137 #Aexp
#     138
#
# TypeError: unsupported operand type(s) for *: 'mpf' and 'method'

# %%
Unu(mpf('1e-10'),mpf('1e15'),2,3),Ununp(1e-10,1e15,2,3)
# Out:
# ((0.73857648216010796105024378295240174436749049515816478041003037042169249278268883 + 0.0j),
#  0.738576482160108)

# %% [markdown]
# ### Form factor with two fermion in the loop.

# %%
def sumTwo(m6,ALab,a,b):
    AL = 0  
    mnk = (m1,m2,m3,m4(m6),m5(m6),m6)
    for i in range(1,4):
        for j in range(4,7):
            L = ALab(mnk[i-1],mnk[j-i],Unu(mnk[0],mnk[-1],b,j),conj(Unu(mnk[0],mnk[-1],a,i)),
                      Cij(mnk[0],mnk[-1],i,j),conj(Cij(mnk[0],mnk[-1],i,j)))
            if mp.isnan(L):
                print(mnk[i-1],mnk[j-i],Unu(mnk[0],mnk[-1],b,j),Cij(mnk[0],mnk[-1],i,j),L)
            AL += L
    return AL

# %%
mnj = symbols('m_{n_j}',positive=True)
Cijs, Cijcs, Ubj = symbols('C_{ij}, {{C_{ij}^*}},U_{bj}')
UnuTwo = {mn[i]:mni,mn[jj]:mnj,C[i,jj]:Cijs, Cc[i,jj]:Cijcs, Uν[b,jj]:Ubj, Uνc[a,i]:Ucai}
UnuTwo
# Out:
# {C[i, j]: C_{ij}, {{C^*}}[i, j]: {{C_{ij}__*}}, {{U^\nu}}[b, j]: U_{bj}, {{U^{
# \nu *}}}[a, i]: {{U_{ai}__*}}, {{m_n}}[i]: m_{n_i}, {{m_n}}[j]: m_{n_j}}

# %%
def numeric_sum_diagramsTwo(aa,bb,quirality='L'):
    if quirality=='L':
        x = AbL.subs(lfvhd.D,4).subs(cambios_hab(aa,bb)).subs(valores).subs(UnuTwo)
    elif quirality=='R':
        x = AbR.subs(lfvhd.D,4).subs(cambios_hab(aa,bb)).subs(valores).subs(UnuTwo)
    else:
        raise ValueError('quirality must be L or R')
    f = lambdify([mni,mnj,Ubj,Ucai,Cijs,Cijcs],replaceBs(x),
                 modules=[pave_functions(valores[mh],aa,bb,lib='mpmath'),'mpmath'] )
        
    fsum = lambda m6:sumTwo(m6,f,aa,bb)
    return fsum

# %%
# a = 2, b = 3
ALTwoTot23 = numeric_sum_diagramsTwo(2,3,quirality='L')
ARTwoTot23 = numeric_sum_diagramsTwo(2,3,quirality='R')

# a = 3, b = 2
ALTwoTot32 = numeric_sum_diagramsTwo(3,2,quirality='L')
ARTwoTot32 = numeric_sum_diagramsTwo(3,2,quirality='R')

# a = 1, b = 3
ALTwoTot13 = numeric_sum_diagramsTwo(1,3,quirality='L')
ARTwoTot13 = numeric_sum_diagramsTwo(1,3,quirality='R')

# a = 3, b = 1
ALTwoTot31 = numeric_sum_diagramsTwo(3,1,quirality='L')
ARTwoTot31 = numeric_sum_diagramsTwo(3,1,quirality='R')

# a = 1, b = 2
ALTwoTot12 = numeric_sum_diagramsTwo(1,2,quirality='L')
ARTwoTot12 = numeric_sum_diagramsTwo(1,2,quirality='R')

# a = 2, b = 1
ALTwoTot21 = numeric_sum_diagramsTwo(2,1,quirality='L')
ARTwoTot21 = numeric_sum_diagramsTwo(2,1,quirality='R')

# %%
n = 100
m6np = np.logspace(-1,15,n)
#m6np = np.linspace(1e-10,1e15,n)


YLTwo23 = np.array([np.abs(ALTwoTot23(mpf(str(m6)))) for m6 in m6np])
YLTwo32 = np.array([np.abs(ARTwoTot32(mpf(str(m6)))) for m6 in m6np])

YLTwo13 = np.array([np.abs(ALTwoTot13(mpf(str(m6)))) for m6 in m6np])
YLTwo31 = np.array([np.abs(ARTwoTot31(mpf(str(m6)))) for m6 in m6np])

YLTwo12 = np.array([np.abs(ALTwoTot12(mpf(str(m6)))) for m6 in m6np])
YLTwo21 = np.array([np.abs(ARTwoTot21(mpf(str(m6)))) for m6 in m6np])

# %%
plt.figure(figsize=(15,8))

plt.loglog(np.real(m6np),YLTwo23,label='$A_L^{(2)}(2,3)$')
plt.loglog(np.real(m6np),YLTwo32,label='$A_L^{(2)}(3,2)$')

plt.loglog(np.real(m6np),YLTwo13,label='$A_L^{(2)}(1,3)$')
plt.loglog(np.real(m6np),YLTwo31,label='$A_L^{(2)}(3,1)$')

plt.loglog(np.real(m6np),YLTwo12,label='$A_L^{(2)}(1,2)$')
plt.loglog(np.real(m6np),YLTwo21,label='$A_L^{(2)}(2,1)$')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)

plt.legend(fontsize=15)

# %% [markdown]
# ## Total Form Factors

# %%
#a = 2, b = 3
ALtot23 =lambda m6: ALOneTot23(mpf(str(m6)))[1] + ALTwoTot23(mpf(str(m6)))
ARtot23 =lambda m6: AROneTot23(mpf(str(m6)))[1] + ARTwoTot23(mpf(str(m6)))

#a = 3, b = 2
ALtot32 =lambda m6: ALOneTot32(mpf(str(m6)))[1] + ALTwoTot32(mpf(str(m6)))
ARtot32 =lambda m6: AROneTot32(mpf(str(m6)))[1] + ARTwoTot32(mpf(str(m6)))

#a = 1, b = 3
ALtot13 =lambda m6: ALOneTot13(mpf(str(m6)))[1] + ALTwoTot13(mpf(str(m6)))
ARtot13 =lambda m6: AROneTot13(mpf(str(m6)))[1] + ARTwoTot13(mpf(str(m6)))

#a = 3, b = 1
ALtot31 =lambda m6: ALOneTot31(mpf(str(m6)))[1] + ALTwoTot31(mpf(str(m6)))
ARtot31 =lambda m6: AROneTot31(mpf(str(m6)))[1] + ARTwoTot31(mpf(str(m6)))

#a = 1, b = 2
ALtot12 =lambda m6: ALOneTot12(mpf(str(m6)))[1] + ALTwoTot12(mpf(str(m6)))
ARtot12 =lambda m6: AROneTot12(mpf(str(m6)))[1] + ARTwoTot12(mpf(str(m6)))

#a = 2, b = 1
ALtot21 =lambda m6: ALOneTot21(mpf(str(m6)))[1] + ALTwoTot21(mpf(str(m6)))
ARtot21 =lambda m6: AROneTot21(mpf(str(m6)))[1] + ARTwoTot21(mpf(str(m6)))

# %%
# plt.figure(figsize=(15,8))
# YLT23 =YLTwo23 + YLTwo32
# YLO23 = YLOne23 + YLOne32
# YL23 = YLT23 + YLO23

# plt.loglog(np.real(m6np),YLO23,label='$A_L^{(1)}(2,3)$')
# plt.loglog(np.real(m6np),YLT23,label='$A_L^{(2)}(2,3)$')
# plt.loglog(np.real(m6np),YL23,label='$A_L(2,3)$')


# plt.xticks(fontsize=15)
# plt.yticks(fontsize=15)

# plt.legend(fontsize=15)

# %% [markdown]
# ## Width decay of $h \to e_a e_b$

# %%
from OneLoopLFVHD import Γhlilj

# %%
n = 100
m6np = np.logspace(-1,15,n)

# %%
YW23 = np.array([Γhlilj(ALtot23(m6),ARtot23(m6),valores[mh],ml[2],ml[3]) for m6 in m6np])
YW32 = np.array([Γhlilj(ALtot32(m6),ARtot32(m6),valores[mh],ml[3],ml[2]) for m6 in m6np])

YW13 = np.array([Γhlilj(ALtot13(m6),ARtot13(m6),valores[mh],ml[1],ml[3]) for m6 in m6np])
YW31 = np.array([Γhlilj(ALtot31(m6),ARtot31(m6),valores[mh],ml[3],ml[1]) for m6 in m6np])

YW12 = np.array([Γhlilj(ALtot12(m6),ARtot12(m6),valores[mh],ml[1],ml[2]) for m6 in m6np])
YW21 = np.array([Γhlilj(ALtot21(m6),ARtot21(m6),valores[mh],ml[2],ml[1]) for m6 in m6np])

# %%
Wtot = (
    YW23 + YW13 + YW12 + 
    0.0032 + YW32 + YW31 + YW21)

# %%
plt.figure(figsize=(12,8))
plt.loglog(np.real(m6np),(
    YW23 + 
    YW32
)/Wtot,label=r'Br($h \to \mu \tau$)')
plt.loglog(np.real(m6np),(
    YW13 + 
    YW31
)/Wtot,label=r'Br($h \to e \tau$)')
plt.loglog(np.real(m6np),(
    YW12 + 
    YW21
)/Wtot,label=r'Br($h \to e \mu$)')

plt.hlines(1,0.1,1e15,linestyles='-.',label=r'$1\times 10^{-1}$')
plt.hlines(4e-37,0.1,1e15,linestyles='--',color='b',label=r'$4\times 10^{-37}$')
plt.vlines(80.379,4e-37,1e-2,linestyles='--',color='r',label=r'$m_W$')
#plt.ylim(1e-49,1)
plt.yticks([1e-49,1e-39,1e-29,1e-19,1e-9,1])
plt.legend(fontsize=15)

# %%
from seesaw_FF import TrianglesOneFermion, TrianglesTwoFermion, Bubbles

# %%
δ1 = (AbL - (TrianglesTwoFermion[0].AL() + TrianglesTwoFermion[1].AL())).subs(lfvhd.D,4)
δ1.simplify()
# Out:
#  3    ⎛   2                                                   2      2
# g ⋅mᵢ⋅⎝m_W ⋅C₀(m_W, {{m_n}}[i], {{m_n}}[j])⋅C[i, j]⋅{{m_n}}[j]  + m_W ⋅C₀(m_W,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                     2
#  {{m_n}}[i], {{m_n}}[j])⋅{{C^*}}[i, j]⋅{{m_n}}[i]⋅{{m_n}}[j] - 2⋅m_W ⋅C₁(m_W,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                           2        2
# {{m_n}}[i], {{m_n}}[j])⋅C[i, j]⋅{{m_n}}[i]  - 2⋅m_W ⋅C₁(m_W, {{m_n}}[i], {{m_n
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                          2        2
# }}[j])⋅C[i, j]⋅{{m_n}}[j]  - 4⋅m_W ⋅C₁(m_W, {{m_n}}[i], {{m_n}}[j])⋅{{C^*}}[i,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                               2
#  j]⋅{{m_n}}[i]⋅{{m_n}}[j] + mᵢ ⋅C₁(m_W, {{m_n}}[i], {{m_n}}[j])⋅C[i, j]⋅{{m_n}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2     2
# }[j]  + mᵢ ⋅C₁(m_W, {{m_n}}[i], {{m_n}}[j])⋅{{C^*}}[i, j]⋅{{m_n}}[i]⋅{{m_n}}[j
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#        2                                                   2      2
# ] + m_j ⋅C₁(m_W, {{m_n}}[i], {{m_n}}[j])⋅C[i, j]⋅{{m_n}}[i]  + m_j ⋅C₁(m_W, {{
# ──────────────────────────────────────────────────────────────────────────────
#                             2    3
#                         32⋅π ⋅m_W
#
#
# m_n}}[i], {{m_n}}[j])⋅{{C^*}}[i, j]⋅{{m_n}}[i]⋅{{m_n}}[j] - 2⋅C₁(m_W, {{m_n}}[
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                   2           2
# i], {{m_n}}[j])⋅C[i, j]⋅{{m_n}}[i] ⋅{{m_n}}[j]  - C₁(m_W, {{m_n}}[i], {{m_n}}[
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             3
# j])⋅{{C^*}}[i, j]⋅{{m_n}}[i] ⋅{{m_n}}[j] - C₁(m_W, {{m_n}}[i], {{m_n}}[j])⋅{{C
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                 3
# ^*}}[i, j]⋅{{m_n}}[i]⋅{{m_n}}[j]  - {{B_{0}}}__{(12)}({{m_n}}[i], {{m_n}}[j])⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                   2
# C[i, j]⋅{{m_n}}[j]  - {{B_{0}}}__{(12)}({{m_n}}[i], {{m_n}}[j])⋅{{C^*}}[i, j]⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                      ⎞
# {{m_n}}[i]⋅{{m_n}}[j]⎠⋅{{U^\nu}}[b, j]⋅{{U^{\nu *}}}[a, i]
# ──────────────────────────────────────────────────────────

# %%
δ2 = (AaL - sum(tria.AL() for tria in TrianglesOneFermion)).subs(lfvhd.D,4)
a2 = δ2.subs(lfvhd.cambiosDivFin(mn[i],mW,mW)).simplify()
a2
# Out:
#  3    ⎛     4 ⎛⎛   2             2⎞
# g ⋅mᵢ⋅⎝8⋅m_W ⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}__{(1)}(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                             ⎞        2 ⎛    2 ⎛
# {{m_n}}[i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠ + 2⋅m_W ⋅⎝- mₐ ⋅⎝\Delta_\epsilon
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                       2                            ⎞       2 ⎛
#  + C₀({{m_n}}[i], m_W, m_W)⋅{{m_n}}[i]  + {{b_0}}__{(12)}(m_W, m_W)⎠ - 2⋅mᵢ ⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     ⎛   2             2⎞
# - 2⋅⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0}}__{(1)}({{m_n}}[i],
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                      ⎞      2
#  m_W) + 2⋅{{b_0}}__{(12)}(m_W, m_W) - {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠ - m_j ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ⎛  ⎛   2             2⎞
# ⎝3⋅⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + 2⋅{{b_0}}__{(1)}({{m_n}}[i]
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                       ⎞   ⎛
# , m_W) - 3⋅{{b_0}}__{(12)}(m_W, m_W) + {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠ - ⎝2⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2      2⎞ ⎛⎛   2             2⎞
# ₐ  - m_j ⎠⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0}}__{(12)}(m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                          ⎞   ⎛  2                            ⎛
# W, m_W) + {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠ + ⎝mₐ ⋅C₀({{m_n}}[i], m_W, m_W) + ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    2             2⎞
# m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}__{(1)}({{m_n}}[i], m_W)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                             ⎞           2   ⎛    2
#  - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{m_n}}[i]  - ⎝2⋅mₐ ⋅C₀({{m_n}}[i], m_W, m_W) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ⎛   2             2⎞
# ⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0}}__{(1)}({{m_n}}[i], m_W
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                              ⎞           2⎞     2 ⎛   2
# ) + {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{m_n}}[i] ⎠ - mₐ ⋅⎝m_j ⋅(\Delta_\epsilon - 2⋅{
# ──────────────────────────────────────────────────────────────────────────────
#            2    3   2
#       128⋅π ⋅m_W ⋅mₐ
#
#                                     ⎛     2     2⎞
# {b_1}}__{(2)}({{m_n}}[i], m_W)) + 2⋅⎝2⋅m_W  + mₐ ⎠⋅C₀({{m_n}}[i], m_W, m_W)⋅{{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         2
# m_n}}[i]  + (-3⋅\Delta_\epsilon - 2⋅{{b_0}}__{(1)}({{m_n}}[i], m_W) + 2⋅{{b_1}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                          2⎞
# }__{(1)}({{m_n}}[i], m_W) - 2⋅{{b_0}}__{(2)}({{m_n}}[i], m_W))⋅{{m_n}}[i] ⎠ +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2 ⎛    2                                    2      2 ⎛⎛   2             2⎞
# 2⋅mₐ ⋅⎝- mₐ ⋅C₀({{m_n}}[i], m_W, m_W)⋅{{m_n}}[i]  + m_j ⋅⎝⎝m_W  - {{m_n}}[i] ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0}}__{(12)}(m_W, m_W) + {{b_0}}__{(2)}({{m_n}}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          ⎞   ⎛⎛   2             2⎞
# [i], m_W)⎠ + ⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}__{(1)}({
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                            ⎞           2⎞     ⎛     2 ⎛  2
# {m_n}}[i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{m_n}}[i] ⎠ - 2⋅⎝2⋅m_W ⋅⎝mₐ  - m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2⎞     2    2⎞ ⎛⎛   2             2⎞
# ᵢ ⎠ - mₐ ⋅m_j ⎠⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0}}__{(12
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                               ⎞     ⎛     2 ⎛     2     2
# )}(m_W, m_W) + {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠ + 2⋅⎝2⋅m_W ⋅⎝2⋅m_W  + mᵢ  - m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  2             2⎞     2           2⎞ ⎛⎛   2             2⎞
# j  + {{m_n}}[i] ⎠ + mₐ ⋅{{m_n}}[i] ⎠⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                    ⎞⎞
#  m_W) + {{b_0}}__{(1)}({{m_n}}[i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⎠⋅{{U^\nu}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# }[b, i]⋅{{U^{\nu *}}}[a, i]
# ───────────────────────────

# %%
δ3 = (AcdL - sum(tria.AL() for tria in Bubbles)).subs(lfvhd.D,4)
a3 = δ3.subs(lfvhd.cambiosDivFin(mn[i],mW,mW)).simplify()
a3
# Out:
#  3    ⎛                  2    2                       2           2
# g ⋅mᵢ⋅⎝\Delta_\epsilon⋅mᵢ ⋅m_j  + 2⋅\Delta_\epsilon⋅mᵢ ⋅{{m_n}}[i]  - \Delta_\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            4                        2           2        2    2
# epsilon⋅m_j  - 2⋅\Delta_\epsilon⋅m_j ⋅{{m_n}}[i]  + 8⋅m_W ⋅m_j ⋅{{b_1}}__{(1)}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                          2    2                                       2    2
# ({{m_n}}[i], m_W) + 8⋅m_W ⋅m_j ⋅{{b_1}}__{(2)}({{m_n}}[i], m_W) + 4⋅mᵢ ⋅m_j ⋅{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                      2    2
# {b_1}}__{(1)}({{m_n}}[i], m_W) + 2⋅mᵢ ⋅m_j ⋅{{b_1}}__{(2)}({{m_n}}[i], m_W) +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#     2                                           2        4
# 2⋅mᵢ ⋅{{b_0}}__{(2)}({{m_n}}[i], m_W)⋅{{m_n}}[i]  + 2⋅m_j ⋅{{b_1}}__{(2)}({{m_
# ──────────────────────────────────────────────────────────────────────────────
#        2    3 ⎛  2      2⎞
#   128⋅π ⋅m_W ⋅⎝mᵢ  - m_j ⎠
#
#                     2                                           2        2
# n}}[i], m_W) - 8⋅m_j ⋅{{b_0}}__{(1)}({{m_n}}[i], m_W)⋅{{m_n}}[i]  + 4⋅m_j ⋅{{b
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                        2        2
# _1}}__{(1)}({{m_n}}[i], m_W)⋅{{m_n}}[i]  + 6⋅m_j ⋅{{b_0}}__{(2)}({{m_n}}[i], m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#               2        2                                           2⎞
# _W)⋅{{m_n}}[i]  + 4⋅m_j ⋅{{b_1}}__{(2)}({{m_n}}[i], m_W)⋅{{m_n}}[i] ⎠⋅{{U^\nu}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# }[b, i]⋅{{U^{\nu *}}}[a, i]
# ───────────────────────────

# %%
(a2 + a3).simplify()
# Out:
#  3    ⎛  2 ⎛                  2    2                       2           2
# g ⋅mᵢ⋅⎝mₐ ⋅⎝\Delta_\epsilon⋅mᵢ ⋅m_j  + 2⋅\Delta_\epsilon⋅mᵢ ⋅{{m_n}}[i]  - \De
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 4                        2           2        2    2
# lta_\epsilon⋅m_j  - 2⋅\Delta_\epsilon⋅m_j ⋅{{m_n}}[i]  + 8⋅m_W ⋅m_j ⋅{{b_1}}__
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                               2    2                                       2
# {(1)}({{m_n}}[i], m_W) + 8⋅m_W ⋅m_j ⋅{{b_1}}__{(2)}({{m_n}}[i], m_W) + 4⋅mᵢ ⋅m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2                                       2    2
# _j ⋅{{b_1}}__{(1)}({{m_n}}[i], m_W) + 2⋅mᵢ ⋅m_j ⋅{{b_1}}__{(2)}({{m_n}}[i], m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          2                                           2        4
# W) + 2⋅mᵢ ⋅{{b_0}}__{(2)}({{m_n}}[i], m_W)⋅{{m_n}}[i]  + 2⋅m_j ⋅{{b_1}}__{(2)}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                          2                                           2
# ({{m_n}}[i], m_W) - 8⋅m_j ⋅{{b_0}}__{(1)}({{m_n}}[i], m_W)⋅{{m_n}}[i]  + 4⋅m_j
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# 2                                           2        2
#  ⋅{{b_1}}__{(1)}({{m_n}}[i], m_W)⋅{{m_n}}[i]  + 6⋅m_j ⋅{{b_0}}__{(2)}({{m_n}}[
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    2        2                                           2⎞   ⎛
# i], m_W)⋅{{m_n}}[i]  + 4⋅m_j ⋅{{b_1}}__{(2)}({{m_n}}[i], m_W)⋅{{m_n}}[i] ⎠ + ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2      2⎞ ⎛     4 ⎛⎛   2             2⎞
# mᵢ  - m_j ⎠⋅⎝8⋅m_W ⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}__
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                   ⎞        2 ⎛    2 ⎛
# {(1)}({{m_n}}[i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠ + 2⋅m_W ⋅⎝- mₐ ⋅⎝\Delta_\e
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                             2                            ⎞
# psilon + C₀({{m_n}}[i], m_W, m_W)⋅{{m_n}}[i]  + {{b_0}}__{(12)}(m_W, m_W)⎠ + 2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    2 ⎛  ⎛   2             2⎞
# ⋅mᵢ ⋅⎝2⋅⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}__{(1)}({{m_n}}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                          ⎞
# [i], m_W) - 2⋅{{b_0}}__{(12)}(m_W, m_W) + {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠ + m
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2 ⎛    ⎛   2             2⎞
# _j ⋅⎝- 3⋅⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - 2⋅{{b_0}}__{(1)}({{m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                             ⎞
# n}}[i], m_W) + 3⋅{{b_0}}__{(12)}(m_W, m_W) - {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   ⎛    2      2⎞ ⎛⎛   2             2⎞
# - ⎝2⋅mₐ  - m_j ⎠⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0}}__{(1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                ⎞   ⎛      2
# 2)}(m_W, m_W) + {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠ + ⎝- 2⋅mₐ ⋅C₀({{m_n}}[i], m_W
# ──────────────────────────────────────────────────────────────────────────────
#          2    3   2 ⎛  2      2⎞
#     128⋅π ⋅m_W ⋅mₐ ⋅⎝mᵢ  - m_j ⎠
#
#          ⎛   2             2⎞
# , m_W) + ⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}__{(1)}({{m_n}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                       ⎞           2   ⎛  2
# }[i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{m_n}}[i]  + ⎝mₐ ⋅C₀({{m_n}}[i], m_W,
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#         ⎛   2             2⎞
#  m_W) + ⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}__{(1)}({{m_n}}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                      ⎞           2⎞     2 ⎛   2
# [i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{m_n}}[i] ⎠ + mₐ ⋅⎝m_j ⋅(-\Delta_\epsi
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                              ⎛     2     2⎞
# lon + 2⋅{{b_1}}__{(2)}({{m_n}}[i], m_W)) - 2⋅⎝2⋅m_W  + mₐ ⎠⋅C₀({{m_n}}[i], m_W
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  2
# , m_W)⋅{{m_n}}[i]  + (3⋅\Delta_\epsilon + 2⋅{{b_0}}__{(1)}({{m_n}}[i], m_W) -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# 2⋅{{b_1}}__{(1)}({{m_n}}[i], m_W) + 2⋅{{b_0}}__{(2)}({{m_n}}[i], m_W))⋅{{m_n}}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#    2⎞       2 ⎛    2                                    2      2 ⎛⎛   2
# [i] ⎠ + 2⋅mₐ ⋅⎝- mₐ ⋅C₀({{m_n}}[i], m_W, m_W)⋅{{m_n}}[i]  + m_j ⋅⎝⎝m_W  - {{m_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2⎞
# n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0}}__{(12)}(m_W, m_W) + {{b_0}}__{(2)}
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                  ⎞   ⎛⎛   2             2⎞
# ({{m_n}}[i], m_W)⎠ + ⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) + {{b_0}}_
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                    ⎞           2⎞     ⎛     2
# _{(1)}({{m_n}}[i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⋅{{m_n}}[i] ⎠ - 2⋅⎝2⋅m_W ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ⎛  2     2⎞     2    2⎞ ⎛⎛   2             2⎞
# ⎝mₐ  - mᵢ ⎠ - mₐ ⋅m_j ⎠⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[i], m_W, m_W) - {{b_0
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                       ⎞     ⎛     2 ⎛     2
# }}__{(12)}(m_W, m_W) + {{b_0}}__{(2)}({{m_n}}[i], m_W)⎠ + 2⋅⎝2⋅m_W ⋅⎝2⋅m_W  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   2      2             2⎞     2           2⎞ ⎛⎛   2             2⎞
# mᵢ  - m_j  + {{m_n}}[i] ⎠ + mₐ ⋅{{m_n}}[i] ⎠⋅⎝⎝m_W  - {{m_n}}[i] ⎠⋅C₀({{m_n}}[
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                                            ⎞⎞⎞
# i], m_W, m_W) + {{b_0}}__{(1)}({{m_n}}[i], m_W) - {{b_0}}__{(12)}(m_W, m_W)⎠⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ⋅{{U^\nu}}[b, i]⋅{{U^{\nu *}}}[a, i]
# ────────────────────────────────────
